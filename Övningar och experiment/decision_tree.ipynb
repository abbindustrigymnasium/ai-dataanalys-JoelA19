# %% [markdown]
# Code to accompany Machine Learning Recipes #8. We'll write a Decision Tree Classifier, in pure Python. Below each of the methods, I've written a little demo to help explain what it does.

# %%
# For Python 2 / 3 compatability
from __future__ import print_function
import random

# %%
# Toy dataset.
# Format: each row is an example.
# The last column is the label.
# The first two columns are features.
# Feel free to play with it by adding more features & examples.
# Interesting note: I've written this so the 2nd and 5th examples
# have the same features, but different labels - so we can see how the
# tree handles this case.
training_data = [
    [54.4, 14.4, 'Kylrum'],    
    [45.4, 12.4, 'Kylrum'],   
    [89.4, 19.5, 'Klassrum'],
    [57.4, 18.1, 'Lärarrum'],    
    [22.4, 8.6, 'Kylrum'],   
    [24.4, 11.24, 'Kylrum'],   
    [84.4, 24.4,'Klassrum'],    
    [95.4, 22.4, 'Klassrum'],   
    [81.4, 20.1, 'Lärarrum'],  
    [70.5, 19.7, 'Lärarrum'],
    [70.5, 19.8,'Klassrum'], 
]

# %%
def generate_data2(times):
    while times != 0:
        randomRow = training_data[random.randint(0, len(training_data) - 1)]
        new_row = [randomRow[0]+ round(random.uniform(-5, 5)), randomRow[1] + round(random.uniform(-3, 3)), randomRow[2]]
        training_data.append(new_row)
        
        times += -1

# %%
generate_data2(2000)

# %%
# Column labels.
# These are used only to print the tree.
header = ["size", "temp", "label"]

# %%
def unique_vals(rows, col):
    """Find the unique values for a column in a dataset."""
    return set([row[col] for row in rows])

# %%
#######
# Demo:
unique_vals(training_data, 0)
# unique_vals(training_data, 1)
#######
# Out:
# {3.3999999999999986,
#  4.399999999999999,
#  5.399999999999999,
#  6.399999999999999,
#  7.399999999999999,
#  8.399999999999999,
#  9.399999999999999,
#  10.399999999999999,
#  11.399999999999999,
#  12.399999999999999,
#  13.399999999999999,
#  14.399999999999999,
#  15.399999999999999,
#  16.4,
#  17.4,
#  18.4,
#  19.4,
#  20.4,
#  21.4,
#  22.4,
#  23.4,
#  24.4,
#  25.4,
#  26.4,
#  27.4,
#  28.4,
#  29.4,
#  30.4,
#  31.4,
#  32.4,
#  33.4,
#  34.4,
#  35.4,
#  36.4,
#  37.4,
#  38.4,
#  39.4,
#  40.4,
#  41.4,
#  42.4,
#  43.4,
#  44.4,
#  45.4,
#  46.4,
#  47.4,
#  48.4,
#  49.4,
#  50.4,
#  51.4,
#  52.4,
#  53.4,
#  54.4,
#  55.4,
#  55.5,
#  56.4,
#  57.4,
#  57.5,
#  58.4,
#  58.5,
#  59.4,
#  59.5,
#  60.4,
#  60.5,
#  61.4,
#  61.5,
#  62.4,
#  62.5,
#  63.4,
#  63.5,
#  64.4,
#  64.5,
#  65.5,
#  66.5,
#  67.5,
#  68.4,
#  68.5,
#  69.5,
#  70.4,
#  70.5,
#  71.4,
#  71.5,
#  72.4,
#  72.5,
#  73.4,
#  73.5,
#  74.4,
#  74.5,
#  75.4,
#  75.5,
#  76.4,
#  76.5,
#  77.4,
#  77.5,
#  78.4,
#  78.5,
#  79.4,
#  79.5,
#  80.4,
#  80.5,
#  81.4,
#  81.5,
#  82.4,
#  82.5,
#  83.4,
#  84.4,
#  84.5,
#  85.4,
#  86.4,
#  87.4,
#  88.4,
#  89.4,
#  90.4,
#  91.4,
#  92.4,
#  93.4,
#  94.4,
#  95.4,
#  96.4,
#  97.4,
#  98.4,
#  99.4,
#  100.4,
#  101.4,
#  102.4,
#  103.4,
#  104.4,
#  105.4,
#  106.4,
#  107.4,
#  108.4,
#  109.4,
#  110.4}

# %%
def class_counts(rows):
    """Counts the number of each type of example in a dataset."""
    counts = {}  # a dictionary of label -> count.
    for row in rows:
        # in our dataset format, the label is always the last column
        label = row[-1]
        if label not in counts:
            counts[label] = 0
        counts[label] += 1
    return counts

# %%
#######
# Demo:
class_counts(training_data)
#######
# Out:
# {'Kylrum': 913, 'Klassrum': 616, 'Lärarrum': 482}

# %%
def is_numeric(value):
    """Test if a value is numeric."""
    return isinstance(value, int) or isinstance(value, float)

# %%
#######
# Demo:
is_numeric(7)
# is_numeric("Red")
#######
# Out:
# True

# %%
class Question:
    """A Question is used to partition a dataset.

    This class just records a 'column number' (e.g., 0 for Color) and a
    'column value' (e.g., Green). The 'match' method is used to compare
    the feature value in an example to the feature value stored in 
    question. See the demo below.
    """

    def __init__(self, column, value):
        self.column = column
        self.value = value

    def match(self, example):
        # Compare the feature value in an example to the
        # feature value in this question.
        val = example[self.column]
        if is_numeric(val):
            return val >= self.value
        else:
            return val == self.value

    def __repr__(self):
        # This is just a helper method to print
        # the question in a readable format.
        condition = "=="
        if is_numeric(self.value):
            condition = ">="
        return "Is %s %s %s?" % (
            header[self.column], condition, str(self.value))

# %%
#######
# Demo:
# Let's write a question for a numeric attribute
Question(0, 60)
# Out:
# Is size >= 60?

# %%
# How about one for a categorical attribute
q = Question(2, 'kylrum')
q
# Out:
# Is label == kylrum?

# %%
# Let's pick an example from the training set...
example = training_data[0]
# ... and see if it matches the question
q.match(example) # this will be true, since the first example is Green.
#######
# Out:
# False

# %%
def partition(rows, question):
    """Partitions a dataset.

    For each row in the dataset, check if it matches the question. If
    so, add it to 'true rows', otherwise, add it to 'false rows'.
    """
    true_rows, false_rows = [], []
    for row in rows:
        if question.match(row):
            true_rows.append(row)
        else:
            false_rows.append(row)
    return true_rows, false_rows

# %%
#######
# Demo:
# Let's partition the training data based on whether rows are Red.
true_rows, false_rows = partition(training_data, Question(0, 60))
# This will contain all the rows bigger than 60
true_rows
# Out:
# [[89.4, 19.5, 'Klassrum'],
#  [84.4, 24.4, 'Klassrum'],
#  [95.4, 22.4, 'Klassrum'],
#  [81.4, 20.1, 'Lärarrum'],
#  [70.5, 19.7, 'Lärarrum'],
#  [70.5, 19.8, 'Klassrum'],
#  [93.4, 22.4, 'Klassrum'],
#  [88.4, 22.5, 'Klassrum'],
#  [90.4, 20.5, 'Klassrum'],
#  [84.4, 18.1, 'Lärarrum'],
#  [82.4, 18.1, 'Lärarrum'],
#  [67.5, 18.7, 'Lärarrum'],
#  [78.4, 19.1, 'Lärarrum'],
#  [74.5, 19.8, 'Klassrum'],
#  [91.4, 21.5, 'Klassrum'],
#  [93.4, 21.5, 'Klassrum'],
#  [88.4, 20.1, 'Lärarrum'],
#  [84.4, 21.5, 'Klassrum'],
#  [94.4, 22.5, 'Klassrum'],
#  [89.4, 20.5, 'Klassrum'],
#  [63.5, 17.7, 'Lärarrum'],
#  [76.5, 18.8, 'Klassrum'],
#  [70.5, 21.7, 'Lärarrum'],
#  [84.4, 20.1, 'Lärarrum'],
#  [88.4, 24.4, 'Klassrum'],
#  [75.5, 22.8, 'Klassrum'],
#  [72.5, 21.8, 'Klassrum'],
#  [85.4, 18.1, 'Lärarrum'],
#  [83.4, 18.1, 'Lärarrum'],
#  [84.4, 22.1, 'Lärarrum'],
#  [81.4, 16.1, 'Lärarrum'],
#  [67.5, 15.7, 'Lärarrum'],
#  [70.5, 17.7, 'Lärarrum'],
#  [86.4, 22.4, 'Klassrum'],
#  [92.4, 24.4, 'Klassrum'],
#  [78.4, 22.1, 'Lärarrum'],
#  [87.4, 20.1, 'Lärarrum'],
#  [81.4, 23.1, 'Lärarrum'],
#  [92.4, 22.4, 'Klassrum'],
#  [73.5, 20.8, 'Klassrum'],
#  [78.4, 18.1, 'Lärarrum'],
#  [89.4, 23.4, 'Klassrum'],
#  [91.4, 21.4, 'Klassrum'],
#  [88.4, 23.4, 'Klassrum'],
#  [84.4, 15.100000000000001, 'Lärarrum'],
#  [87.4, 20.1, 'Lärarrum'],
#  [84.4, 18.1, 'Lärarrum'],
#  [80.4, 15.100000000000001, 'Lärarrum'],
#  [85.4, 21.4, 'Klassrum'],
#  [76.4, 15.100000000000001, 'Lärarrum'],
#  [94.4, 22.5, 'Klassrum'],
#  [71.5, 19.7, 'Lärarrum'],
#  [67.5, 20.7, 'Lärarrum'],
#  [91.4, 19.5, 'Klassrum'],
#  [69.5, 24.8, 'Klassrum'],
#  [86.4, 17.1, 'Lärarrum'],
#  [75.5, 19.8, 'Klassrum'],
#  [72.5, 16.7, 'Lärarrum'],
#  [72.5, 20.8, 'Klassrum'],
#  [86.4, 19.4, 'Klassrum'],
#  [81.4, 22.1, 'Lärarrum'],
#  [73.5, 18.8, 'Klassrum'],
#  [74.5, 23.7, 'Lärarrum'],
#  [74.5, 21.8, 'Klassrum'],
#  [90.4, 26.4, 'Klassrum'],
#  [75.5, 17.8, 'Klassrum'],
#  [99.4, 24.5, 'Klassrum'],
#  [84.4, 20.5, 'Klassrum'],
#  [78.4, 23.1, 'Lärarrum'],
#  [78.4, 16.1, 'Lärarrum'],
#  [63.5, 22.7, 'Lärarrum'],
#  [72.5, 18.8, 'Klassrum'],
#  [82.4, 14.100000000000001, 'Lärarrum'],
#  [83.4, 19.1, 'Lärarrum'],
#  [94.4, 20.5, 'Klassrum'],
#  [90.4, 22.5, 'Klassrum'],
#  [92.4, 20.5, 'Klassrum'],
#  [89.4, 19.5, 'Klassrum'],
#  [84.4, 16.1, 'Lärarrum'],
#  [93.4, 26.4, 'Klassrum'],
#  [93.4, 22.4, 'Klassrum'],
#  [95.4, 23.5, 'Klassrum'],
#  [93.4, 22.1, 'Lärarrum'],
#  [70.5, 17.8, 'Klassrum'],
#  [92.4, 24.5, 'Klassrum'],
#  [73.5, 18.8, 'Klassrum'],
#  [75.5, 25.7, 'Lärarrum'],
#  [101.4, 22.5, 'Klassrum'],
#  [72.5, 16.8, 'Klassrum'],
#  [74.5, 21.7, 'Lärarrum'],
#  [72.5, 18.7, 'Lärarrum'],
#  [92.4, 28.4, 'Klassrum'],
#  [88.4, 25.5, 'Klassrum'],
#  [75.5, 23.8, 'Klassrum'],
#  [73.5, 22.7, 'Lärarrum'],
#  [85.4, 20.5, 'Klassrum'],
#  [78.5, 23.8, 'Klassrum'],
#  [95.4, 20.5, 'Klassrum'],
#  [73.5, 17.7, 'Lärarrum'],
#  [89.4, 20.5, 'Klassrum'],
#  [77.5, 23.8, 'Klassrum'],
#  [78.4, 19.1, 'Lärarrum'],
#  [66.5, 18.8, 'Klassrum'],
#  [76.5, 20.8, 'Klassrum'],
#  [74.5, 27.7, 'Lärarrum'],
#  [77.4, 15.100000000000001, 'Lärarrum'],
#  [82.4, 21.1, 'Lärarrum'],
#  [91.4, 23.5, 'Klassrum'],
#  [85.4, 23.5, 'Klassrum'],
#  [92.4, 21.4, 'Klassrum'],
#  [77.4, 21.1, 'Lärarrum'],
#  [79.5, 21.8, 'Klassrum'],
#  [68.5, 16.8, 'Klassrum'],
#  [74.5, 19.7, 'Lärarrum'],
#  [73.5, 15.8, 'Klassrum'],
#  [87.4, 19.5, 'Klassrum'],
#  [69.5, 19.8, 'Klassrum'],
#  [83.4, 21.1, 'Lärarrum'],
#  [80.4, 25.1, 'Lärarrum'],
#  [66.5, 18.8, 'Klassrum'],
#  [83.4, 22.4, 'Klassrum'],
#  [83.4, 18.5, 'Klassrum'],
#  [93.4, 20.5, 'Klassrum'],
#  [87.4, 17.1, 'Lärarrum'],
#  [73.5, 15.7, 'Lärarrum'],
#  [91.4, 20.1, 'Lärarrum'],
#  [84.4, 16.1, 'Lärarrum'],
#  [69.5, 15.8, 'Klassrum'],
#  [69.5, 23.7, 'Lärarrum'],
#  [84.4, 19.5, 'Klassrum'],
#  [94.4, 24.5, 'Klassrum'],
#  [65.5, 21.8, 'Klassrum'],
#  [94.4, 25.5, 'Klassrum'],
#  [87.4, 16.5, 'Klassrum'],
#  [79.5, 26.8, 'Klassrum'],
#  [80.4, 21.4, 'Klassrum'],
#  [80.4, 24.4, 'Klassrum'],
#  [78.4, 19.1, 'Lärarrum'],
#  [78.5, 16.7, 'Lärarrum'],
#  [85.4, 19.5, 'Klassrum'],
#  [100.4, 26.5, 'Klassrum'],
#  [105.4, 26.5, 'Klassrum'],
#  [68.5, 20.8, 'Klassrum'],
#  [78.5, 19.8, 'Klassrum'],
#  [81.4, 13.100000000000001, 'Lärarrum'],
#  [89.4, 20.1, 'Lärarrum'],
#  [72.5, 24.7, 'Lärarrum'],
#  [73.5, 16.7, 'Lärarrum'],
#  [90.4, 26.5, 'Klassrum'],
#  [87.4, 19.5, 'Klassrum'],
#  [88.4, 19.5, 'Klassrum'],
#  [105.4, 20.5, 'Klassrum'],
#  [72.5, 17.7, 'Lärarrum'],
#  [65.5, 21.7, 'Lärarrum'],
#  [89.4, 23.4, 'Klassrum'],
#  [85.4, 14.100000000000001, 'Lärarrum'],
#  [66.5, 19.8, 'Klassrum'],
#  [69.5, 17.8, 'Klassrum'],
#  [69.5, 24.7, 'Lärarrum'],
#  [84.4, 18.1, 'Lärarrum'],
#  [105.4, 18.5, 'Klassrum'],
#  [66.5, 17.8, 'Klassrum'],
#  [104.4, 21.5, 'Klassrum'],
#  [75.5, 17.8, 'Klassrum'],
#  [76.5, 20.8, 'Klassrum'],
#  [81.4, 19.1, 'Lärarrum'],
#  [82.4, 22.1, 'Lärarrum'],
#  [69.5, 21.7, 'Lärarrum'],
#  [72.5, 15.8, 'Klassrum'],
#  [86.4, 21.5, 'Klassrum'],
#  [84.4, 25.4, 'Klassrum'],
#  [83.4, 20.5, 'Klassrum'],
#  [84.4, 13.100000000000001, 'Lärarrum'],
#  [72.5, 23.7, 'Lärarrum'],
#  [70.5, 14.8, 'Klassrum'],
#  [93.4, 19.4, 'Klassrum'],
#  [98.4, 21.4, 'Klassrum'],
#  [89.4, 21.1, 'Lärarrum'],
#  [97.4, 21.5, 'Klassrum'],
#  [84.4, 15.100000000000001, 'Lärarrum'],
#  [96.4, 20.4, 'Klassrum'],
#  [88.4, 23.5, 'Klassrum'],
#  [69.5, 21.7, 'Lärarrum'],
#  [98.4, 24.5, 'Klassrum'],
#  [87.4, 19.1, 'Lärarrum'],
#  [91.4, 22.5, 'Klassrum'],
#  [81.4, 22.1, 'Lärarrum'],
#  [81.4, 13.100000000000001, 'Lärarrum'],
#  [97.4, 24.4, 'Klassrum'],
#  [92.4, 21.5, 'Klassrum'],
#  [82.4, 22.5, 'Klassrum'],
#  [89.4, 23.4, 'Klassrum'],
#  [68.5, 18.7, 'Lärarrum'],
#  [83.4, 21.1, 'Lärarrum'],
#  [75.5, 16.7, 'Lärarrum'],
#  [92.4, 25.4, 'Klassrum'],
#  [76.5, 19.8, 'Klassrum'],
#  [85.4, 20.5, 'Klassrum'],
#  [102.4, 26.5, 'Klassrum'],
#  [89.4, 19.1, 'Lärarrum'],
#  [85.4, 15.100000000000001, 'Lärarrum'],
#  [87.4, 17.5, 'Klassrum'],
#  [72.5, 18.8, 'Klassrum'],
#  [83.4, 25.4, 'Klassrum'],
#  [65.5, 20.8, 'Klassrum'],
#  [90.4, 20.5, 'Klassrum'],
#  [85.4, 24.4, 'Klassrum'],
#  [93.4, 22.5, 'Klassrum'],
#  [82.4, 24.1, 'Lärarrum'],
#  [77.5, 28.8, 'Klassrum'],
#  [88.4, 22.5, 'Klassrum'],
#  [90.4, 21.5, 'Klassrum'],
#  [75.5, 20.8, 'Klassrum'],
#  [84.4, 14.100000000000001, 'Lärarrum'],
#  [65.5, 19.8, 'Klassrum'],
#  [89.4, 25.4, 'Klassrum'],
#  [74.5, 22.7, 'Lärarrum'],
#  [87.4, 23.4, 'Klassrum'],
#  [89.4, 22.5, 'Klassrum'],
#  [105.4, 21.5, 'Klassrum'],
#  [98.4, 20.4, 'Klassrum'],
#  [94.4, 26.4, 'Klassrum'],
#  [86.4, 20.5, 'Klassrum'],
#  [68.5, 18.7, 'Lärarrum'],
#  [85.4, 26.4, 'Klassrum'],
#  [72.5, 16.7, 'Lärarrum'],
#  [81.4, 20.1, 'Lärarrum'],
#  [68.5, 26.7, 'Lärarrum'],
#  [81.4, 27.4, 'Klassrum'],
#  [76.4, 19.1, 'Lärarrum'],
#  [71.5, 16.8, 'Klassrum'],
#  [80.4, 17.1, 'Lärarrum'],
#  [86.4, 22.4, 'Klassrum'],
#  [76.4, 15.100000000000001, 'Lärarrum'],
#  [93.4, 25.4, 'Klassrum'],
#  [74.5, 20.8, 'Klassrum'],
#  [76.5, 21.8, 'Klassrum'],
#  [91.4, 19.5, 'Klassrum'],
#  [68.5, 18.8, 'Klassrum'],
#  [90.4, 23.1, 'Lärarrum'],
#  [92.4, 25.4, 'Klassrum'],
#  [73.5, 22.8, 'Klassrum'],
#  [82.4, 22.5, 'Klassrum'],
#  [83.4, 17.1, 'Lärarrum'],
#  [82.4, 21.4, 'Klassrum'],
#  [72.5, 20.7, 'Lärarrum'],
#  [71.5, 19.8, 'Klassrum'],
#  [80.4, 20.1, 'Lärarrum'],
#  [83.4, 22.5, 'Klassrum'],
#  [62.5, 22.8, 'Klassrum'],
#  [88.4, 17.1, 'Lärarrum'],
#  [71.5, 24.7, 'Lärarrum'],
#  [86.4, 14.100000000000001, 'Lärarrum'],
#  [92.4, 21.4, 'Klassrum'],
#  [79.5, 24.8, 'Klassrum'],
#  [82.4, 21.5, 'Klassrum'],
#  [74.5, 18.8, 'Klassrum'],
#  [81.4, 18.1, 'Lärarrum'],
#  [79.5, 19.8, 'Klassrum'],
#  [86.4, 18.1, 'Lärarrum'],
#  [85.4, 24.1, 'Lärarrum'],
#  [108.4, 23.5, 'Klassrum'],
#  [79.4, 13.100000000000001, 'Lärarrum'],
#  [87.4, 23.5, 'Klassrum'],
#  [78.5, 23.8, 'Klassrum'],
#  [76.4, 20.1, 'Lärarrum'],
#  [82.4, 19.1, 'Lärarrum'],
#  [81.4, 26.4, 'Klassrum'],
#  [68.5, 13.8, 'Klassrum'],
#  [90.4, 23.4, 'Klassrum'],
#  [82.4, 22.1, 'Lärarrum'],
#  [74.5, 20.7, 'Lärarrum'],
#  [67.5, 20.8, 'Klassrum'],
#  [75.5, 20.8, 'Klassrum'],
#  [70.5, 19.8, 'Klassrum'],
#  [70.5, 22.7, 'Lärarrum'],
#  [97.4, 17.4, 'Klassrum'],
#  [63.5, 20.8, 'Klassrum'],
#  [74.5, 18.8, 'Klassrum'],
#  [102.4, 26.4, 'Klassrum'],
#  [86.4, 19.1, 'Lärarrum'],
#  [77.4, 17.1, 'Lärarrum'],
#  [83.4, 16.1, 'Lärarrum'],
#  [81.4, 25.1, 'Lärarrum'],
#  [86.4, 19.1, 'Lärarrum'],
#  [82.4, 16.1, 'Lärarrum'],
#  [61.5, 17.8, 'Klassrum'],
#  [88.4, 20.5, 'Klassrum'],
#  [80.4, 17.1, 'Lärarrum'],
#  [78.5, 20.8, 'Klassrum'],
#  [84.4, 20.5, 'Klassrum'],
#  [61.4, 19.1, 'Lärarrum'],
#  [65.5, 24.7, 'Lärarrum'],
#  [78.5, 25.8, 'Klassrum'],
#  [74.5, 19.8, 'Klassrum'],
#  [85.4, 21.5, 'Klassrum'],
#  [65.5, 23.8, 'Klassrum'],
#  [86.4, 19.5, 'Klassrum'],
#  [71.5, 19.7, 'Lärarrum'],
#  [66.5, 19.7, 'Lärarrum'],
#  [76.5, 15.8, 'Klassrum'],
#  [61.5, 25.7, 'Lärarrum'],
#  [85.4, 22.5, 'Klassrum'],
#  [66.5, 21.7, 'Lärarrum'],
#  [93.4, 23.5, 'Klassrum'],
#  [87.4, 20.5, 'Klassrum'],
#  [84.4, 19.1, 'Lärarrum'],
#  [86.4, 17.5, 'Klassrum'],
#  [97.4, 17.5, 'Klassrum'],
#  [94.4, 22.5, 'Klassrum'],
#  [94.4, 22.5, 'Klassrum'],
#  [77.5, 17.8, 'Klassrum'],
#  [84.4, 20.4, 'Klassrum'],
#  [86.4, 18.1, 'Lärarrum'],
#  [89.4, 20.5, 'Klassrum'],
#  [92.4, 19.5, 'Klassrum'],
#  [108.4, 20.5, 'Klassrum'],
#  [79.4, 16.1, 'Lärarrum'],
#  [76.5, 24.7, 'Lärarrum'],
#  [78.5, 21.8, 'Klassrum'],
#  [90.4, 22.4, 'Klassrum'],
#  [83.4, 19.5, 'Klassrum'],
#  [80.5, 22.7, 'Lärarrum'],
#  [85.4, 22.5, 'Klassrum'],
#  [101.4, 19.5, 'Klassrum'],
#  [96.4, 18.5, 'Klassrum'],
#  [84.4, 22.5, 'Klassrum'],
#  [92.4, 18.5, 'Klassrum'],
#  [73.4, 16.1, 'Lärarrum'],
#  [85.4, 21.1, 'Lärarrum'],
#  [96.4, 23.5, 'Klassrum'],
#  [79.5, 19.8, 'Klassrum'],
#  [82.4, 23.5, 'Klassrum'],
#  [103.4, 19.5, 'Klassrum'],
#  [67.5, 23.7, 'Lärarrum'],
#  [85.4, 22.1, 'Lärarrum'],
#  [73.5, 15.7, 'Lärarrum'],
#  [99.4, 23.5, 'Klassrum'],
#  [86.4, 17.5, 'Klassrum'],
#  [73.5, 24.8, 'Klassrum'],
#  [77.4, 19.1, 'Lärarrum'],
#  [105.4, 18.5, 'Klassrum'],
#  [80.4, 13.100000000000001, 'Lärarrum'],
#  [84.4, 21.5, 'Klassrum'],
#  [96.4, 22.4, 'Klassrum'],
#  [108.4, 21.5, 'Klassrum'],
#  [89.4, 24.4, 'Klassrum'],
#  [68.5, 17.8, 'Klassrum'],
#  [97.4, 20.4, 'Klassrum'],
#  [69.5, 15.8, 'Klassrum'],
#  [83.4, 19.1, 'Lärarrum'],
#  [85.4, 25.1, 'Lärarrum'],
#  [87.4, 23.1, 'Lärarrum'],
#  [72.5, 20.7, 'Lärarrum'],
#  [86.4, 17.5, 'Klassrum'],
#  [101.4, 20.4, 'Klassrum'],
#  [82.4, 17.5, 'Klassrum'],
#  [85.4, 28.4, 'Klassrum'],
#  [86.4, 26.5, 'Klassrum'],
#  [81.4, 23.1, 'Lärarrum'],
#  [72.5, 21.7, 'Lärarrum'],
#  [69.5, 19.7, 'Lärarrum'],
#  [86.4, 19.5, 'Klassrum'],
#  [104.4, 19.5, 'Klassrum'],
#  [88.4, 20.5, 'Klassrum'],
#  [73.5, 21.7, 'Lärarrum'],
#  [78.5, 25.8, 'Klassrum'],
#  [82.4, 24.1, 'Lärarrum'],
#  [88.4, 21.5, 'Klassrum'],
#  [77.4, 12.100000000000001, 'Lärarrum'],
#  [90.4, 22.5, 'Klassrum'],
#  [73.5, 21.8, 'Klassrum'],
#  [90.4, 20.5, 'Klassrum'],
#  [76.4, 20.1, 'Lärarrum'],
#  [62.4, 9.4, 'Kylrum'],
#  [68.5, 19.8, 'Klassrum'],
#  [81.4, 23.5, 'Klassrum'],
#  [85.4, 23.4, 'Klassrum'],
#  [70.5, 26.7, 'Lärarrum'],
#  [73.5, 15.8, 'Klassrum'],
#  [78.5, 20.8, 'Klassrum'],
#  [69.5, 18.7, 'Lärarrum'],
#  [72.5, 22.8, 'Klassrum'],
#  [89.4, 19.5, 'Klassrum'],
#  [85.4, 20.5, 'Klassrum'],
#  [68.5, 18.7, 'Lärarrum'],
#  [72.5, 17.8, 'Klassrum'],
#  [69.5, 16.8, 'Klassrum'],
#  [74.5, 23.7, 'Lärarrum'],
#  [103.4, 22.5, 'Klassrum'],
#  [74.4, 18.1, 'Lärarrum'],
#  [60.4, 25.1, 'Lärarrum'],
#  [93.4, 23.4, 'Klassrum'],
#  [82.4, 20.5, 'Klassrum'],
#  [80.4, 23.1, 'Lärarrum'],
#  [74.5, 18.8, 'Klassrum'],
#  [92.4, 21.5, 'Klassrum'],
#  [76.5, 19.7, 'Lärarrum'],
#  [72.5, 18.8, 'Klassrum'],
#  [101.4, 14.399999999999999, 'Klassrum'],
#  [79.4, 16.5, 'Klassrum'],
#  [85.4, 21.1, 'Lärarrum'],
#  [97.4, 20.4, 'Klassrum'],
#  [77.5, 17.7, 'Lärarrum'],
#  [80.4, 22.1, 'Lärarrum'],
#  [89.4, 16.1, 'Lärarrum'],
#  [63.5, 16.7, 'Lärarrum'],
#  [65.5, 22.7, 'Lärarrum'],
#  [78.4, 21.4, 'Klassrum'],
#  [84.4, 16.1, 'Lärarrum'],
#  [75.5, 22.8, 'Klassrum'],
#  [94.4, 15.5, 'Klassrum'],
#  [81.4, 18.1, 'Lärarrum'],
#  [105.4, 23.5, 'Klassrum'],
#  [67.5, 24.7, 'Lärarrum'],
#  [95.4, 13.5, 'Klassrum'],
#  [86.4, 17.1, 'Lärarrum'],
#  [85.4, 17.5, 'Klassrum'],
#  [87.4, 16.5, 'Klassrum'],
#  [81.4, 11.100000000000001, 'Lärarrum'],
#  [83.4, 16.5, 'Klassrum'],
#  [90.4, 20.1, 'Lärarrum'],
#  [107.4, 19.5, 'Klassrum'],
#  [60.4, 22.1, 'Lärarrum'],
#  [63.5, 19.8, 'Klassrum'],
#  [86.4, 24.5, 'Klassrum'],
#  [79.4, 25.1, 'Lärarrum'],
#  [75.5, 16.8, 'Klassrum'],
#  [90.4, 26.4, 'Klassrum'],
#  [73.5, 17.7, 'Lärarrum'],
#  [69.5, 25.7, 'Lärarrum'],
#  [73.5, 18.8, 'Klassrum'],
#  [87.4, 27.5, 'Klassrum'],
#  [108.4, 19.5, 'Klassrum'],
#  [82.4, 18.5, 'Klassrum'],
#  [87.4, 17.5, 'Klassrum'],
#  [81.4, 28.4, 'Klassrum'],
#  [82.4, 24.4, 'Klassrum'],
#  [84.4, 22.4, 'Klassrum'],
#  [65.5, 25.8, 'Klassrum'],
#  [104.4, 22.5, 'Klassrum'],
#  [82.4, 14.5, 'Klassrum'],
#  [90.4, 20.5, 'Klassrum'],
#  [75.5, 14.8, 'Klassrum'],
#  [80.4, 17.1, 'Lärarrum'],
#  [88.4, 26.1, 'Lärarrum'],
#  [83.4, 20.1, 'Lärarrum'],
#  [82.4, 19.5, 'Klassrum'],
#  [93.4, 23.5, 'Klassrum'],
#  [65.5, 17.7, 'Lärarrum'],
#  [71.5, 16.7, 'Lärarrum'],
#  [100.4, 23.4, 'Klassrum'],
#  [97.4, 23.5, 'Klassrum'],
#  [61.4, 12.4, 'Kylrum'],
#  [72.5, 15.8, 'Klassrum'],
#  [89.4, 19.1, 'Lärarrum'],
#  [81.4, 23.1, 'Lärarrum'],
#  [79.4, 20.5, 'Klassrum'],
#  [73.5, 20.7, 'Lärarrum'],
#  [74.5, 13.8, 'Klassrum'],
#  [66.5, 13.8, 'Klassrum'],
#  [92.4, 16.4, 'Klassrum'],
#  [91.4, 18.5, 'Klassrum'],
#  [95.4, 24.4, 'Klassrum'],
#  [77.5, 16.8, 'Klassrum'],
#  [75.5, 19.7, 'Lärarrum'],
#  [82.5, 24.8, 'Klassrum'],
#  [93.4, 15.100000000000001, 'Lärarrum'],
#  [83.4, 18.1, 'Lärarrum'],
#  [78.5, 22.8, 'Klassrum'],
#  [89.4, 18.1, 'Lärarrum'],
#  [82.4, 18.1, 'Lärarrum'],
#  [73.5, 19.8, 'Klassrum'],
#  [96.4, 21.5, 'Klassrum'],
#  [89.4, 24.4, 'Klassrum'],
#  [65.5, 25.8, 'Klassrum'],
#  [94.4, 21.5, 'Klassrum'],
#  [61.5, 19.8, 'Klassrum'],
#  [92.4, 22.5, 'Klassrum'],
#  [98.4, 26.4, 'Klassrum'],
#  [89.4, 19.5, 'Klassrum'],
#  [83.4, 20.1, 'Lärarrum'],
#  [91.4, 27.4, 'Klassrum'],
#  [77.4, 17.1, 'Lärarrum'],
#  [75.4, 22.1, 'Lärarrum'],
#  [75.5, 18.7, 'Lärarrum'],
#  [94.4, 22.4, 'Klassrum'],
#  [79.4, 20.5, 'Klassrum'],
#  [93.4, 20.4, 'Klassrum'],
#  [100.4, 18.5, 'Klassrum'],
#  [84.4, 14.100000000000001, 'Lärarrum'],
#  [108.4, 27.5, 'Klassrum'],
#  [85.4, 23.4, 'Klassrum'],
#  [91.4, 23.4, 'Klassrum'],
#  [85.4, 21.1, 'Lärarrum'],
#  [95.4, 19.5, 'Klassrum'],
#  [93.4, 21.4, 'Klassrum'],
#  [84.4, 21.1, 'Lärarrum'],
#  [71.5, 27.7, 'Lärarrum'],
#  [73.5, 19.7, 'Lärarrum'],
#  [68.5, 19.7, 'Lärarrum'],
#  [83.4, 19.5, 'Klassrum'],
#  [73.5, 25.8, 'Klassrum'],
#  [86.4, 17.1, 'Lärarrum'],
#  [90.4, 20.5, 'Klassrum'],
#  [79.4, 9.100000000000001, 'Lärarrum'],
#  [82.4, 21.1, 'Lärarrum'],
#  [78.4, 22.1, 'Lärarrum'],
#  [81.4, 15.100000000000001, 'Lärarrum'],
#  [100.4, 11.399999999999999, 'Klassrum'],
#  [93.4, 19.5, 'Klassrum'],
#  [71.5, 14.8, 'Klassrum'],
#  [83.4, 22.4, 'Klassrum'],
#  [97.4, 20.5, 'Klassrum'],
#  [66.5, 14.7, 'Lärarrum'],
#  [82.4, 19.5, 'Klassrum'],
#  [82.4, 14.100000000000001, 'Lärarrum'],
#  [84.4, 16.4, 'Klassrum'],
#  [69.5, 18.7, 'Lärarrum'],
#  [85.4, 20.1, 'Lärarrum'],
#  [76.5, 23.8, 'Klassrum'],
#  [77.4, 16.5, 'Klassrum'],
#  [75.4, 25.1, 'Lärarrum'],
#  [87.4, 24.4, 'Klassrum'],
#  [68.5, 21.7, 'Lärarrum'],
#  [90.4, 15.100000000000001, 'Lärarrum'],
#  [81.4, 18.5, 'Klassrum'],
#  [93.4, 10.5, 'Klassrum'],
#  [86.4, 21.5, 'Klassrum'],
#  [106.4, 21.5, 'Klassrum'],
#  [63.5, 19.8, 'Klassrum'],
#  [68.5, 17.8, 'Klassrum'],
#  [94.4, 21.5, 'Klassrum'],
#  [82.5, 19.8, 'Klassrum'],
#  [84.4, 20.1, 'Lärarrum'],
#  [79.4, 17.1, 'Lärarrum'],
#  [93.4, 22.4, 'Klassrum'],
#  [82.4, 19.1, 'Lärarrum'],
#  [90.4, 24.5, 'Klassrum'],
#  [72.5, 17.7, 'Lärarrum'],
#  [73.5, 25.7, 'Lärarrum'],
#  [88.4, 18.5, 'Klassrum'],
#  [66.5, 24.8, 'Klassrum'],
#  [77.4, 27.1, 'Lärarrum'],
#  [67.5, 19.8, 'Klassrum'],
#  [73.4, 17.1, 'Lärarrum'],
#  [96.4, 20.4, 'Klassrum'],
#  [81.4, 16.1, 'Lärarrum'],
#  [85.4, 20.1, 'Lärarrum'],
#  [82.4, 24.1, 'Lärarrum'],
#  [81.4, 21.5, 'Klassrum'],
#  [84.4, 23.1, 'Lärarrum'],
#  [75.5, 20.7, 'Lärarrum'],
#  [78.4, 19.1, 'Lärarrum'],
#  [73.5, 15.8, 'Klassrum'],
#  [85.4, 19.5, 'Klassrum'],
#  [90.4, 24.4, 'Klassrum'],
#  [89.4, 23.5, 'Klassrum'],
#  [80.5, 25.7, 'Lärarrum'],
#  [71.5, 15.8, 'Klassrum'],
#  [89.4, 21.1, 'Lärarrum'],
#  [68.5, 13.7, 'Lärarrum'],
#  [71.5, 19.7, 'Lärarrum'],
#  [79.4, 21.1, 'Lärarrum'],
#  [77.4, 28.1, 'Lärarrum'],
#  [84.4, 16.1, 'Lärarrum'],
#  [90.4, 20.5, 'Klassrum'],
#  [93.4, 19.5, 'Klassrum'],
#  [68.5, 15.7, 'Lärarrum'],
#  [69.5, 24.7, 'Lärarrum'],
#  [86.4, 16.1, 'Lärarrum'],
#  [79.4, 23.5, 'Klassrum'],
#  [71.5, 18.8, 'Klassrum'],
#  [90.4, 25.5, 'Klassrum'],
#  [71.5, 22.8, 'Klassrum'],
#  [70.4, 18.1, 'Lärarrum'],
#  [90.4, 18.4, 'Klassrum'],
#  [92.4, 21.4, 'Klassrum'],
#  [87.4, 20.1, 'Lärarrum'],
#  [79.4, 19.1, 'Lärarrum'],
#  [106.4, 16.5, 'Klassrum'],
#  [85.4, 25.5, 'Klassrum'],
#  [65.5, 27.7, 'Lärarrum'],
#  [78.4, 23.4, 'Klassrum'],
#  [102.4, 14.399999999999999, 'Klassrum'],
#  [74.4, 14.100000000000001, 'Lärarrum'],
#  [82.4, 21.5, 'Klassrum'],
#  [92.4, 23.5, 'Klassrum'],
#  [89.4, 25.4, 'Klassrum'],
#  [74.5, 21.8, 'Klassrum'],
#  [63.4, 25.1, 'Lärarrum'],
#  [84.4, 20.4, 'Klassrum'],
#  [73.5, 15.7, 'Lärarrum'],
#  [103.4, 14.5, 'Klassrum'],
#  [72.5, 18.8, 'Klassrum'],
#  [62.5, 18.7, 'Lärarrum'],
#  [75.4, 14.100000000000001, 'Lärarrum'],
#  [76.5, 24.7, 'Lärarrum'],
#  [74.5, 18.7, 'Lärarrum'],
#  [88.4, 16.1, 'Lärarrum'],
#  [100.4, 17.5, 'Klassrum'],
#  [83.4, 18.5, 'Klassrum'],
#  [97.4, 21.5, 'Klassrum'],
#  [78.4, 19.4, 'Klassrum'],
#  [82.4, 22.5, 'Klassrum'],
#  [98.4, 22.4, 'Klassrum'],
#  [69.5, 24.8, 'Klassrum'],
#  [77.4, 22.1, 'Lärarrum'],
#  [95.4, 25.4, 'Klassrum'],
#  [60.4, 13.4, 'Kylrum'],
#  [84.4, 21.1, 'Lärarrum'],
#  [86.4, 22.5, 'Klassrum'],
#  [92.4, 20.5, 'Klassrum'],
#  [74.5, 17.7, 'Lärarrum'],
#  [89.4, 22.5, 'Klassrum'],
#  [95.4, 24.4, 'Klassrum'],
#  [108.4, 29.5, 'Klassrum'],
#  [75.5, 17.8, 'Klassrum'],
#  [67.5, 19.7, 'Lärarrum'],
#  [86.4, 20.5, 'Klassrum'],
#  [97.4, 27.5, 'Klassrum'],
#  [61.4, 19.1, 'Lärarrum'],
#  [86.4, 26.5, 'Klassrum'],
#  [85.4, 22.1, 'Lärarrum'],
#  [89.4, 20.5, 'Klassrum'],
#  [62.5, 17.8, 'Klassrum'],
#  [79.4, 15.100000000000001, 'Lärarrum'],
#  [60.4, 12.4, 'Kylrum'],
#  [73.5, 17.8, 'Klassrum'],
#  [76.4, 22.1, 'Lärarrum'],
#  [87.4, 25.4, 'Klassrum'],
#  [76.4, 20.1, 'Lärarrum'],
#  [64.5, 15.8, 'Klassrum'],
#  [88.4, 22.4, 'Klassrum'],
#  [72.5, 22.8, 'Klassrum'],
#  [74.4, 12.100000000000001, 'Lärarrum'],
#  [75.5, 19.7, 'Lärarrum'],
#  [67.5, 24.7, 'Lärarrum'],
#  [77.4, 20.1, 'Lärarrum'],
#  [79.4, 19.5, 'Klassrum'],
#  [92.4, 22.5, 'Klassrum'],
#  [95.4, 29.4, 'Klassrum'],
#  [94.4, 26.4, 'Klassrum'],
#  [77.5, 18.8, 'Klassrum'],
#  [73.5, 18.8, 'Klassrum'],
#  [71.4, 19.1, 'Lärarrum'],
#  [68.5, 21.8, 'Klassrum'],
#  [87.4, 14.5, 'Klassrum'],
#  [63.5, 22.7, 'Lärarrum'],
#  [79.4, 11.100000000000001, 'Lärarrum'],
#  [66.5, 16.7, 'Lärarrum'],
#  [94.4, 20.4, 'Klassrum'],
#  [82.4, 25.4, 'Klassrum'],
#  [83.4, 17.5, 'Klassrum'],
#  [82.4, 20.1, 'Lärarrum'],
#  [82.4, 21.5, 'Klassrum'],
#  [79.5, 20.8, 'Klassrum'],
#  [80.4, 24.1, 'Lärarrum'],
#  [91.4, 21.5, 'Klassrum'],
#  [85.4, 16.5, 'Klassrum'],
#  [77.5, 28.7, 'Lärarrum'],
#  [67.5, 21.8, 'Klassrum'],
#  [71.5, 19.7, 'Lärarrum'],
#  [87.4, 19.1, 'Lärarrum'],
#  [92.4, 15.100000000000001, 'Lärarrum'],
#  [88.4, 21.4, 'Klassrum'],
#  [75.5, 18.7, 'Lärarrum'],
#  [72.5, 18.8, 'Klassrum'],
#  [73.5, 23.7, 'Lärarrum'],
#  [93.4, 28.4, 'Klassrum'],
#  [74.5, 23.7, 'Lärarrum'],
#  [79.5, 21.7, 'Lärarrum'],
#  [72.5, 22.7, 'Lärarrum'],
#  [81.4, 29.4, 'Klassrum'],
#  [71.5, 18.8, 'Klassrum'],
#  [87.4, 13.399999999999999, 'Klassrum'],
#  [90.4, 20.4, 'Klassrum'],
#  [84.4, 21.1, 'Lärarrum'],
#  [87.4, 24.4, 'Klassrum'],
#  [79.4, 26.5, 'Klassrum'],
#  [79.5, 26.8, 'Klassrum'],
#  [81.4, 20.1, 'Lärarrum'],
#  [84.4, 18.1, 'Lärarrum'],
#  [67.5, 21.8, 'Klassrum'],
#  [76.5, 21.7, 'Lärarrum'],
#  [70.5, 20.7, 'Lärarrum'],
#  [81.5, 15.8, 'Klassrum'],
#  [73.5, 17.8, 'Klassrum'],
#  [95.4, 23.4, 'Klassrum'],
#  [80.4, 23.5, 'Klassrum'],
#  [69.5, 16.8, 'Klassrum'],
#  [70.5, 17.8, 'Klassrum'],
#  [76.4, 19.4, 'Klassrum'],
#  [105.4, 20.5, 'Klassrum'],
#  [76.5, 19.7, 'Lärarrum'],
#  [89.4, 25.4, 'Klassrum'],
#  [88.4, 20.5, 'Klassrum'],
#  [89.4, 24.5, 'Klassrum'],
#  [65.5, 22.7, 'Lärarrum'],
#  [100.4, 26.5, 'Klassrum'],
#  [90.4, 19.1, 'Lärarrum'],
#  [67.5, 19.7, 'Lärarrum'],
#  [85.4, 14.100000000000001, 'Lärarrum'],
#  [78.4, 10.100000000000001, 'Lärarrum'],
#  [101.4, 17.5, 'Klassrum'],
#  [63.4, 22.1, 'Lärarrum'],
#  [96.4, 15.5, 'Klassrum'],
#  [74.4, 18.5, 'Klassrum'],
#  [64.5, 22.8, 'Klassrum'],
#  [96.4, 19.5, 'Klassrum'],
#  [76.5, 19.7, 'Lärarrum'],
#  [87.4, 17.1, 'Lärarrum'],
#  [76.5, 19.7, 'Lärarrum'],
#  [79.4, 6.100000000000001, 'Lärarrum'],
#  [79.5, 21.8, 'Klassrum'],
#  [94.4, 21.5, 'Klassrum'],
#  [69.5, 26.7, 'Lärarrum'],
#  [66.5, 23.7, 'Lärarrum'],
#  [89.4, 17.1, 'Lärarrum'],
#  [72.5, 18.8, 'Klassrum'],
#  [96.4, 25.5, 'Klassrum'],
#  [76.5, 20.7, 'Lärarrum'],
#  [87.4, 24.5, 'Klassrum'],
#  [69.5, 18.7, 'Lärarrum'],
#  [83.4, 21.1, 'Lärarrum'],
#  [83.4, 20.5, 'Klassrum'],
#  [83.4, 18.1, 'Lärarrum'],
#  [93.4, 23.5, 'Klassrum'],
#  [89.4, 28.5, 'Klassrum'],
#  [92.4, 21.5, 'Klassrum'],
#  [87.4, 25.1, 'Lärarrum'],
#  [73.4, 21.1, 'Lärarrum'],
#  [76.5, 22.8, 'Klassrum'],
#  [62.5, 21.7, 'Lärarrum'],
#  [64.5, 19.8, 'Klassrum'],
#  [63.4, 9.4, 'Kylrum'],
#  [89.4, 26.1, 'Lärarrum'],
#  [71.5, 17.8, 'Klassrum'],
#  [96.4, 21.5, 'Klassrum'],
#  [83.4, 19.5, 'Klassrum'],
#  [77.4, 18.1, 'Lärarrum'],
#  [84.4, 13.100000000000001, 'Lärarrum'],
#  [79.4, 19.1, 'Lärarrum'],
#  [87.4, 19.5, 'Klassrum'],
#  [85.4, 24.4, 'Klassrum'],
#  [92.4, 25.4, 'Klassrum'],
#  [61.4, 23.1, 'Lärarrum'],
#  [73.5, 14.8, 'Klassrum'],
#  [84.4, 23.1, 'Lärarrum'],
#  [89.4, 22.1, 'Lärarrum'],
#  [80.5, 17.8, 'Klassrum'],
#  [93.4, 19.4, 'Klassrum'],
#  [77.5, 28.8, 'Klassrum'],
#  [88.4, 21.4, 'Klassrum'],
#  [83.4, 22.4, 'Klassrum'],
#  [97.4, 28.4, 'Klassrum'],
#  [81.4, 21.5, 'Klassrum'],
#  [104.4, 21.4, 'Klassrum'],
#  [91.4, 25.5, 'Klassrum'],
#  [62.5, 18.8, 'Klassrum'],
#  [73.4, 15.5, 'Klassrum'],
#  [89.4, 25.1, 'Lärarrum'],
#  [80.5, 17.8, 'Klassrum'],
#  [83.4, 20.1, 'Lärarrum'],
#  [83.4, 24.1, 'Lärarrum'],
#  [65.5, 20.8, 'Klassrum'],
#  [83.4, 24.5, 'Klassrum'],
#  [60.4, 13.4, 'Kylrum'],
#  [68.5, 21.8, 'Klassrum'],
#  [87.4, 24.1, 'Lärarrum'],
#  [91.4, 17.5, 'Klassrum'],
#  [87.4, 27.4, 'Klassrum'],
#  [72.5, 13.8, 'Klassrum'],
#  [77.4, 19.1, 'Lärarrum'],
#  [68.5, 16.8, 'Klassrum'],
#  [84.4, 16.4, 'Klassrum'],
#  [93.4, 19.1, 'Lärarrum'],
#  [84.4, 24.1, 'Lärarrum'],
#  [97.4, 15.5, 'Klassrum'],
#  [62.5, 16.7, 'Lärarrum'],
#  [75.5, 21.7, 'Lärarrum'],
#  [77.4, 15.100000000000001, 'Lärarrum'],
#  [69.5, 20.7, 'Lärarrum'],
#  [96.4, 18.5, 'Klassrum'],
#  [110.4, 28.5, 'Klassrum'],
#  [76.4, 17.1, 'Lärarrum'],
#  [74.4, 20.1, 'Lärarrum'],
#  [81.4, 17.1, 'Lärarrum'],
#  [82.4, 21.4, 'Klassrum'],
#  [60.5, 15.8, 'Klassrum'],
#  [93.4, 23.1, 'Lärarrum'],
#  [86.4, 19.4, 'Klassrum'],
#  [74.5, 24.8, 'Klassrum'],
#  [92.4, 19.1, 'Lärarrum'],
#  [73.5, 20.8, 'Klassrum'],
#  [84.4, 24.1, 'Lärarrum'],
#  [74.4, 14.5, 'Klassrum'],
#  [63.5, 21.7, 'Lärarrum'],
#  [90.4, 28.4, 'Klassrum'],
#  [74.5, 21.7, 'Lärarrum'],
#  [79.5, 20.8, 'Klassrum'],
#  [72.4, 20.1, 'Lärarrum'],
#  [79.4, 20.1, 'Lärarrum'],
#  [71.5, 22.7, 'Lärarrum'],
#  [65.5, 22.7, 'Lärarrum'],
#  [83.4, 18.1, 'Lärarrum'],
#  [83.4, 11.100000000000001, 'Lärarrum'],
#  [63.5, 24.7, 'Lärarrum'],
#  [77.5, 21.7, 'Lärarrum'],
#  [77.4, 16.1, 'Lärarrum'],
#  [72.5, 27.7, 'Lärarrum'],
#  [71.4, 20.1, 'Lärarrum'],
#  [63.4, 22.1, 'Lärarrum'],
#  [83.4, 21.1, 'Lärarrum'],
#  [78.4, 13.100000000000001, 'Lärarrum'],
#  [75.4, 21.1, 'Lärarrum'],
#  [89.4, 22.1, 'Lärarrum'],
#  [88.4, 20.4, 'Klassrum'],
#  [90.4, 23.1, 'Lärarrum'],
#  [86.4, 21.5, 'Klassrum'],
#  [92.4, 21.5, 'Klassrum'],
#  [78.4, 21.1, 'Lärarrum'],
#  [74.5, 23.7, 'Lärarrum'],
#  [94.4, 24.4, 'Klassrum'],
#  [106.4, 16.5, 'Klassrum'],
#  [89.4, 18.5, 'Klassrum'],
#  [94.4, 18.1, 'Lärarrum'],
#  [77.4, 10.100000000000001, 'Lärarrum'],
#  [63.5, 20.8, 'Klassrum'],
#  [81.4, 16.1, 'Lärarrum'],
#  [80.4, 22.1, 'Lärarrum'],
#  [83.4, 26.5, 'Klassrum'],
#  [97.4, 23.5, 'Klassrum'],
#  [109.4, 19.5, 'Klassrum'],
#  [68.5, 23.7, 'Lärarrum'],
#  [81.4, 20.1, 'Lärarrum'],
#  [62.5, 19.8, 'Klassrum'],
#  [82.4, 22.4, 'Klassrum'],
#  [76.5, 17.7, 'Lärarrum'],
#  [98.4, 16.5, 'Klassrum'],
#  [81.4, 15.100000000000001, 'Lärarrum'],
#  [78.5, 24.8, 'Klassrum'],
#  [90.4, 18.5, 'Klassrum'],
#  [85.4, 23.5, 'Klassrum'],
#  [97.4, 12.5, 'Klassrum'],
#  [72.5, 17.7, 'Lärarrum'],
#  [62.4, 25.1, 'Lärarrum'],
#  [83.4, 24.5, 'Klassrum'],
#  [82.4, 23.4, 'Klassrum'],
#  [104.4, 15.5, 'Klassrum'],
#  [69.5, 17.8, 'Klassrum'],
#  [88.4, 18.1, 'Lärarrum'],
#  [88.4, 18.5, 'Klassrum'],
#  [83.4, 20.4, 'Klassrum'],
#  [93.4, 29.4, 'Klassrum'],
#  [91.4, 21.5, 'Klassrum'],
#  [81.4, 19.1, 'Lärarrum'],
#  [107.4, 20.5, 'Klassrum'],
#  [76.5, 21.7, 'Lärarrum'],
#  [91.4, 22.4, 'Klassrum'],
#  [80.4, 15.100000000000001, 'Lärarrum'],
#  [61.4, 16.4, 'Kylrum'],
#  [77.5, 27.7, 'Lärarrum'],
#  [88.4, 21.1, 'Lärarrum'],
#  [97.4, 29.5, 'Klassrum'],
#  [75.5, 24.7, 'Lärarrum'],
#  [100.4, 21.4, 'Klassrum'],
#  [101.4, 22.5, 'Klassrum'],
#  [71.5, 21.7, 'Lärarrum'],
#  [97.4, 13.100000000000001, 'Lärarrum'],
#  [60.4, 11.4, 'Kylrum'],
#  [73.4, 19.1, 'Lärarrum'],
#  [92.4, 21.4, 'Klassrum'],
#  [64.5, 19.8, 'Klassrum'],
#  [69.5, 14.7, 'Lärarrum'],
#  [73.4, 19.1, 'Lärarrum'],
#  [93.4, 21.5, 'Klassrum'],
#  [79.4, 20.1, 'Lärarrum'],
#  [89.4, 19.1, 'Lärarrum'],
#  [84.5, 18.8, 'Klassrum'],
#  [77.5, 17.7, 'Lärarrum'],
#  [88.4, 25.5, 'Klassrum'],
#  [86.4, 27.1, 'Lärarrum'],
#  [87.4, 15.100000000000001, 'Lärarrum'],
#  [102.4, 20.4, 'Klassrum'],
#  [84.4, 16.1, 'Lärarrum'],
#  [100.4, 15.5, 'Klassrum'],
#  [73.4, 20.1, 'Lärarrum'],
#  [92.4, 18.5, 'Klassrum'],
#  [81.4, 16.5, 'Klassrum'],
#  [93.4, 24.5, 'Klassrum'],
#  [81.5, 20.7, 'Lärarrum'],
#  [78.5, 20.8, 'Klassrum'],
#  [85.4, 13.5, 'Klassrum'],
#  [93.4, 19.5, 'Klassrum'],
#  [80.4, 27.4, 'Klassrum'],
#  [89.4, 17.5, 'Klassrum'],
#  [87.4, 20.4, 'Klassrum'],
#  [80.4, 24.4, 'Klassrum'],
#  [88.4, 19.5, 'Klassrum'],
#  [92.4, 20.4, 'Klassrum'],
#  [104.4, 15.399999999999999, 'Klassrum'],
#  [84.4, 23.4, 'Klassrum'],
#  [89.4, 10.100000000000001, 'Lärarrum'],
#  [61.4, 17.1, 'Lärarrum'],
#  [83.4, 17.5, 'Klassrum'],
#  [77.4, 20.1, 'Lärarrum'],
#  [64.5, 20.8, 'Klassrum'],
#  [88.4, 18.1, 'Lärarrum'],
#  [79.4, 25.1, 'Lärarrum'],
#  [67.5, 23.7, 'Lärarrum'],
#  [91.4, 26.4, 'Klassrum'],
#  [76.5, 24.8, 'Klassrum'],
#  [98.4, 26.4, 'Klassrum'],
#  [67.5, 18.7, 'Lärarrum'],
#  [74.5, 17.8, 'Klassrum'],
#  [78.4, 11.100000000000001, 'Lärarrum'],
#  [72.5, 19.7, 'Lärarrum'],
#  [88.4, 14.100000000000001, 'Lärarrum'],
#  [82.4, 23.1, 'Lärarrum'],
#  [79.4, 22.1, 'Lärarrum'],
#  [84.4, 19.1, 'Lärarrum'],
#  [86.4, 22.5, 'Klassrum'],
#  [71.5, 19.7, 'Lärarrum'],
#  [85.4, 22.1, 'Lärarrum'],
#  [90.4, 25.1, 'Lärarrum'],
#  [68.4, 23.1, 'Lärarrum'],
#  [80.5, 23.7, 'Lärarrum'],
#  [64.4, 11.4, 'Kylrum'],
#  [69.5, 18.8, 'Klassrum'],
#  [82.4, 22.5, 'Klassrum'],
#  [85.4, 17.5, 'Klassrum'],
#  [68.5, 18.8, 'Klassrum'],
#  [81.4, 22.5, 'Klassrum'],
#  [94.4, 26.4, 'Klassrum'],
#  [88.4, 17.1, 'Lärarrum'],
#  [86.4, 19.1, 'Lärarrum'],
#  [99.4, 18.5, 'Klassrum'],
#  [83.4, 20.5, 'Klassrum'],
#  [82.4, 18.1, 'Lärarrum'],
#  [88.4, 24.1, 'Lärarrum'],
#  [97.4, 27.4, 'Klassrum'],
#  [99.4, 20.5, 'Klassrum'],
#  [72.5, 23.7, 'Lärarrum'],
#  [67.5, 19.7, 'Lärarrum'],
#  [71.5, 13.7, 'Lärarrum'],
#  [84.4, 16.5, 'Klassrum'],
#  [95.4, 22.5, 'Klassrum'],
#  [78.4, 28.4, 'Klassrum'],
#  [102.4, 19.4, 'Klassrum'],
#  [84.4, 20.4, 'Klassrum'],
#  [94.4, 20.4, 'Klassrum'],
#  [82.4, 24.4, 'Klassrum'],
#  [100.4, 17.5, 'Klassrum'],
#  [79.4, 18.1, 'Lärarrum'],
#  [61.4, 15.4, 'Kylrum'],
#  [81.4, 22.5, 'Klassrum'],
#  [86.4, 17.1, 'Lärarrum'],
#  [86.4, 24.4, 'Klassrum'],
#  [88.4, 20.5, 'Klassrum'],
#  [91.4, 26.5, 'Klassrum'],
#  [83.4, 18.4, 'Klassrum'],
#  [81.5, 22.7, 'Lärarrum'],
#  [81.5, 19.7, 'Lärarrum'],
#  [60.5, 20.8, 'Klassrum'],
#  [86.4, 15.5, 'Klassrum'],
#  [81.4, 9.100000000000001, 'Lärarrum'],
#  [77.4, 18.1, 'Lärarrum'],
#  [85.4, 21.4, 'Klassrum'],
#  [75.4, 16.1, 'Lärarrum'],
#  [89.4, 24.4, 'Klassrum'],
#  [85.4, 19.1, 'Lärarrum'],
#  [85.4, 14.5, 'Klassrum'],
#  [88.4, 23.1, 'Lärarrum'],
#  [68.5, 20.7, 'Lärarrum'],
#  [63.5, 24.7, 'Lärarrum'],
#  [70.5, 15.7, 'Lärarrum'],
#  [82.4, 19.5, 'Klassrum'],
#  [79.5, 14.7, 'Lärarrum'],
#  [70.5, 19.7, 'Lärarrum'],
#  [110.4, 21.5, 'Klassrum'],
#  [92.4, 21.1, 'Lärarrum'],
#  [76.4, 22.1, 'Lärarrum'],
#  [79.4, 21.1, 'Lärarrum'],
#  [91.4, 26.4, 'Klassrum'],
#  [69.5, 22.7, 'Lärarrum'],
#  [85.4, 24.1, 'Lärarrum'],
#  [69.5, 20.8, 'Klassrum'],
#  [92.4, 17.4, 'Klassrum'],
#  [86.4, 28.4, 'Klassrum'],
#  [83.4, 23.4, 'Klassrum'],
#  [70.5, 20.7, 'Lärarrum'],
#  [91.4, 21.4, 'Klassrum'],
#  [63.4, 7.4, 'Kylrum'],
#  [73.5, 13.8, 'Klassrum'],
#  [76.4, 14.100000000000001, 'Lärarrum'],
#  [81.4, 29.5, 'Klassrum'],
#  [65.5, 16.7, 'Lärarrum'],
#  [87.4, 7.100000000000001, 'Lärarrum'],
#  [83.4, 21.1, 'Lärarrum'],
#  ...]

# %%
# This will contain everything else.
false_rows
#######
# Out:
# [[54.4, 14.4, 'Kylrum'],
#  [45.4, 12.4, 'Kylrum'],
#  [57.4, 18.1, 'Lärarrum'],
#  [22.4, 8.6, 'Kylrum'],
#  [24.4, 11.24, 'Kylrum'],
#  [23.4, 5.6, 'Kylrum'],
#  [18.4, 4.6, 'Kylrum'],
#  [26.4, 11.6, 'Kylrum'],
#  [41.4, 11.4, 'Kylrum'],
#  [20.4, 3.5999999999999996, 'Kylrum'],
#  [16.4, 5.6, 'Kylrum'],
#  [43.4, 13.4, 'Kylrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [43.4, 12.4, 'Kylrum'],
#  [53.4, 13.4, 'Kylrum'],
#  [18.4, 0.5999999999999996, 'Kylrum'],
#  [16.4, 6.6, 'Kylrum'],
#  [17.4, -2.4000000000000004, 'Kylrum'],
#  [44.4, 13.4, 'Kylrum'],
#  [38.4, 13.4, 'Kylrum'],
#  [13.399999999999999, 6.6, 'Kylrum'],
#  [19.4, 11.6, 'Kylrum'],
#  [19.4, -1.4000000000000004, 'Kylrum'],
#  [41.4, 9.4, 'Kylrum'],
#  [22.4, 5.6, 'Kylrum'],
#  [38.4, 11.4, 'Kylrum'],
#  [19.4, 1.5999999999999996, 'Kylrum'],
#  [51.4, 13.4, 'Kylrum'],
#  [16.4, 13.6, 'Kylrum'],
#  [27.4, 9.6, 'Kylrum'],
#  [23.4, 0.5999999999999996, 'Kylrum'],
#  [39.4, 13.4, 'Kylrum'],
#  [47.4, 10.4, 'Kylrum'],
#  [17.4, 6.6, 'Kylrum'],
#  [15.399999999999999, 1.5999999999999996, 'Kylrum'],
#  [21.4, -1.4000000000000004, 'Kylrum'],
#  [53.4, 11.4, 'Kylrum'],
#  [42.4, 13.4, 'Kylrum'],
#  [20.4, -0.40000000000000036, 'Kylrum'],
#  [18.4, 8.6, 'Kylrum'],
#  [20.4, 1.5999999999999996, 'Kylrum'],
#  [18.4, 3.5999999999999996, 'Kylrum'],
#  [36.4, 11.4, 'Kylrum'],
#  [38.4, 13.4, 'Kylrum'],
#  [24.4, 2.5999999999999996, 'Kylrum'],
#  [44.4, 12.4, 'Kylrum'],
#  [24.4, 9.6, 'Kylrum'],
#  [15.399999999999999, 5.6, 'Kylrum'],
#  [14.399999999999999, -2.4000000000000004, 'Kylrum'],
#  [55.4, 21.1, 'Lärarrum'],
#  [43.4, 13.4, 'Kylrum'],
#  [27.4, 10.6, 'Kylrum'],
#  [56.4, 13.4, 'Kylrum'],
#  [19.4, 6.6, 'Kylrum'],
#  [47.4, 11.4, 'Kylrum'],
#  [46.4, 10.4, 'Kylrum'],
#  [23.4, 2.5999999999999996, 'Kylrum'],
#  [18.4, 2.5999999999999996, 'Kylrum'],
#  [41.4, 13.4, 'Kylrum'],
#  [14.399999999999999, -1.4000000000000004, 'Kylrum'],
#  [44.4, 10.4, 'Kylrum'],
#  [13.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [51.4, 12.4, 'Kylrum'],
#  [20.4, 7.6, 'Kylrum'],
#  [39.4, 11.4, 'Kylrum'],
#  [20.4, 6.6, 'Kylrum'],
#  [54.4, 15.4, 'Kylrum'],
#  [36.4, 11.4, 'Kylrum'],
#  [51.4, 14.4, 'Kylrum'],
#  [56.4, 13.4, 'Kylrum'],
#  [38.4, 14.4, 'Kylrum'],
#  [59.4, 19.1, 'Lärarrum'],
#  [55.4, 9.4, 'Kylrum'],
#  [26.4, 2.5999999999999996, 'Kylrum'],
#  [36.4, 11.4, 'Kylrum'],
#  [23.4, 9.6, 'Kylrum'],
#  [16.4, 4.6, 'Kylrum'],
#  [9.399999999999999, 4.6, 'Kylrum'],
#  [12.399999999999999, 7.6, 'Kylrum'],
#  [58.4, 13.4, 'Kylrum'],
#  [56.4, 12.4, 'Kylrum'],
#  [59.4, 19.1, 'Lärarrum'],
#  [24.4, -2.4000000000000004, 'Kylrum'],
#  [18.4, 6.6, 'Kylrum'],
#  [25.4, 9.6, 'Kylrum'],
#  [26.4, 11.6, 'Kylrum'],
#  [33.4, 11.4, 'Kylrum'],
#  [21.4, 7.6, 'Kylrum'],
#  [40.4, 14.4, 'Kylrum'],
#  [16.4, 4.6, 'Kylrum'],
#  [25.4, 10.6, 'Kylrum'],
#  [14.399999999999999, 4.6, 'Kylrum'],
#  [16.4, -2.4000000000000004, 'Kylrum'],
#  [19.4, -1.4000000000000004, 'Kylrum'],
#  [54.4, 13.4, 'Kylrum'],
#  [20.4, 9.6, 'Kylrum'],
#  [37.4, 9.4, 'Kylrum'],
#  [23.4, 10.6, 'Kylrum'],
#  [57.4, 13.4, 'Kylrum'],
#  [11.399999999999999, 4.6, 'Kylrum'],
#  [11.399999999999999, 2.5999999999999996, 'Kylrum'],
#  [18.4, -2.4000000000000004, 'Kylrum'],
#  [16.4, -0.40000000000000036, 'Kylrum'],
#  [25.4, 8.6, 'Kylrum'],
#  [23.4, 0.5999999999999996, 'Kylrum'],
#  [56.4, 14.4, 'Kylrum'],
#  [53.4, 11.4, 'Kylrum'],
#  [59.5, 21.7, 'Lärarrum'],
#  [19.4, 5.6, 'Kylrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [15.399999999999999, 7.6, 'Kylrum'],
#  [52.4, 11.4, 'Kylrum'],
#  [53.4, 19.1, 'Lärarrum'],
#  [50.4, 8.4, 'Kylrum'],
#  [45.4, 10.4, 'Kylrum'],
#  [18.4, 8.6, 'Kylrum'],
#  [24.4, 10.6, 'Kylrum'],
#  [13.399999999999999, 0.5999999999999996, 'Kylrum'],
#  [48.4, 11.4, 'Kylrum'],
#  [13.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [37.4, 11.4, 'Kylrum'],
#  [37.4, 13.4, 'Kylrum'],
#  [46.4, 12.4, 'Kylrum'],
#  [46.4, 10.4, 'Kylrum'],
#  [22.4, -0.40000000000000036, 'Kylrum'],
#  [14.399999999999999, -3.4000000000000004, 'Kylrum'],
#  [24.4, 2.5999999999999996, 'Kylrum'],
#  [38.4, 12.4, 'Kylrum'],
#  [27.4, 10.6, 'Kylrum'],
#  [37.4, 11.4, 'Kylrum'],
#  [13.399999999999999, 0.5999999999999996, 'Kylrum'],
#  [20.4, 5.6, 'Kylrum'],
#  [40.4, 13.4, 'Kylrum'],
#  [49.4, 8.4, 'Kylrum'],
#  [15.399999999999999, 0.5999999999999996, 'Kylrum'],
#  [21.4, -3.4000000000000004, 'Kylrum'],
#  [17.4, -5.4, 'Kylrum'],
#  [26.4, 7.6, 'Kylrum'],
#  [17.4, 14.6, 'Kylrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [14.399999999999999, -6.4, 'Kylrum'],
#  [43.4, 13.4, 'Kylrum'],
#  [54.4, 16.4, 'Kylrum'],
#  [13.399999999999999, 5.6, 'Kylrum'],
#  [34.4, 15.4, 'Kylrum'],
#  [15.399999999999999, 1.5999999999999996, 'Kylrum'],
#  [42.4, 13.4, 'Kylrum'],
#  [22.4, 0.5999999999999996, 'Kylrum'],
#  [20.4, 5.6, 'Kylrum'],
#  [59.4, 18.1, 'Lärarrum'],
#  [24.4, 5.6, 'Kylrum'],
#  [14.399999999999999, 16.6, 'Kylrum'],
#  [17.4, 4.6, 'Kylrum'],
#  [59.4, 12.4, 'Kylrum'],
#  [17.4, -1.4000000000000004, 'Kylrum'],
#  [18.4, -0.40000000000000036, 'Kylrum'],
#  [40.4, 11.4, 'Kylrum'],
#  [43.4, 10.4, 'Kylrum'],
#  [42.4, 11.4, 'Kylrum'],
#  [46.4, 12.4, 'Kylrum'],
#  [52.4, 15.4, 'Kylrum'],
#  [21.4, -1.4000000000000004, 'Kylrum'],
#  [17.4, 4.6, 'Kylrum'],
#  [25.4, 6.6, 'Kylrum'],
#  [36.4, 13.4, 'Kylrum'],
#  [41.4, 9.4, 'Kylrum'],
#  [14.399999999999999, -3.4000000000000004, 'Kylrum'],
#  [25.4, -3.4000000000000004, 'Kylrum'],
#  [29.4, 7.6, 'Kylrum'],
#  [37.4, 9.4, 'Kylrum'],
#  [15.399999999999999, 6.6, 'Kylrum'],
#  [19.4, -2.4000000000000004, 'Kylrum'],
#  [25.4, 10.6, 'Kylrum'],
#  [17.4, 0.5999999999999996, 'Kylrum'],
#  [31.4, 13.6, 'Kylrum'],
#  [39.4, 10.4, 'Kylrum'],
#  [51.4, 13.399999999999999, 'Kylrum'],
#  [28.4, 8.6, 'Kylrum'],
#  [17.4, 7.6, 'Kylrum'],
#  [36.4, 10.4, 'Kylrum'],
#  [24.4, 0.5999999999999996, 'Kylrum'],
#  [24.4, 7.6, 'Kylrum'],
#  [28.4, 1.5999999999999996, 'Kylrum'],
#  [55.4, 15.4, 'Kylrum'],
#  [49.4, 12.4, 'Kylrum'],
#  [57.4, 15.4, 'Kylrum'],
#  [30.4, 12.6, 'Kylrum'],
#  [37.4, 11.4, 'Kylrum'],
#  [11.399999999999999, -8.4, 'Kylrum'],
#  [40.4, 11.4, 'Kylrum'],
#  [51.4, 17.4, 'Kylrum'],
#  [20.4, 4.6, 'Kylrum'],
#  [33.4, 13.4, 'Kylrum'],
#  [38.4, 14.4, 'Kylrum'],
#  [16.4, 1.5999999999999996, 'Kylrum'],
#  [18.4, 7.6, 'Kylrum'],
#  [14.399999999999999, -3.4000000000000004, 'Kylrum'],
#  [45.4, 14.4, 'Kylrum'],
#  [11.399999999999999, -9.4, 'Kylrum'],
#  [44.4, 11.4, 'Kylrum'],
#  [53.4, 14.4, 'Kylrum'],
#  [15.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [51.4, 15.4, 'Kylrum'],
#  [49.4, 12.4, 'Kylrum'],
#  [35.4, 13.4, 'Kylrum'],
#  [39.4, 10.4, 'Kylrum'],
#  [13.399999999999999, 4.6, 'Kylrum'],
#  [44.4, 10.4, 'Kylrum'],
#  [17.4, 0.5999999999999996, 'Kylrum'],
#  [29.4, 10.6, 'Kylrum'],
#  [36.4, 15.4, 'Kylrum'],
#  [41.4, 12.4, 'Kylrum'],
#  [17.4, 13.600000000000001, 'Kylrum'],
#  [35.4, 14.6, 'Kylrum'],
#  [21.4, 1.5999999999999996, 'Kylrum'],
#  [59.4, 12.4, 'Kylrum'],
#  [44.4, 8.4, 'Kylrum'],
#  [21.4, 8.6, 'Kylrum'],
#  [17.4, 3.5999999999999996, 'Kylrum'],
#  [59.4, 15.4, 'Kylrum'],
#  [45.4, 14.4, 'Kylrum'],
#  [57.4, 13.4, 'Kylrum'],
#  [25.4, 3.5999999999999996, 'Kylrum'],
#  [39.4, 13.4, 'Kylrum'],
#  [36.4, 12.4, 'Kylrum'],
#  [18.4, 0.5999999999999996, 'Kylrum'],
#  [58.4, 23.1, 'Lärarrum'],
#  [48.4, 12.4, 'Kylrum'],
#  [42.4, 11.4, 'Kylrum'],
#  [23.4, 8.6, 'Kylrum'],
#  [49.4, 11.4, 'Kylrum'],
#  [18.4, 7.6, 'Kylrum'],
#  [46.4, 8.4, 'Kylrum'],
#  [21.4, 10.6, 'Kylrum'],
#  [15.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [16.4, 5.6, 'Kylrum'],
#  [23.4, 10.6, 'Kylrum'],
#  [28.4, 2.5999999999999996, 'Kylrum'],
#  [23.4, 7.6, 'Kylrum'],
#  [24.4, 12.6, 'Kylrum'],
#  [14.399999999999999, 7.6, 'Kylrum'],
#  [40.4, 14.4, 'Kylrum'],
#  [24.4, -0.40000000000000036, 'Kylrum'],
#  [24.4, 9.6, 'Kylrum'],
#  [15.399999999999999, 6.6, 'Kylrum'],
#  [14.399999999999999, -2.4000000000000004, 'Kylrum'],
#  [20.4, 10.6, 'Kylrum'],
#  [37.4, 17.4, 'Kylrum'],
#  [32.4, 8.6, 'Kylrum'],
#  [19.4, 0.5999999999999996, 'Kylrum'],
#  [20.4, 6.6, 'Kylrum'],
#  [46.4, 11.4, 'Kylrum'],
#  [33.4, 15.4, 'Kylrum'],
#  [41.4, 9.4, 'Kylrum'],
#  [44.4, 12.4, 'Kylrum'],
#  [24.4, 7.6, 'Kylrum'],
#  [20.4, 0.5999999999999996, 'Kylrum'],
#  [23.4, -4.4, 'Kylrum'],
#  [37.4, 10.4, 'Kylrum'],
#  [12.399999999999999, 0.5999999999999996, 'Kylrum'],
#  [14.399999999999999, 6.6, 'Kylrum'],
#  [58.4, 9.4, 'Kylrum'],
#  [51.4, 15.4, 'Kylrum'],
#  [21.4, 2.5999999999999996, 'Kylrum'],
#  [18.4, 5.6, 'Kylrum'],
#  [26.4, 13.6, 'Kylrum'],
#  [43.4, 13.4, 'Kylrum'],
#  [18.4, 1.5999999999999996, 'Kylrum'],
#  [15.399999999999999, -4.4, 'Kylrum'],
#  [44.4, 9.4, 'Kylrum'],
#  [14.399999999999999, 10.6, 'Kylrum'],
#  [56.4, 14.4, 'Kylrum'],
#  [43.4, 9.4, 'Kylrum'],
#  [24.4, 11.6, 'Kylrum'],
#  [10.399999999999999, -4.4, 'Kylrum'],
#  [30.4, 8.6, 'Kylrum'],
#  [16.4, -2.4000000000000004, 'Kylrum'],
#  [40.4, 14.4, 'Kylrum'],
#  [13.399999999999999, -4.4, 'Kylrum'],
#  [42.4, 9.4, 'Kylrum'],
#  [32.4, 12.4, 'Kylrum'],
#  [10.399999999999999, 5.6, 'Kylrum'],
#  [49.4, 11.4, 'Kylrum'],
#  [21.4, 8.6, 'Kylrum'],
#  [16.4, 2.5999999999999996, 'Kylrum'],
#  [24.4, -3.4000000000000004, 'Kylrum'],
#  [54.4, 15.4, 'Kylrum'],
#  [24.4, 5.6, 'Kylrum'],
#  [39.4, 9.4, 'Kylrum'],
#  [29.4, 10.6, 'Kylrum'],
#  [43.4, 12.4, 'Kylrum'],
#  [18.4, 4.6, 'Kylrum'],
#  [53.4, 14.4, 'Kylrum'],
#  [43.4, 9.4, 'Kylrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [16.4, -7.4, 'Kylrum'],
#  [26.4, 7.6, 'Kylrum'],
#  [31.4, 7.6, 'Kylrum'],
#  [10.399999999999999, -9.4, 'Kylrum'],
#  [45.4, 10.4, 'Kylrum'],
#  [53.4, 14.4, 'Kylrum'],
#  [37.4, 13.4, 'Kylrum'],
#  [28.4, 12.6, 'Kylrum'],
#  [41.4, 14.4, 'Kylrum'],
#  [48.4, 10.4, 'Kylrum'],
#  [25.4, 6.6, 'Kylrum'],
#  [25.4, 9.6, 'Kylrum'],
#  [40.4, 10.4, 'Kylrum'],
#  [12.399999999999999, -1.4000000000000004, 'Kylrum'],
#  [14.399999999999999, 2.5999999999999996, 'Kylrum'],
#  [51.4, 7.4, 'Kylrum'],
#  [24.4, 7.6, 'Kylrum'],
#  [8.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [50.4, 13.4, 'Kylrum'],
#  [28.4, 11.6, 'Kylrum'],
#  [15.399999999999999, 6.6, 'Kylrum'],
#  [15.399999999999999, -1.4000000000000004, 'Kylrum'],
#  [12.399999999999999, -5.4, 'Kylrum'],
#  [58.4, 20.1, 'Lärarrum'],
#  [19.4, 3.5999999999999996, 'Kylrum'],
#  [36.4, 17.4, 'Kylrum'],
#  [57.4, 11.4, 'Kylrum'],
#  [25.4, 7.6, 'Kylrum'],
#  [16.4, -1.4000000000000004, 'Kylrum'],
#  [42.4, 14.4, 'Kylrum'],
#  [37.4, 14.4, 'Kylrum'],
#  [51.4, 17.1, 'Lärarrum'],
#  [14.399999999999999, -7.4, 'Kylrum'],
#  [52.4, 13.4, 'Kylrum'],
#  [27.4, 2.5999999999999996, 'Kylrum'],
#  [19.4, 4.6, 'Kylrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [51.4, 11.4, 'Kylrum'],
#  [54.4, 16.4, 'Kylrum'],
#  [41.4, 11.4, 'Kylrum'],
#  [53.4, 11.4, 'Kylrum'],
#  [54.4, 13.4, 'Kylrum'],
#  [17.4, 4.6, 'Kylrum'],
#  [34.4, 16.4, 'Kylrum'],
#  [42.4, 14.4, 'Kylrum'],
#  [10.399999999999999, 2.5999999999999996, 'Kylrum'],
#  [43.4, 12.4, 'Kylrum'],
#  [19.4, 6.6, 'Kylrum'],
#  [29.4, 14.6, 'Kylrum'],
#  [16.4, -6.4, 'Kylrum'],
#  [24.4, 4.6, 'Kylrum'],
#  [45.4, 15.4, 'Kylrum'],
#  [32.4, 7.4, 'Kylrum'],
#  [27.4, 2.5999999999999996, 'Kylrum'],
#  [56.4, 14.4, 'Kylrum'],
#  [12.399999999999999, -6.4, 'Kylrum'],
#  [15.399999999999999, 4.6, 'Kylrum'],
#  [17.4, 13.6, 'Kylrum'],
#  [42.4, 8.4, 'Kylrum'],
#  [14.399999999999999, 0.5999999999999996, 'Kylrum'],
#  [38.4, 12.4, 'Kylrum'],
#  [53.4, 16.4, 'Kylrum'],
#  [41.4, 10.4, 'Kylrum'],
#  [27.4, 0.5999999999999996, 'Kylrum'],
#  [27.4, 8.6, 'Kylrum'],
#  [21.4, 5.6, 'Kylrum'],
#  [33.4, 15.6, 'Kylrum'],
#  [23.4, 9.6, 'Kylrum'],
#  [30.4, 5.6, 'Kylrum'],
#  [40.4, 13.4, 'Kylrum'],
#  [36.4, 17.4, 'Kylrum'],
#  [51.4, 15.4, 'Kylrum'],
#  [25.4, 2.5999999999999996, 'Kylrum'],
#  [20.4, 7.6, 'Kylrum'],
#  [18.4, 5.6, 'Kylrum'],
#  [19.4, 11.6, 'Kylrum'],
#  [33.4, 15.4, 'Kylrum'],
#  [16.4, 6.6, 'Kylrum'],
#  [34.4, 13.4, 'Kylrum'],
#  [45.4, 12.4, 'Kylrum'],
#  [22.4, 5.6, 'Kylrum'],
#  [39.4, 11.4, 'Kylrum'],
#  [13.399999999999999, -3.4000000000000004, 'Kylrum'],
#  [23.4, 9.6, 'Kylrum'],
#  [30.4, -0.40000000000000036, 'Kylrum'],
#  [18.4, -3.4000000000000004, 'Kylrum'],
#  [42.4, 15.4, 'Kylrum'],
#  [15.399999999999999, -8.4, 'Kylrum'],
#  [54.4, 17.4, 'Kylrum'],
#  [17.4, 5.6, 'Kylrum'],
#  [26.4, 12.6, 'Kylrum'],
#  [16.4, 4.6, 'Kylrum'],
#  [38.4, 16.4, 'Kylrum'],
#  [12.399999999999999, -4.4, 'Kylrum'],
#  [18.4, 8.6, 'Kylrum'],
#  [54.4, 15.399999999999999, 'Kylrum'],
#  [14.399999999999999, 2.5999999999999996, 'Kylrum'],
#  [20.4, 10.6, 'Kylrum'],
#  [18.4, 1.5999999999999996, 'Kylrum'],
#  [17.4, 0.5999999999999996, 'Kylrum'],
#  [26.4, 11.6, 'Kylrum'],
#  [16.4, 7.6, 'Kylrum'],
#  [21.4, 10.6, 'Kylrum'],
#  [20.4, 0.5999999999999996, 'Kylrum'],
#  [35.4, 14.4, 'Kylrum'],
#  [52.4, 16.4, 'Kylrum'],
#  [35.4, 14.4, 'Kylrum'],
#  [24.4, -2.4000000000000004, 'Kylrum'],
#  [17.4, 5.6, 'Kylrum'],
#  [23.4, 11.6, 'Kylrum'],
#  [16.4, -11.4, 'Kylrum'],
#  [22.4, 2.5999999999999996, 'Kylrum'],
#  [52.4, 12.4, 'Kylrum'],
#  [18.4, 8.6, 'Kylrum'],
#  [14.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [18.4, 7.6, 'Kylrum'],
#  [43.4, 14.4, 'Kylrum'],
#  [16.4, -0.40000000000000036, 'Kylrum'],
#  [52.4, 12.4, 'Kylrum'],
#  [20.4, 4.6, 'Kylrum'],
#  [33.4, 12.4, 'Kylrum'],
#  [38.4, 13.4, 'Kylrum'],
#  [16.4, 6.6, 'Kylrum'],
#  [13.399999999999999, -3.4000000000000004, 'Kylrum'],
#  [48.4, 9.4, 'Kylrum'],
#  [16.4, 3.5999999999999996, 'Kylrum'],
#  [37.4, 12.4, 'Kylrum'],
#  [44.4, 9.4, 'Kylrum'],
#  [10.399999999999999, -0.40000000000000036, 'Kylrum'],
#  [48.4, 11.4, 'Kylrum'],
#  [54.4, 18.4, 'Kylrum'],
#  [21.4, -2.4000000000000004, 'Kylrum'],
#  [21.4, -3.4000000000000004, 'Kylrum'],
#  [36.4, 14.4, 'Kylrum'],
#  [25.4, 8.6, 'Kylrum'],
#  [44.4, 8.4, 'Kylrum'],
#  [17.4, 4.6, 'Kylrum'],
#  [25.4, 9.6, 'Kylrum'],
#  [39.4, 10.4, 'Kylrum'],
#  [32.4, 13.4, 'Kylrum'],
#  [57.4, 9.4, 'Kylrum'],
#  [23.4, 3.5999999999999996, 'Kylrum'],
#  [38.4, 15.4, 'Kylrum'],
#  [44.4, 15.4, 'Kylrum'],
#  [14.399999999999999, 12.6, 'Kylrum'],
#  [21.4, 11.6, 'Kylrum'],
#  [36.4, 12.4, 'Kylrum'],
#  [40.4, 15.4, 'Kylrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [30.4, 6.6, 'Kylrum'],
#  [12.399999999999999, 8.6, 'Kylrum'],
#  [23.4, 5.6, 'Kylrum'],
#  [57.4, 11.4, 'Kylrum'],
#  [52.4, 8.4, 'Kylrum'],
#  [54.4, 9.4, 'Kylrum'],
#  [23.4, 3.5999999999999996, 'Kylrum'],
#  [42.4, 14.4, 'Kylrum'],
#  [38.4, 13.4, 'Kylrum'],
#  [19.4, -0.40000000000000036, 'Kylrum'],
#  [34.4, -2.4000000000000004, 'Kylrum'],
#  [56.4, 13.4, 'Kylrum'],
#  [27.4, -0.40000000000000036, 'Kylrum'],
#  [46.4, 14.4, 'Kylrum'],
#  [44.4, 11.4, 'Kylrum'],
#  [13.399999999999999, 15.6, 'Kylrum'],
#  [14.399999999999999, -0.40000000000000036, 'Kylrum'],
#  [22.4, 3.5999999999999996, 'Kylrum'],
#  [20.4, 4.6, 'Kylrum'],
#  [42.4, 13.4, 'Kylrum'],
#  [49.4, 11.4, 'Kylrum'],
#  [18.4, -5.4, 'Kylrum'],
#  [27.4, 7.6, 'Kylrum'],
#  [58.4, 25.1, 'Lärarrum'],
#  [8.399999999999999, -5.4, 'Kylrum'],
#  [35.4, -0.40000000000000036, 'Kylrum'],
#  [48.4, 17.4, 'Kylrum'],
#  [42.4, 14.4, 'Kylrum'],
#  [13.399999999999999, -8.4, 'Kylrum'],
#  [18.4, 7.6, 'Kylrum'],
#  [41.4, 17.4, 'Kylrum'],
#  [15.399999999999999, 4.6, 'Kylrum'],
#  [21.4, 1.5999999999999996, 'Kylrum'],
#  [16.4, 12.6, 'Kylrum'],
#  [56.4, 15.4, 'Kylrum'],
#  [29.4, 5.6, 'Kylrum'],
#  [21.4, 4.6, 'Kylrum'],
#  [10.399999999999999, 0.5999999999999996, 'Kylrum'],
#  [28.4, 2.5999999999999996, 'Kylrum'],
#  [27.4, 13.6, 'Kylrum'],
#  [31.4, 13.6, 'Kylrum'],
#  [11.399999999999999, 1.5999999999999996, 'Kylrum'],
#  [53.4, 17.4, 'Kylrum'],
#  [35.4, 14.4, 'Kylrum'],
#  [17.4, 1.5999999999999996, 'Kylrum'],
#  [27.4, 8.6, 'Kylrum'],
#  [54.4, 15.4, 'Kylrum'],
#  [57.4, 12.4, 'Kylrum'],
#  [32.4, 9.4, 'Kylrum'],
#  [53.4, 13.4, 'Kylrum'],
#  [39.4, 15.399999999999999, 'Kylrum'],
#  [12.399999999999999, -0.40000000000000036, 'Kylrum'],
#  [56.4, 14.4, 'Kylrum'],
#  [59.4, 10.4, 'Kylrum'],
#  [26.4, 2.5999999999999996, 'Kylrum'],
#  [31.4, 12.6, 'Kylrum'],
#  [24.4, 13.6, 'Kylrum'],
#  [31.4, 10.4, 'Kylrum'],
#  [32.4, 11.4, 'Kylrum'],
#  [21.4, 3.5999999999999996, 'Kylrum'],
#  [40.4, 13.4, 'Kylrum'],
#  [20.4, 1.5999999999999996, 'Kylrum'],
#  [39.4, 7.4, 'Kylrum'],
#  [57.4, 12.4, 'Kylrum'],
#  [16.4, 8.6, 'Kylrum'],
#  [16.4, 6.6, 'Kylrum'],
#  [56.4, 15.4, 'Kylrum'],
#  [16.4, 3.5999999999999996, 'Kylrum'],
#  [15.399999999999999, 0.5999999999999996, 'Kylrum'],
#  [23.4, 8.6, 'Kylrum'],
#  [25.4, 4.6, 'Kylrum'],
#  [43.4, 12.4, 'Kylrum'],
#  [31.4, 5.6, 'Kylrum'],
#  [19.4, 8.6, 'Kylrum'],
#  [17.4, 1.5999999999999996, 'Kylrum'],
#  [14.399999999999999, 17.6, 'Kylrum'],
#  [19.4, 4.6, 'Kylrum'],
#  [13.399999999999999, 6.6, 'Kylrum'],
#  [16.4, -6.4, 'Kylrum'],
#  [13.399999999999999, -8.4, 'Kylrum'],
#  [39.4, 15.4, 'Kylrum'],
#  [51.4, 14.4, 'Kylrum'],
#  [28.4, 14.6, 'Kylrum'],
#  [27.4, 10.6, 'Kylrum'],
#  [45.4, 5.4, 'Kylrum'],
#  [38.4, 9.4, 'Kylrum'],
#  [33.4, 17.4, 'Kylrum'],
#  [12.399999999999999, 4.6, 'Kylrum'],
#  [25.4, -0.40000000000000036, 'Kylrum'],
#  [51.4, 21.1, 'Lärarrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [20.4, 1.5999999999999996, 'Kylrum'],
#  [56.4, 19.4, 'Kylrum'],
#  [45.4, 12.4, 'Kylrum'],
#  [42.4, 12.4, 'Kylrum'],
#  [26.4, 1.5999999999999996, 'Kylrum'],
#  [28.4, 10.4, 'Kylrum'],
#  [8.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [51.4, 11.4, 'Kylrum'],
#  [26.4, 6.6, 'Kylrum'],
#  [22.4, 3.5999999999999996, 'Kylrum'],
#  [18.4, -4.4, 'Kylrum'],
#  [47.4, 9.4, 'Kylrum'],
#  [26.4, -4.4, 'Kylrum'],
#  [27.4, 6.6, 'Kylrum'],
#  [49.4, 15.399999999999999, 'Kylrum'],
#  [25.4, 9.24, 'Kylrum'],
#  [39.4, 13.4, 'Kylrum'],
#  [28.4, 5.6, 'Kylrum'],
#  [35.4, 10.4, 'Kylrum'],
#  [19.4, -4.4, 'Kylrum'],
#  [27.4, 11.6, 'Kylrum'],
#  [21.4, 8.6, 'Kylrum'],
#  [19.4, 8.6, 'Kylrum'],
#  [49.4, 20.4, 'Kylrum'],
#  [24.4, -2.4000000000000004, 'Kylrum'],
#  [18.4, 0.5999999999999996, 'Kylrum'],
#  [22.4, -3.4000000000000004, 'Kylrum'],
#  [21.4, 7.6, 'Kylrum'],
#  [51.4, 8.4, 'Kylrum'],
#  [12.399999999999999, -7.4, 'Kylrum'],
#  [31.4, 3.5999999999999996, 'Kylrum'],
#  [51.4, 7.4, 'Kylrum'],
#  [43.4, 16.4, 'Kylrum'],
#  [18.4, 1.5999999999999996, 'Kylrum'],
#  [53.4, 12.4, 'Kylrum'],
#  [13.399999999999999, -8.4, 'Kylrum'],
#  [54.4, 13.4, 'Kylrum'],
#  [5.399999999999999, 5.6, 'Kylrum'],
#  [12.399999999999999, 0.5999999999999996, 'Kylrum'],
#  [54.4, 11.4, 'Kylrum'],
#  [43.4, 14.4, 'Kylrum'],
#  [17.4, -7.4, 'Kylrum'],
#  [23.4, 7.6, 'Kylrum'],
#  [46.4, 10.4, 'Kylrum'],
#  [21.4, 9.6, 'Kylrum'],
#  [42.4, 16.4, 'Kylrum'],
#  [14.399999999999999, 7.6, 'Kylrum'],
#  [23.4, 4.6, 'Kylrum'],
#  [28.4, 9.6, 'Kylrum'],
#  [9.399999999999999, 13.6, 'Kylrum'],
#  [54.4, 8.4, 'Kylrum'],
#  [31.4, 16.4, 'Kylrum'],
#  [18.4, 1.5999999999999996, 'Kylrum'],
#  [16.4, 7.6, 'Kylrum'],
#  [17.4, 8.6, 'Kylrum'],
#  [20.4, 5.6, 'Kylrum'],
#  [17.4, -1.4000000000000004, 'Kylrum'],
#  [53.4, 17.4, 'Kylrum'],
#  [13.399999999999999, 7.6, 'Kylrum'],
#  [16.4, 7.6, 'Kylrum'],
#  [41.4, 17.4, 'Kylrum'],
#  [46.4, 10.4, 'Kylrum'],
#  [22.4, 5.6, 'Kylrum'],
#  [53.4, 6.4, 'Kylrum'],
#  [15.399999999999999, 5.6, 'Kylrum'],
#  [17.4, -3.4000000000000004, 'Kylrum'],
#  [16.4, 9.6, 'Kylrum'],
#  [27.4, 2.5999999999999996, 'Kylrum'],
#  [10.399999999999999, 1.5999999999999996, 'Kylrum'],
#  [27.4, 5.6, 'Kylrum'],
#  [47.4, 14.4, 'Kylrum'],
#  [49.4, 11.4, 'Kylrum'],
#  [45.4, 11.4, 'Kylrum'],
#  [38.4, 7.4, 'Kylrum'],
#  [15.399999999999999, -0.40000000000000036, 'Kylrum'],
#  [20.4, 1.5999999999999996, 'Kylrum'],
#  [40.4, 9.4, 'Kylrum'],
#  [17.4, 7.6, 'Kylrum'],
#  [18.4, 10.6, 'Kylrum'],
#  [19.4, 11.6, 'Kylrum'],
#  [54.4, 14.4, 'Kylrum'],
#  [30.4, 9.6, 'Kylrum'],
#  [32.4, 4.6, 'Kylrum'],
#  [14.399999999999999, 8.6, 'Kylrum'],
#  [41.4, 10.4, 'Kylrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [45.4, 11.4, 'Kylrum'],
#  [22.4, -0.40000000000000036, 'Kylrum'],
#  [41.4, 8.4, 'Kylrum'],
#  [29.4, 8.6, 'Kylrum'],
#  [21.4, 11.6, 'Kylrum'],
#  [14.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [38.4, 11.4, 'Kylrum'],
#  [43.4, 15.4, 'Kylrum'],
#  [53.4, 4.4, 'Kylrum'],
#  [26.4, 8.6, 'Kylrum'],
#  [45.4, 10.4, 'Kylrum'],
#  [16.4, 4.6, 'Kylrum'],
#  [12.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [13.399999999999999, -11.4, 'Kylrum'],
#  [24.4, 0.5999999999999996, 'Kylrum'],
#  [29.4, 8.6, 'Kylrum'],
#  [39.4, 12.4, 'Kylrum'],
#  [17.4, -0.40000000000000036, 'Kylrum'],
#  [24.4, 8.6, 'Kylrum'],
#  [41.4, 14.399999999999999, 'Kylrum'],
#  [56.4, 14.399999999999999, 'Kylrum'],
#  [27.4, 5.6, 'Kylrum'],
#  [56.4, 14.4, 'Kylrum'],
#  [18.4, 5.6, 'Kylrum'],
#  [19.4, 10.6, 'Kylrum'],
#  [58.4, 10.4, 'Kylrum'],
#  [17.4, -0.40000000000000036, 'Kylrum'],
#  [21.4, 0.5999999999999996, 'Kylrum'],
#  [16.4, 4.6, 'Kylrum'],
#  [48.4, 9.4, 'Kylrum'],
#  [7.399999999999999, 1.5999999999999996, 'Kylrum'],
#  [26.4, 9.6, 'Kylrum'],
#  [40.4, 10.4, 'Kylrum'],
#  [58.4, 17.1, 'Lärarrum'],
#  [31.4, 0.5999999999999996, 'Kylrum'],
#  [15.399999999999999, -1.4000000000000004, 'Kylrum'],
#  [31.4, 16.4, 'Kylrum'],
#  [20.4, 10.6, 'Kylrum'],
#  [20.4, 9.6, 'Kylrum'],
#  [37.4, 16.4, 'Kylrum'],
#  [40.4, 10.4, 'Kylrum'],
#  [19.4, 5.6, 'Kylrum'],
#  [9.399999999999999, 1.5999999999999996, 'Kylrum'],
#  [20.4, 1.5999999999999996, 'Kylrum'],
#  [57.4, 8.4, 'Kylrum'],
#  [50.4, 13.4, 'Kylrum'],
#  [40.4, 8.4, 'Kylrum'],
#  [16.4, 3.5999999999999996, 'Kylrum'],
#  [7.399999999999999, 2.5999999999999996, 'Kylrum'],
#  [24.4, 10.6, 'Kylrum'],
#  [17.4, -0.40000000000000036, 'Kylrum'],
#  [42.4, 11.4, 'Kylrum'],
#  [20.4, 1.5999999999999996, 'Kylrum'],
#  [41.4, 13.4, 'Kylrum'],
#  [28.4, 6.6, 'Kylrum'],
#  [25.4, 11.6, 'Kylrum'],
#  [55.5, 19.7, 'Lärarrum'],
#  [26.4, 8.6, 'Kylrum'],
#  [36.4, 9.4, 'Kylrum'],
#  [49.4, 10.4, 'Kylrum'],
#  [50.4, 16.1, 'Lärarrum'],
#  [33.4, 8.6, 'Kylrum'],
#  [32.4, 8.4, 'Kylrum'],
#  [18.4, 4.6, 'Kylrum'],
#  [54.4, 14.4, 'Kylrum'],
#  [57.4, 20.1, 'Lärarrum'],
#  [15.399999999999999, 6.6, 'Kylrum'],
#  [7.399999999999999, 5.6, 'Kylrum'],
#  [6.399999999999999, 2.5999999999999996, 'Kylrum'],
#  [49.4, 11.4, 'Kylrum'],
#  [23.4, 2.5999999999999996, 'Kylrum'],
#  [16.4, -2.4000000000000004, 'Kylrum'],
#  [35.4, 15.4, 'Kylrum'],
#  [13.399999999999999, 6.6, 'Kylrum'],
#  [44.4, 10.4, 'Kylrum'],
#  [27.4, 17.6, 'Kylrum'],
#  [39.4, 11.4, 'Kylrum'],
#  [19.4, 11.600000000000001, 'Kylrum'],
#  [28.4, 5.4, 'Kylrum'],
#  [57.4, 19.1, 'Lärarrum'],
#  [16.4, 4.6, 'Kylrum'],
#  [13.399999999999999, -0.40000000000000036, 'Kylrum'],
#  [28.4, 11.6, 'Kylrum'],
#  [21.4, -2.4000000000000004, 'Kylrum'],
#  [51.4, 13.4, 'Kylrum'],
#  [14.399999999999999, -5.4, 'Kylrum'],
#  [19.4, -0.40000000000000036, 'Kylrum'],
#  [24.4, 5.6, 'Kylrum'],
#  [20.4, 7.6, 'Kylrum'],
#  [33.4, 5.6, 'Kylrum'],
#  [27.4, 13.6, 'Kylrum'],
#  [53.4, 11.4, 'Kylrum'],
#  [18.4, -4.4, 'Kylrum'],
#  [29.4, 16.6, 'Kylrum'],
#  [39.4, 8.4, 'Kylrum'],
#  [57.5, 20.8, 'Klassrum'],
#  [36.4, 14.399999999999999, 'Kylrum'],
#  [9.399999999999999, 12.6, 'Kylrum'],
#  [24.4, 7.6, 'Kylrum'],
#  [21.4, 13.6, 'Kylrum'],
#  [38.4, 15.4, 'Kylrum'],
#  [54.4, 12.4, 'Kylrum'],
#  [40.4, 10.4, 'Kylrum'],
#  [31.4, 12.4, 'Kylrum'],
#  [3.3999999999999986, 4.6, 'Kylrum'],
#  [38.4, 12.4, 'Kylrum'],
#  [19.4, 10.6, 'Kylrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [9.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [14.399999999999999, 6.6, 'Kylrum'],
#  [30.4, 12.4, 'Kylrum'],
#  [17.4, 5.6, 'Kylrum'],
#  [24.4, 3.5999999999999996, 'Kylrum'],
#  [36.4, 18.4, 'Kylrum'],
#  [15.399999999999999, 2.5999999999999996, 'Kylrum'],
#  [40.4, 14.4, 'Kylrum'],
#  [37.4, 13.4, 'Kylrum'],
#  [45.4, 15.4, 'Kylrum'],
#  [32.4, 13.6, 'Kylrum'],
#  [19.4, 4.6, 'Kylrum'],
#  [17.4, 7.6, 'Kylrum'],
#  [23.4, 0.5999999999999996, 'Kylrum'],
#  [41.4, 11.4, 'Kylrum'],
#  [52.4, 14.4, 'Kylrum'],
#  [31.4, 8.6, 'Kylrum'],
#  [58.5, 20.8, 'Klassrum'],
#  [17.4, 10.6, 'Kylrum'],
#  [54.4, 14.4, 'Kylrum'],
#  [38.4, 11.4, 'Kylrum'],
#  [53.4, 13.4, 'Kylrum'],
#  [43.4, 9.4, 'Kylrum'],
#  [13.399999999999999, 7.6, 'Kylrum'],
#  [21.4, -2.4000000000000004, 'Kylrum'],
#  [36.4, 11.4, 'Kylrum'],
#  [59.4, 15.4, 'Kylrum'],
#  [24.4, 1.5999999999999996, 'Kylrum'],
#  [17.4, 4.6, 'Kylrum'],
#  [12.399999999999999, -4.4, 'Kylrum'],
#  [23.4, 2.5999999999999996, 'Kylrum'],
#  [56.4, 11.4, 'Kylrum'],
#  [31.4, 12.4, 'Kylrum'],
#  [17.4, -1.4000000000000004, 'Kylrum'],
#  [22.4, 0.5999999999999996, 'Kylrum'],
#  [59.4, 26.1, 'Lärarrum'],
#  [56.4, 12.4, 'Kylrum'],
#  [57.4, 12.4, 'Kylrum'],
#  [13.399999999999999, 2.5999999999999996, 'Kylrum'],
#  [48.4, 6.4, 'Kylrum'],
#  [27.4, 1.5999999999999996, 'Kylrum'],
#  [29.4, 11.6, 'Kylrum'],
#  [20.4, -3.4000000000000004, 'Kylrum'],
#  [56.4, 12.4, 'Kylrum'],
#  [20.4, 5.6, 'Kylrum'],
#  [13.399999999999999, 2.5999999999999996, 'Kylrum'],
#  [20.4, 9.6, 'Kylrum'],
#  [15.399999999999999, 4.6, 'Kylrum'],
#  [19.4, 0.5999999999999996, 'Kylrum'],
#  [39.4, 12.4, 'Kylrum'],
#  [25.4, 12.6, 'Kylrum'],
#  [19.4, 3.5999999999999996, 'Kylrum'],
#  [16.4, 6.6, 'Kylrum'],
#  [46.4, 11.4, 'Kylrum'],
#  [12.399999999999999, 1.5999999999999996, 'Kylrum'],
#  [27.4, 9.6, 'Kylrum'],
#  [16.4, 3.5999999999999996, 'Kylrum'],
#  [55.4, 17.4, 'Kylrum'],
#  [21.4, 5.6, 'Kylrum'],
#  [17.4, -2.4000000000000004, 'Kylrum'],
#  [36.4, 5.4, 'Kylrum'],
#  [34.4, 9.4, 'Kylrum'],
#  [30.4, 11.4, 'Kylrum'],
#  [51.4, 15.399999999999999, 'Kylrum'],
#  [36.4, 16.4, 'Kylrum'],
#  [13.399999999999999, -1.4000000000000004, 'Kylrum'],
#  [53.4, 14.4, 'Kylrum'],
#  [20.4, 12.6, 'Kylrum'],
#  [21.4, 11.6, 'Kylrum'],
#  [6.399999999999999, 1.5999999999999996, 'Kylrum'],
#  [22.4, 3.5999999999999996, 'Kylrum'],
#  [18.4, 1.5999999999999996, 'Kylrum'],
#  [55.4, 5.4, 'Kylrum'],
#  [18.4, 4.6, 'Kylrum'],
#  [36.4, 14.4, 'Kylrum'],
#  [56.4, 12.4, 'Kylrum'],
#  [34.4, 11.6, 'Kylrum'],
#  [16.4, 7.6, 'Kylrum'],
#  [32.4, 13.4, 'Kylrum'],
#  [56.4, 12.4, 'Kylrum'],
#  [27.4, 12.6, 'Kylrum'],
#  [17.4, -0.40000000000000036, 'Kylrum'],
#  [14.399999999999999, -7.4, 'Kylrum'],
#  [22.4, -3.4000000000000004, 'Kylrum'],
#  [19.4, 2.5999999999999996, 'Kylrum'],
#  [28.4, 6.6, 'Kylrum'],
#  [50.4, 4.4, 'Kylrum'],
#  [18.4, 1.5999999999999996, 'Kylrum'],
#  [31.4, 16.4, 'Kylrum'],
#  [58.4, 8.4, 'Kylrum'],
#  [46.4, 6.4, 'Kylrum'],
#  [22.4, 3.5999999999999996, 'Kylrum'],
#  [34.4, 13.4, 'Kylrum'],
#  [13.399999999999999, 5.6, 'Kylrum'],
#  [8.399999999999999, -7.4, 'Kylrum'],
#  [40.4, 12.4, 'Kylrum'],
#  [26.4, 12.6, 'Kylrum'],
#  [54.4, 19.1, 'Lärarrum'],
#  [18.4, 4.6, 'Kylrum'],
#  [15.399999999999999, 5.6, 'Kylrum'],
#  [44.4, 13.4, 'Kylrum'],
#  [22.4, -1.4000000000000004, 'Kylrum'],
#  [25.4, -1.4000000000000004, 'Kylrum'],
#  [42.4, 14.399999999999999, 'Kylrum'],
#  [39.4, 9.4, 'Kylrum'],
#  [22.4, 12.6, 'Kylrum'],
#  [43.4, 13.4, 'Kylrum'],
#  [18.4, -4.4, 'Kylrum'],
#  [53.4, 12.4, 'Kylrum'],
#  [20.4, 10.6, 'Kylrum'],
#  [23.4, 5.6, 'Kylrum'],
#  [20.4, 12.6, 'Kylrum'],
#  [58.4, 23.1, 'Lärarrum'],
#  [39.4, 10.4, 'Kylrum'],
#  [16.4, 15.6, 'Kylrum'],
#  [31.4, 12.6, 'Kylrum'],
#  [15.399999999999999, 6.6, 'Kylrum'],
#  [56.4, 13.4, 'Kylrum'],
#  [19.4, 6.6, 'Kylrum'],
#  [49.4, 3.4000000000000004, 'Kylrum'],
#  [13.399999999999999, 9.6, 'Kylrum'],
#  [15.399999999999999, -9.4, 'Kylrum'],
#  [21.4, 3.5999999999999996, 'Kylrum'],
#  [22.4, 12.6, 'Kylrum'],
#  [32.4, 14.4, 'Kylrum'],
#  [5.399999999999999, 5.6, 'Kylrum'],
#  [22.4, 13.6, 'Kylrum'],
#  [21.4, 6.6, 'Kylrum'],
#  [36.4, 7.4, 'Kylrum'],
#  [33.4, 12.4, 'Kylrum'],
#  [54.4, 20.1, 'Lärarrum'],
#  [20.4, 6.6, 'Kylrum'],
#  [50.4, 14.4, 'Kylrum'],
#  [4.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [44.4, 11.4, 'Kylrum'],
#  [15.399999999999999, -5.4, 'Kylrum'],
#  [32.4, 7.6, 'Kylrum'],
#  [19.4, -7.4, 'Kylrum'],
#  [17.4, 7.6, 'Kylrum'],
#  [18.4, 2.5999999999999996, 'Kylrum'],
#  [49.4, 19.1, 'Lärarrum'],
#  [50.4, 11.4, 'Kylrum'],
#  [5.399999999999999, 6.6, 'Kylrum'],
#  [52.4, 4.4, 'Kylrum'],
#  [55.4, 7.4, 'Kylrum'],
#  [20.4, 6.6, 'Kylrum'],
#  [29.4, 4.6, 'Kylrum'],
#  [26.4, 0.5999999999999996, 'Kylrum'],
#  [40.4, 12.4, 'Kylrum'],
#  [19.4, -3.4000000000000004, 'Kylrum'],
#  [31.4, 3.5999999999999996, 'Kylrum'],
#  [14.399999999999999, 7.6, 'Kylrum'],
#  [26.4, 2.5999999999999996, 'Kylrum'],
#  [32.4, 11.4, 'Kylrum'],
#  [35.4, 10.4, 'Kylrum'],
#  [17.4, 10.6, 'Kylrum'],
#  [16.4, 6.6, 'Kylrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [10.399999999999999, 8.6, 'Kylrum'],
#  [7.399999999999999, -9.4, 'Kylrum'],
#  [21.4, 9.6, 'Kylrum'],
#  [17.4, 1.5999999999999996, 'Kylrum'],
#  [18.4, 6.6, 'Kylrum'],
#  [22.4, 4.6, 'Kylrum'],
#  [20.4, 6.6, 'Kylrum'],
#  [19.4, 9.6, 'Kylrum'],
#  [20.4, -0.40000000000000036, 'Kylrum'],
#  [39.4, 12.4, 'Kylrum'],
#  [22.4, 7.6, 'Kylrum'],
#  [18.4, 12.6, 'Kylrum'],
#  [30.4, 16.4, 'Kylrum'],
#  [37.4, 9.6, 'Kylrum'],
#  [19.4, 4.6, 'Kylrum'],
#  [33.4, 13.4, 'Kylrum'],
#  [15.399999999999999, -3.4000000000000004, 'Kylrum'],
#  [19.4, -1.4000000000000004, 'Kylrum'],
#  [54.4, 22.1, 'Lärarrum'],
#  [53.4, 13.4, 'Kylrum'],
#  [45.4, 16.4, 'Kylrum'],
#  [25.4, 4.6, 'Kylrum'],
#  [17.4, -6.4, 'Kylrum'],
#  [19.4, 5.6, 'Kylrum'],
#  [58.4, 15.4, 'Kylrum'],
#  [38.4, 7.4, 'Kylrum'],
#  [38.4, 9.4, 'Kylrum'],
#  [53.4, 6.4, 'Kylrum'],
#  [29.4, 9.4, 'Kylrum'],
#  [38.4, 10.4, 'Kylrum'],
#  [27.4, 1.5999999999999996, 'Kylrum'],
#  [46.4, 12.4, 'Kylrum'],
#  [56.4, 11.399999999999999, 'Kylrum'],
#  [55.4, 7.4, 'Kylrum'],
#  [14.399999999999999, -7.4, 'Kylrum'],
#  [25.4, 9.6, 'Kylrum'],
#  [23.4, 3.5999999999999996, 'Kylrum'],
#  [59.4, 12.4, 'Kylrum']]

# %%
def gini(rows):
    """Calculate the Gini Impurity for a list of rows.

    There are a few different ways to do this, I thought this one was
    the most concise. See:
    https://en.wikipedia.org/wiki/Decision_tree_learning#Gini_impurity
    """
    counts = class_counts(rows)
    impurity = 1
    for lbl in counts:
        prob_of_lbl = counts[lbl] / float(len(rows))
        impurity -= prob_of_lbl**2
    return impurity

# %%
#######
# Demo:
# Let's look at some example to understand how Gini Impurity works.
#
# First, we'll look at a dataset with no mixing.
no_mixing = [['Kylrum'],
              ['Kylrum']]
# this will return 0
gini(no_mixing)
# Out:
# 0.0

# %%
# Now, we'll look at dataset with a 50:50 apples:oranges ratio
some_mixing = [['Kylrum'],
               ['Klassrum']]
# this will return 0.5 - meaning, there's a 50% chance of misclassifying
# a random example we draw from the dataset.
gini(some_mixing)
# Out:
# 0.5

# %%
# Now, we'll look at a dataset with many different labels
lots_of_mixing = [['Kylrum'],
                  ['Klassrum'],
                  ['Lärarrum']]
                  
# This will return 0.8
gini(lots_of_mixing)
# Out:
# 0.6666666666666665

# %%
def info_gain(left, right, current_uncertainty):
    """Information Gain.

    The uncertainty of the starting node, minus the weighted impurity of
    two child nodes.
    """
    p = float(len(left)) / (len(left) + len(right))
    return current_uncertainty - p * gini(left) - (1 - p) * gini(right)

# %%
#######
# Demo:
# Calculate the uncertainy of our training data.
current_uncertainty = gini(training_data)
current_uncertainty
# Out:
# 0.6426049072221133

# %%
# How much information do we gain by partioning on 'Green'?
true_rows, false_rows = partition(training_data, Question(0, 57))
info_gain(true_rows, false_rows, current_uncertainty)
# Out:
# 0.34226232548924396

# %%
# What about if we partioned on 'Red' instead?
true_rows, false_rows = partition(training_data, Question(0, 70))
info_gain(true_rows, false_rows, current_uncertainty)
# Out:
# 0.2741462542175305

# %%
# It looks like we learned more using 'Red' (0.37), than 'Green' (0.14).
# Why? Look at the different splits that result, and see which one
# looks more 'unmixed' to you.
true_rows, false_rows = partition(training_data, Question(0,57))

# Here, the true_rows contain only 'Grapes'.
true_rows
# Out:
# [[89.4, 19.5, 'Klassrum'],
#  [57.4, 18.1, 'Lärarrum'],
#  [84.4, 24.4, 'Klassrum'],
#  [95.4, 22.4, 'Klassrum'],
#  [81.4, 20.1, 'Lärarrum'],
#  [70.5, 19.7, 'Lärarrum'],
#  [70.5, 19.8, 'Klassrum'],
#  [93.4, 22.4, 'Klassrum'],
#  [88.4, 22.5, 'Klassrum'],
#  [90.4, 20.5, 'Klassrum'],
#  [84.4, 18.1, 'Lärarrum'],
#  [82.4, 18.1, 'Lärarrum'],
#  [67.5, 18.7, 'Lärarrum'],
#  [78.4, 19.1, 'Lärarrum'],
#  [74.5, 19.8, 'Klassrum'],
#  [91.4, 21.5, 'Klassrum'],
#  [93.4, 21.5, 'Klassrum'],
#  [88.4, 20.1, 'Lärarrum'],
#  [84.4, 21.5, 'Klassrum'],
#  [94.4, 22.5, 'Klassrum'],
#  [89.4, 20.5, 'Klassrum'],
#  [63.5, 17.7, 'Lärarrum'],
#  [76.5, 18.8, 'Klassrum'],
#  [70.5, 21.7, 'Lärarrum'],
#  [84.4, 20.1, 'Lärarrum'],
#  [88.4, 24.4, 'Klassrum'],
#  [75.5, 22.8, 'Klassrum'],
#  [72.5, 21.8, 'Klassrum'],
#  [85.4, 18.1, 'Lärarrum'],
#  [83.4, 18.1, 'Lärarrum'],
#  [84.4, 22.1, 'Lärarrum'],
#  [81.4, 16.1, 'Lärarrum'],
#  [67.5, 15.7, 'Lärarrum'],
#  [70.5, 17.7, 'Lärarrum'],
#  [86.4, 22.4, 'Klassrum'],
#  [92.4, 24.4, 'Klassrum'],
#  [78.4, 22.1, 'Lärarrum'],
#  [87.4, 20.1, 'Lärarrum'],
#  [81.4, 23.1, 'Lärarrum'],
#  [92.4, 22.4, 'Klassrum'],
#  [73.5, 20.8, 'Klassrum'],
#  [78.4, 18.1, 'Lärarrum'],
#  [89.4, 23.4, 'Klassrum'],
#  [91.4, 21.4, 'Klassrum'],
#  [88.4, 23.4, 'Klassrum'],
#  [84.4, 15.100000000000001, 'Lärarrum'],
#  [87.4, 20.1, 'Lärarrum'],
#  [84.4, 18.1, 'Lärarrum'],
#  [80.4, 15.100000000000001, 'Lärarrum'],
#  [85.4, 21.4, 'Klassrum'],
#  [76.4, 15.100000000000001, 'Lärarrum'],
#  [94.4, 22.5, 'Klassrum'],
#  [71.5, 19.7, 'Lärarrum'],
#  [67.5, 20.7, 'Lärarrum'],
#  [91.4, 19.5, 'Klassrum'],
#  [69.5, 24.8, 'Klassrum'],
#  [86.4, 17.1, 'Lärarrum'],
#  [75.5, 19.8, 'Klassrum'],
#  [72.5, 16.7, 'Lärarrum'],
#  [72.5, 20.8, 'Klassrum'],
#  [86.4, 19.4, 'Klassrum'],
#  [81.4, 22.1, 'Lärarrum'],
#  [73.5, 18.8, 'Klassrum'],
#  [74.5, 23.7, 'Lärarrum'],
#  [74.5, 21.8, 'Klassrum'],
#  [90.4, 26.4, 'Klassrum'],
#  [75.5, 17.8, 'Klassrum'],
#  [99.4, 24.5, 'Klassrum'],
#  [84.4, 20.5, 'Klassrum'],
#  [78.4, 23.1, 'Lärarrum'],
#  [78.4, 16.1, 'Lärarrum'],
#  [63.5, 22.7, 'Lärarrum'],
#  [72.5, 18.8, 'Klassrum'],
#  [82.4, 14.100000000000001, 'Lärarrum'],
#  [83.4, 19.1, 'Lärarrum'],
#  [94.4, 20.5, 'Klassrum'],
#  [90.4, 22.5, 'Klassrum'],
#  [92.4, 20.5, 'Klassrum'],
#  [59.4, 19.1, 'Lärarrum'],
#  [89.4, 19.5, 'Klassrum'],
#  [84.4, 16.1, 'Lärarrum'],
#  [93.4, 26.4, 'Klassrum'],
#  [93.4, 22.4, 'Klassrum'],
#  [95.4, 23.5, 'Klassrum'],
#  [93.4, 22.1, 'Lärarrum'],
#  [70.5, 17.8, 'Klassrum'],
#  [92.4, 24.5, 'Klassrum'],
#  [73.5, 18.8, 'Klassrum'],
#  [75.5, 25.7, 'Lärarrum'],
#  [58.4, 13.4, 'Kylrum'],
#  [59.4, 19.1, 'Lärarrum'],
#  [101.4, 22.5, 'Klassrum'],
#  [72.5, 16.8, 'Klassrum'],
#  [74.5, 21.7, 'Lärarrum'],
#  [72.5, 18.7, 'Lärarrum'],
#  [92.4, 28.4, 'Klassrum'],
#  [88.4, 25.5, 'Klassrum'],
#  [75.5, 23.8, 'Klassrum'],
#  [73.5, 22.7, 'Lärarrum'],
#  [85.4, 20.5, 'Klassrum'],
#  [78.5, 23.8, 'Klassrum'],
#  [95.4, 20.5, 'Klassrum'],
#  [73.5, 17.7, 'Lärarrum'],
#  [89.4, 20.5, 'Klassrum'],
#  [77.5, 23.8, 'Klassrum'],
#  [78.4, 19.1, 'Lärarrum'],
#  [66.5, 18.8, 'Klassrum'],
#  [76.5, 20.8, 'Klassrum'],
#  [74.5, 27.7, 'Lärarrum'],
#  [77.4, 15.100000000000001, 'Lärarrum'],
#  [82.4, 21.1, 'Lärarrum'],
#  [91.4, 23.5, 'Klassrum'],
#  [57.4, 13.4, 'Kylrum'],
#  [85.4, 23.5, 'Klassrum'],
#  [92.4, 21.4, 'Klassrum'],
#  [77.4, 21.1, 'Lärarrum'],
#  [79.5, 21.8, 'Klassrum'],
#  [68.5, 16.8, 'Klassrum'],
#  [74.5, 19.7, 'Lärarrum'],
#  [73.5, 15.8, 'Klassrum'],
#  [59.5, 21.7, 'Lärarrum'],
#  [87.4, 19.5, 'Klassrum'],
#  [69.5, 19.8, 'Klassrum'],
#  [83.4, 21.1, 'Lärarrum'],
#  [80.4, 25.1, 'Lärarrum'],
#  [66.5, 18.8, 'Klassrum'],
#  [83.4, 22.4, 'Klassrum'],
#  [83.4, 18.5, 'Klassrum'],
#  [93.4, 20.5, 'Klassrum'],
#  [87.4, 17.1, 'Lärarrum'],
#  [73.5, 15.7, 'Lärarrum'],
#  [91.4, 20.1, 'Lärarrum'],
#  [84.4, 16.1, 'Lärarrum'],
#  [69.5, 15.8, 'Klassrum'],
#  [69.5, 23.7, 'Lärarrum'],
#  [84.4, 19.5, 'Klassrum'],
#  [94.4, 24.5, 'Klassrum'],
#  [65.5, 21.8, 'Klassrum'],
#  [94.4, 25.5, 'Klassrum'],
#  [87.4, 16.5, 'Klassrum'],
#  [79.5, 26.8, 'Klassrum'],
#  [80.4, 21.4, 'Klassrum'],
#  [80.4, 24.4, 'Klassrum'],
#  [78.4, 19.1, 'Lärarrum'],
#  [78.5, 16.7, 'Lärarrum'],
#  [85.4, 19.5, 'Klassrum'],
#  [100.4, 26.5, 'Klassrum'],
#  [105.4, 26.5, 'Klassrum'],
#  [68.5, 20.8, 'Klassrum'],
#  [78.5, 19.8, 'Klassrum'],
#  [81.4, 13.100000000000001, 'Lärarrum'],
#  [89.4, 20.1, 'Lärarrum'],
#  [72.5, 24.7, 'Lärarrum'],
#  [73.5, 16.7, 'Lärarrum'],
#  [90.4, 26.5, 'Klassrum'],
#  [87.4, 19.5, 'Klassrum'],
#  [88.4, 19.5, 'Klassrum'],
#  [105.4, 20.5, 'Klassrum'],
#  [72.5, 17.7, 'Lärarrum'],
#  [65.5, 21.7, 'Lärarrum'],
#  [89.4, 23.4, 'Klassrum'],
#  [85.4, 14.100000000000001, 'Lärarrum'],
#  [66.5, 19.8, 'Klassrum'],
#  [69.5, 17.8, 'Klassrum'],
#  [69.5, 24.7, 'Lärarrum'],
#  [84.4, 18.1, 'Lärarrum'],
#  [105.4, 18.5, 'Klassrum'],
#  [66.5, 17.8, 'Klassrum'],
#  [104.4, 21.5, 'Klassrum'],
#  [75.5, 17.8, 'Klassrum'],
#  [76.5, 20.8, 'Klassrum'],
#  [81.4, 19.1, 'Lärarrum'],
#  [82.4, 22.1, 'Lärarrum'],
#  [69.5, 21.7, 'Lärarrum'],
#  [72.5, 15.8, 'Klassrum'],
#  [86.4, 21.5, 'Klassrum'],
#  [84.4, 25.4, 'Klassrum'],
#  [83.4, 20.5, 'Klassrum'],
#  [84.4, 13.100000000000001, 'Lärarrum'],
#  [72.5, 23.7, 'Lärarrum'],
#  [59.4, 18.1, 'Lärarrum'],
#  [70.5, 14.8, 'Klassrum'],
#  [59.4, 12.4, 'Kylrum'],
#  [93.4, 19.4, 'Klassrum'],
#  [98.4, 21.4, 'Klassrum'],
#  [89.4, 21.1, 'Lärarrum'],
#  [97.4, 21.5, 'Klassrum'],
#  [84.4, 15.100000000000001, 'Lärarrum'],
#  [96.4, 20.4, 'Klassrum'],
#  [88.4, 23.5, 'Klassrum'],
#  [69.5, 21.7, 'Lärarrum'],
#  [98.4, 24.5, 'Klassrum'],
#  [87.4, 19.1, 'Lärarrum'],
#  [91.4, 22.5, 'Klassrum'],
#  [81.4, 22.1, 'Lärarrum'],
#  [81.4, 13.100000000000001, 'Lärarrum'],
#  [97.4, 24.4, 'Klassrum'],
#  [92.4, 21.5, 'Klassrum'],
#  [82.4, 22.5, 'Klassrum'],
#  [89.4, 23.4, 'Klassrum'],
#  [68.5, 18.7, 'Lärarrum'],
#  [83.4, 21.1, 'Lärarrum'],
#  [75.5, 16.7, 'Lärarrum'],
#  [92.4, 25.4, 'Klassrum'],
#  [76.5, 19.8, 'Klassrum'],
#  [57.4, 15.4, 'Kylrum'],
#  [85.4, 20.5, 'Klassrum'],
#  [102.4, 26.5, 'Klassrum'],
#  [89.4, 19.1, 'Lärarrum'],
#  [85.4, 15.100000000000001, 'Lärarrum'],
#  [87.4, 17.5, 'Klassrum'],
#  [72.5, 18.8, 'Klassrum'],
#  [83.4, 25.4, 'Klassrum'],
#  [65.5, 20.8, 'Klassrum'],
#  [90.4, 20.5, 'Klassrum'],
#  [85.4, 24.4, 'Klassrum'],
#  [93.4, 22.5, 'Klassrum'],
#  [82.4, 24.1, 'Lärarrum'],
#  [77.5, 28.8, 'Klassrum'],
#  [88.4, 22.5, 'Klassrum'],
#  [90.4, 21.5, 'Klassrum'],
#  [75.5, 20.8, 'Klassrum'],
#  [84.4, 14.100000000000001, 'Lärarrum'],
#  [65.5, 19.8, 'Klassrum'],
#  [89.4, 25.4, 'Klassrum'],
#  [74.5, 22.7, 'Lärarrum'],
#  [87.4, 23.4, 'Klassrum'],
#  [89.4, 22.5, 'Klassrum'],
#  [105.4, 21.5, 'Klassrum'],
#  [98.4, 20.4, 'Klassrum'],
#  [94.4, 26.4, 'Klassrum'],
#  [86.4, 20.5, 'Klassrum'],
#  [59.4, 12.4, 'Kylrum'],
#  [68.5, 18.7, 'Lärarrum'],
#  [85.4, 26.4, 'Klassrum'],
#  [59.4, 15.4, 'Kylrum'],
#  [72.5, 16.7, 'Lärarrum'],
#  [81.4, 20.1, 'Lärarrum'],
#  [68.5, 26.7, 'Lärarrum'],
#  [81.4, 27.4, 'Klassrum'],
#  [76.4, 19.1, 'Lärarrum'],
#  [57.4, 13.4, 'Kylrum'],
#  [71.5, 16.8, 'Klassrum'],
#  [80.4, 17.1, 'Lärarrum'],
#  [86.4, 22.4, 'Klassrum'],
#  [76.4, 15.100000000000001, 'Lärarrum'],
#  [93.4, 25.4, 'Klassrum'],
#  [74.5, 20.8, 'Klassrum'],
#  [76.5, 21.8, 'Klassrum'],
#  [91.4, 19.5, 'Klassrum'],
#  [68.5, 18.8, 'Klassrum'],
#  [90.4, 23.1, 'Lärarrum'],
#  [58.4, 23.1, 'Lärarrum'],
#  [92.4, 25.4, 'Klassrum'],
#  [73.5, 22.8, 'Klassrum'],
#  [82.4, 22.5, 'Klassrum'],
#  [83.4, 17.1, 'Lärarrum'],
#  [82.4, 21.4, 'Klassrum'],
#  [72.5, 20.7, 'Lärarrum'],
#  [71.5, 19.8, 'Klassrum'],
#  [80.4, 20.1, 'Lärarrum'],
#  [83.4, 22.5, 'Klassrum'],
#  [62.5, 22.8, 'Klassrum'],
#  [88.4, 17.1, 'Lärarrum'],
#  [71.5, 24.7, 'Lärarrum'],
#  [86.4, 14.100000000000001, 'Lärarrum'],
#  [92.4, 21.4, 'Klassrum'],
#  [79.5, 24.8, 'Klassrum'],
#  [82.4, 21.5, 'Klassrum'],
#  [74.5, 18.8, 'Klassrum'],
#  [81.4, 18.1, 'Lärarrum'],
#  [79.5, 19.8, 'Klassrum'],
#  [86.4, 18.1, 'Lärarrum'],
#  [85.4, 24.1, 'Lärarrum'],
#  [108.4, 23.5, 'Klassrum'],
#  [79.4, 13.100000000000001, 'Lärarrum'],
#  [87.4, 23.5, 'Klassrum'],
#  [78.5, 23.8, 'Klassrum'],
#  [76.4, 20.1, 'Lärarrum'],
#  [82.4, 19.1, 'Lärarrum'],
#  [81.4, 26.4, 'Klassrum'],
#  [68.5, 13.8, 'Klassrum'],
#  [90.4, 23.4, 'Klassrum'],
#  [58.4, 9.4, 'Kylrum'],
#  [82.4, 22.1, 'Lärarrum'],
#  [74.5, 20.7, 'Lärarrum'],
#  [67.5, 20.8, 'Klassrum'],
#  [75.5, 20.8, 'Klassrum'],
#  [70.5, 19.8, 'Klassrum'],
#  [70.5, 22.7, 'Lärarrum'],
#  [97.4, 17.4, 'Klassrum'],
#  [63.5, 20.8, 'Klassrum'],
#  [74.5, 18.8, 'Klassrum'],
#  [102.4, 26.4, 'Klassrum'],
#  [86.4, 19.1, 'Lärarrum'],
#  [77.4, 17.1, 'Lärarrum'],
#  [83.4, 16.1, 'Lärarrum'],
#  [81.4, 25.1, 'Lärarrum'],
#  [86.4, 19.1, 'Lärarrum'],
#  [82.4, 16.1, 'Lärarrum'],
#  [61.5, 17.8, 'Klassrum'],
#  [88.4, 20.5, 'Klassrum'],
#  [80.4, 17.1, 'Lärarrum'],
#  [78.5, 20.8, 'Klassrum'],
#  [84.4, 20.5, 'Klassrum'],
#  [61.4, 19.1, 'Lärarrum'],
#  [65.5, 24.7, 'Lärarrum'],
#  [78.5, 25.8, 'Klassrum'],
#  [74.5, 19.8, 'Klassrum'],
#  [85.4, 21.5, 'Klassrum'],
#  [65.5, 23.8, 'Klassrum'],
#  [86.4, 19.5, 'Klassrum'],
#  [71.5, 19.7, 'Lärarrum'],
#  [66.5, 19.7, 'Lärarrum'],
#  [76.5, 15.8, 'Klassrum'],
#  [61.5, 25.7, 'Lärarrum'],
#  [85.4, 22.5, 'Klassrum'],
#  [66.5, 21.7, 'Lärarrum'],
#  [93.4, 23.5, 'Klassrum'],
#  [87.4, 20.5, 'Klassrum'],
#  [84.4, 19.1, 'Lärarrum'],
#  [86.4, 17.5, 'Klassrum'],
#  [97.4, 17.5, 'Klassrum'],
#  [94.4, 22.5, 'Klassrum'],
#  [94.4, 22.5, 'Klassrum'],
#  [77.5, 17.8, 'Klassrum'],
#  [84.4, 20.4, 'Klassrum'],
#  [86.4, 18.1, 'Lärarrum'],
#  [89.4, 20.5, 'Klassrum'],
#  [92.4, 19.5, 'Klassrum'],
#  [108.4, 20.5, 'Klassrum'],
#  [79.4, 16.1, 'Lärarrum'],
#  [76.5, 24.7, 'Lärarrum'],
#  [78.5, 21.8, 'Klassrum'],
#  [90.4, 22.4, 'Klassrum'],
#  [83.4, 19.5, 'Klassrum'],
#  [80.5, 22.7, 'Lärarrum'],
#  [85.4, 22.5, 'Klassrum'],
#  [101.4, 19.5, 'Klassrum'],
#  [96.4, 18.5, 'Klassrum'],
#  [84.4, 22.5, 'Klassrum'],
#  [92.4, 18.5, 'Klassrum'],
#  [73.4, 16.1, 'Lärarrum'],
#  [85.4, 21.1, 'Lärarrum'],
#  [96.4, 23.5, 'Klassrum'],
#  [79.5, 19.8, 'Klassrum'],
#  [82.4, 23.5, 'Klassrum'],
#  [103.4, 19.5, 'Klassrum'],
#  [67.5, 23.7, 'Lärarrum'],
#  [85.4, 22.1, 'Lärarrum'],
#  [73.5, 15.7, 'Lärarrum'],
#  [99.4, 23.5, 'Klassrum'],
#  [86.4, 17.5, 'Klassrum'],
#  [73.5, 24.8, 'Klassrum'],
#  [77.4, 19.1, 'Lärarrum'],
#  [105.4, 18.5, 'Klassrum'],
#  [80.4, 13.100000000000001, 'Lärarrum'],
#  [58.4, 20.1, 'Lärarrum'],
#  [84.4, 21.5, 'Klassrum'],
#  [57.4, 11.4, 'Kylrum'],
#  [96.4, 22.4, 'Klassrum'],
#  [108.4, 21.5, 'Klassrum'],
#  [89.4, 24.4, 'Klassrum'],
#  [68.5, 17.8, 'Klassrum'],
#  [97.4, 20.4, 'Klassrum'],
#  [69.5, 15.8, 'Klassrum'],
#  [83.4, 19.1, 'Lärarrum'],
#  [85.4, 25.1, 'Lärarrum'],
#  [87.4, 23.1, 'Lärarrum'],
#  [72.5, 20.7, 'Lärarrum'],
#  [86.4, 17.5, 'Klassrum'],
#  [101.4, 20.4, 'Klassrum'],
#  [82.4, 17.5, 'Klassrum'],
#  [85.4, 28.4, 'Klassrum'],
#  [86.4, 26.5, 'Klassrum'],
#  [81.4, 23.1, 'Lärarrum'],
#  [72.5, 21.7, 'Lärarrum'],
#  [69.5, 19.7, 'Lärarrum'],
#  [86.4, 19.5, 'Klassrum'],
#  [104.4, 19.5, 'Klassrum'],
#  [88.4, 20.5, 'Klassrum'],
#  [73.5, 21.7, 'Lärarrum'],
#  [78.5, 25.8, 'Klassrum'],
#  [82.4, 24.1, 'Lärarrum'],
#  [88.4, 21.5, 'Klassrum'],
#  [77.4, 12.100000000000001, 'Lärarrum'],
#  [90.4, 22.5, 'Klassrum'],
#  [73.5, 21.8, 'Klassrum'],
#  [90.4, 20.5, 'Klassrum'],
#  [76.4, 20.1, 'Lärarrum'],
#  [62.4, 9.4, 'Kylrum'],
#  [68.5, 19.8, 'Klassrum'],
#  [81.4, 23.5, 'Klassrum'],
#  [85.4, 23.4, 'Klassrum'],
#  [70.5, 26.7, 'Lärarrum'],
#  [73.5, 15.8, 'Klassrum'],
#  [78.5, 20.8, 'Klassrum'],
#  [69.5, 18.7, 'Lärarrum'],
#  [72.5, 22.8, 'Klassrum'],
#  [89.4, 19.5, 'Klassrum'],
#  [85.4, 20.5, 'Klassrum'],
#  [68.5, 18.7, 'Lärarrum'],
#  [72.5, 17.8, 'Klassrum'],
#  [69.5, 16.8, 'Klassrum'],
#  [74.5, 23.7, 'Lärarrum'],
#  [103.4, 22.5, 'Klassrum'],
#  [74.4, 18.1, 'Lärarrum'],
#  [60.4, 25.1, 'Lärarrum'],
#  [93.4, 23.4, 'Klassrum'],
#  [82.4, 20.5, 'Klassrum'],
#  [80.4, 23.1, 'Lärarrum'],
#  [74.5, 18.8, 'Klassrum'],
#  [92.4, 21.5, 'Klassrum'],
#  [76.5, 19.7, 'Lärarrum'],
#  [72.5, 18.8, 'Klassrum'],
#  [101.4, 14.399999999999999, 'Klassrum'],
#  [79.4, 16.5, 'Klassrum'],
#  [85.4, 21.1, 'Lärarrum'],
#  [97.4, 20.4, 'Klassrum'],
#  [77.5, 17.7, 'Lärarrum'],
#  [80.4, 22.1, 'Lärarrum'],
#  [89.4, 16.1, 'Lärarrum'],
#  [63.5, 16.7, 'Lärarrum'],
#  [65.5, 22.7, 'Lärarrum'],
#  [78.4, 21.4, 'Klassrum'],
#  [84.4, 16.1, 'Lärarrum'],
#  [75.5, 22.8, 'Klassrum'],
#  [94.4, 15.5, 'Klassrum'],
#  [81.4, 18.1, 'Lärarrum'],
#  [105.4, 23.5, 'Klassrum'],
#  [67.5, 24.7, 'Lärarrum'],
#  [95.4, 13.5, 'Klassrum'],
#  [86.4, 17.1, 'Lärarrum'],
#  [85.4, 17.5, 'Klassrum'],
#  [87.4, 16.5, 'Klassrum'],
#  [81.4, 11.100000000000001, 'Lärarrum'],
#  [83.4, 16.5, 'Klassrum'],
#  [90.4, 20.1, 'Lärarrum'],
#  [107.4, 19.5, 'Klassrum'],
#  [60.4, 22.1, 'Lärarrum'],
#  [63.5, 19.8, 'Klassrum'],
#  [86.4, 24.5, 'Klassrum'],
#  [79.4, 25.1, 'Lärarrum'],
#  [75.5, 16.8, 'Klassrum'],
#  [90.4, 26.4, 'Klassrum'],
#  [73.5, 17.7, 'Lärarrum'],
#  [69.5, 25.7, 'Lärarrum'],
#  [73.5, 18.8, 'Klassrum'],
#  [87.4, 27.5, 'Klassrum'],
#  [108.4, 19.5, 'Klassrum'],
#  [82.4, 18.5, 'Klassrum'],
#  [87.4, 17.5, 'Klassrum'],
#  [81.4, 28.4, 'Klassrum'],
#  [82.4, 24.4, 'Klassrum'],
#  [84.4, 22.4, 'Klassrum'],
#  [65.5, 25.8, 'Klassrum'],
#  [104.4, 22.5, 'Klassrum'],
#  [82.4, 14.5, 'Klassrum'],
#  [90.4, 20.5, 'Klassrum'],
#  [75.5, 14.8, 'Klassrum'],
#  [80.4, 17.1, 'Lärarrum'],
#  [88.4, 26.1, 'Lärarrum'],
#  [83.4, 20.1, 'Lärarrum'],
#  [82.4, 19.5, 'Klassrum'],
#  [93.4, 23.5, 'Klassrum'],
#  [65.5, 17.7, 'Lärarrum'],
#  [71.5, 16.7, 'Lärarrum'],
#  [100.4, 23.4, 'Klassrum'],
#  [97.4, 23.5, 'Klassrum'],
#  [61.4, 12.4, 'Kylrum'],
#  [72.5, 15.8, 'Klassrum'],
#  [89.4, 19.1, 'Lärarrum'],
#  [81.4, 23.1, 'Lärarrum'],
#  [79.4, 20.5, 'Klassrum'],
#  [73.5, 20.7, 'Lärarrum'],
#  [74.5, 13.8, 'Klassrum'],
#  [66.5, 13.8, 'Klassrum'],
#  [92.4, 16.4, 'Klassrum'],
#  [91.4, 18.5, 'Klassrum'],
#  [95.4, 24.4, 'Klassrum'],
#  [77.5, 16.8, 'Klassrum'],
#  [75.5, 19.7, 'Lärarrum'],
#  [82.5, 24.8, 'Klassrum'],
#  [93.4, 15.100000000000001, 'Lärarrum'],
#  [83.4, 18.1, 'Lärarrum'],
#  [78.5, 22.8, 'Klassrum'],
#  [89.4, 18.1, 'Lärarrum'],
#  [82.4, 18.1, 'Lärarrum'],
#  [73.5, 19.8, 'Klassrum'],
#  [96.4, 21.5, 'Klassrum'],
#  [89.4, 24.4, 'Klassrum'],
#  [65.5, 25.8, 'Klassrum'],
#  [94.4, 21.5, 'Klassrum'],
#  [61.5, 19.8, 'Klassrum'],
#  [92.4, 22.5, 'Klassrum'],
#  [98.4, 26.4, 'Klassrum'],
#  [89.4, 19.5, 'Klassrum'],
#  [83.4, 20.1, 'Lärarrum'],
#  [57.4, 9.4, 'Kylrum'],
#  [91.4, 27.4, 'Klassrum'],
#  [77.4, 17.1, 'Lärarrum'],
#  [75.4, 22.1, 'Lärarrum'],
#  [75.5, 18.7, 'Lärarrum'],
#  [94.4, 22.4, 'Klassrum'],
#  [79.4, 20.5, 'Klassrum'],
#  [93.4, 20.4, 'Klassrum'],
#  [100.4, 18.5, 'Klassrum'],
#  [84.4, 14.100000000000001, 'Lärarrum'],
#  [108.4, 27.5, 'Klassrum'],
#  [85.4, 23.4, 'Klassrum'],
#  [91.4, 23.4, 'Klassrum'],
#  [85.4, 21.1, 'Lärarrum'],
#  [95.4, 19.5, 'Klassrum'],
#  [93.4, 21.4, 'Klassrum'],
#  [84.4, 21.1, 'Lärarrum'],
#  [71.5, 27.7, 'Lärarrum'],
#  [73.5, 19.7, 'Lärarrum'],
#  [68.5, 19.7, 'Lärarrum'],
#  [83.4, 19.5, 'Klassrum'],
#  [73.5, 25.8, 'Klassrum'],
#  [86.4, 17.1, 'Lärarrum'],
#  [90.4, 20.5, 'Klassrum'],
#  [79.4, 9.100000000000001, 'Lärarrum'],
#  [57.4, 11.4, 'Kylrum'],
#  [82.4, 21.1, 'Lärarrum'],
#  [78.4, 22.1, 'Lärarrum'],
#  [81.4, 15.100000000000001, 'Lärarrum'],
#  [100.4, 11.399999999999999, 'Klassrum'],
#  [93.4, 19.5, 'Klassrum'],
#  [71.5, 14.8, 'Klassrum'],
#  [83.4, 22.4, 'Klassrum'],
#  [97.4, 20.5, 'Klassrum'],
#  [66.5, 14.7, 'Lärarrum'],
#  [82.4, 19.5, 'Klassrum'],
#  [82.4, 14.100000000000001, 'Lärarrum'],
#  [84.4, 16.4, 'Klassrum'],
#  [69.5, 18.7, 'Lärarrum'],
#  [85.4, 20.1, 'Lärarrum'],
#  [76.5, 23.8, 'Klassrum'],
#  [77.4, 16.5, 'Klassrum'],
#  [75.4, 25.1, 'Lärarrum'],
#  [87.4, 24.4, 'Klassrum'],
#  [68.5, 21.7, 'Lärarrum'],
#  [90.4, 15.100000000000001, 'Lärarrum'],
#  [81.4, 18.5, 'Klassrum'],
#  [93.4, 10.5, 'Klassrum'],
#  [86.4, 21.5, 'Klassrum'],
#  [106.4, 21.5, 'Klassrum'],
#  [63.5, 19.8, 'Klassrum'],
#  [58.4, 25.1, 'Lärarrum'],
#  [68.5, 17.8, 'Klassrum'],
#  [94.4, 21.5, 'Klassrum'],
#  [82.5, 19.8, 'Klassrum'],
#  [84.4, 20.1, 'Lärarrum'],
#  [79.4, 17.1, 'Lärarrum'],
#  [93.4, 22.4, 'Klassrum'],
#  [82.4, 19.1, 'Lärarrum'],
#  [90.4, 24.5, 'Klassrum'],
#  [72.5, 17.7, 'Lärarrum'],
#  [73.5, 25.7, 'Lärarrum'],
#  [88.4, 18.5, 'Klassrum'],
#  [66.5, 24.8, 'Klassrum'],
#  [77.4, 27.1, 'Lärarrum'],
#  [67.5, 19.8, 'Klassrum'],
#  [73.4, 17.1, 'Lärarrum'],
#  [96.4, 20.4, 'Klassrum'],
#  [81.4, 16.1, 'Lärarrum'],
#  [85.4, 20.1, 'Lärarrum'],
#  [82.4, 24.1, 'Lärarrum'],
#  [81.4, 21.5, 'Klassrum'],
#  [57.4, 12.4, 'Kylrum'],
#  [84.4, 23.1, 'Lärarrum'],
#  [75.5, 20.7, 'Lärarrum'],
#  [78.4, 19.1, 'Lärarrum'],
#  [73.5, 15.8, 'Klassrum'],
#  [85.4, 19.5, 'Klassrum'],
#  [90.4, 24.4, 'Klassrum'],
#  [89.4, 23.5, 'Klassrum'],
#  [80.5, 25.7, 'Lärarrum'],
#  [59.4, 10.4, 'Kylrum'],
#  [71.5, 15.8, 'Klassrum'],
#  [89.4, 21.1, 'Lärarrum'],
#  [68.5, 13.7, 'Lärarrum'],
#  [71.5, 19.7, 'Lärarrum'],
#  [79.4, 21.1, 'Lärarrum'],
#  [77.4, 28.1, 'Lärarrum'],
#  [84.4, 16.1, 'Lärarrum'],
#  [90.4, 20.5, 'Klassrum'],
#  [93.4, 19.5, 'Klassrum'],
#  [68.5, 15.7, 'Lärarrum'],
#  [57.4, 12.4, 'Kylrum'],
#  [69.5, 24.7, 'Lärarrum'],
#  [86.4, 16.1, 'Lärarrum'],
#  [79.4, 23.5, 'Klassrum'],
#  [71.5, 18.8, 'Klassrum'],
#  [90.4, 25.5, 'Klassrum'],
#  [71.5, 22.8, 'Klassrum'],
#  [70.4, 18.1, 'Lärarrum'],
#  [90.4, 18.4, 'Klassrum'],
#  [92.4, 21.4, 'Klassrum'],
#  [87.4, 20.1, 'Lärarrum'],
#  [79.4, 19.1, 'Lärarrum'],
#  [106.4, 16.5, 'Klassrum'],
#  [85.4, 25.5, 'Klassrum'],
#  [65.5, 27.7, 'Lärarrum'],
#  [78.4, 23.4, 'Klassrum'],
#  [102.4, 14.399999999999999, 'Klassrum'],
#  [74.4, 14.100000000000001, 'Lärarrum'],
#  [82.4, 21.5, 'Klassrum'],
#  [92.4, 23.5, 'Klassrum'],
#  [89.4, 25.4, 'Klassrum'],
#  [74.5, 21.8, 'Klassrum'],
#  [63.4, 25.1, 'Lärarrum'],
#  [84.4, 20.4, 'Klassrum'],
#  [73.5, 15.7, 'Lärarrum'],
#  [103.4, 14.5, 'Klassrum'],
#  [72.5, 18.8, 'Klassrum'],
#  [62.5, 18.7, 'Lärarrum'],
#  [75.4, 14.100000000000001, 'Lärarrum'],
#  [76.5, 24.7, 'Lärarrum'],
#  [74.5, 18.7, 'Lärarrum'],
#  [88.4, 16.1, 'Lärarrum'],
#  [100.4, 17.5, 'Klassrum'],
#  [83.4, 18.5, 'Klassrum'],
#  [97.4, 21.5, 'Klassrum'],
#  [78.4, 19.4, 'Klassrum'],
#  [82.4, 22.5, 'Klassrum'],
#  [98.4, 22.4, 'Klassrum'],
#  [69.5, 24.8, 'Klassrum'],
#  [77.4, 22.1, 'Lärarrum'],
#  [95.4, 25.4, 'Klassrum'],
#  [60.4, 13.4, 'Kylrum'],
#  [84.4, 21.1, 'Lärarrum'],
#  [86.4, 22.5, 'Klassrum'],
#  [92.4, 20.5, 'Klassrum'],
#  [74.5, 17.7, 'Lärarrum'],
#  [89.4, 22.5, 'Klassrum'],
#  [95.4, 24.4, 'Klassrum'],
#  [108.4, 29.5, 'Klassrum'],
#  [75.5, 17.8, 'Klassrum'],
#  [67.5, 19.7, 'Lärarrum'],
#  [86.4, 20.5, 'Klassrum'],
#  [97.4, 27.5, 'Klassrum'],
#  [61.4, 19.1, 'Lärarrum'],
#  [86.4, 26.5, 'Klassrum'],
#  [85.4, 22.1, 'Lärarrum'],
#  [89.4, 20.5, 'Klassrum'],
#  [62.5, 17.8, 'Klassrum'],
#  [79.4, 15.100000000000001, 'Lärarrum'],
#  [60.4, 12.4, 'Kylrum'],
#  [73.5, 17.8, 'Klassrum'],
#  [76.4, 22.1, 'Lärarrum'],
#  [87.4, 25.4, 'Klassrum'],
#  [76.4, 20.1, 'Lärarrum'],
#  [64.5, 15.8, 'Klassrum'],
#  [88.4, 22.4, 'Klassrum'],
#  [72.5, 22.8, 'Klassrum'],
#  [74.4, 12.100000000000001, 'Lärarrum'],
#  [75.5, 19.7, 'Lärarrum'],
#  [67.5, 24.7, 'Lärarrum'],
#  [77.4, 20.1, 'Lärarrum'],
#  [79.4, 19.5, 'Klassrum'],
#  [92.4, 22.5, 'Klassrum'],
#  [95.4, 29.4, 'Klassrum'],
#  [94.4, 26.4, 'Klassrum'],
#  [77.5, 18.8, 'Klassrum'],
#  [73.5, 18.8, 'Klassrum'],
#  [71.4, 19.1, 'Lärarrum'],
#  [68.5, 21.8, 'Klassrum'],
#  [87.4, 14.5, 'Klassrum'],
#  [63.5, 22.7, 'Lärarrum'],
#  [79.4, 11.100000000000001, 'Lärarrum'],
#  [66.5, 16.7, 'Lärarrum'],
#  [94.4, 20.4, 'Klassrum'],
#  [82.4, 25.4, 'Klassrum'],
#  [83.4, 17.5, 'Klassrum'],
#  [82.4, 20.1, 'Lärarrum'],
#  [82.4, 21.5, 'Klassrum'],
#  [79.5, 20.8, 'Klassrum'],
#  [80.4, 24.1, 'Lärarrum'],
#  [91.4, 21.5, 'Klassrum'],
#  [85.4, 16.5, 'Klassrum'],
#  [77.5, 28.7, 'Lärarrum'],
#  [67.5, 21.8, 'Klassrum'],
#  [71.5, 19.7, 'Lärarrum'],
#  [87.4, 19.1, 'Lärarrum'],
#  [92.4, 15.100000000000001, 'Lärarrum'],
#  [88.4, 21.4, 'Klassrum'],
#  [75.5, 18.7, 'Lärarrum'],
#  [72.5, 18.8, 'Klassrum'],
#  [73.5, 23.7, 'Lärarrum'],
#  [93.4, 28.4, 'Klassrum'],
#  [74.5, 23.7, 'Lärarrum'],
#  [79.5, 21.7, 'Lärarrum'],
#  [72.5, 22.7, 'Lärarrum'],
#  [81.4, 29.4, 'Klassrum'],
#  [71.5, 18.8, 'Klassrum'],
#  [87.4, 13.399999999999999, 'Klassrum'],
#  [90.4, 20.4, 'Klassrum'],
#  [84.4, 21.1, 'Lärarrum'],
#  [87.4, 24.4, 'Klassrum'],
#  [79.4, 26.5, 'Klassrum'],
#  [79.5, 26.8, 'Klassrum'],
#  [81.4, 20.1, 'Lärarrum'],
#  [84.4, 18.1, 'Lärarrum'],
#  [67.5, 21.8, 'Klassrum'],
#  [76.5, 21.7, 'Lärarrum'],
#  [70.5, 20.7, 'Lärarrum'],
#  [81.5, 15.8, 'Klassrum'],
#  [73.5, 17.8, 'Klassrum'],
#  [95.4, 23.4, 'Klassrum'],
#  [80.4, 23.5, 'Klassrum'],
#  [69.5, 16.8, 'Klassrum'],
#  [70.5, 17.8, 'Klassrum'],
#  [76.4, 19.4, 'Klassrum'],
#  [105.4, 20.5, 'Klassrum'],
#  [76.5, 19.7, 'Lärarrum'],
#  [89.4, 25.4, 'Klassrum'],
#  [88.4, 20.5, 'Klassrum'],
#  [89.4, 24.5, 'Klassrum'],
#  [65.5, 22.7, 'Lärarrum'],
#  [100.4, 26.5, 'Klassrum'],
#  [90.4, 19.1, 'Lärarrum'],
#  [67.5, 19.7, 'Lärarrum'],
#  [85.4, 14.100000000000001, 'Lärarrum'],
#  [78.4, 10.100000000000001, 'Lärarrum'],
#  [101.4, 17.5, 'Klassrum'],
#  [63.4, 22.1, 'Lärarrum'],
#  [96.4, 15.5, 'Klassrum'],
#  [74.4, 18.5, 'Klassrum'],
#  [64.5, 22.8, 'Klassrum'],
#  [96.4, 19.5, 'Klassrum'],
#  [76.5, 19.7, 'Lärarrum'],
#  [87.4, 17.1, 'Lärarrum'],
#  [76.5, 19.7, 'Lärarrum'],
#  [79.4, 6.100000000000001, 'Lärarrum'],
#  [79.5, 21.8, 'Klassrum'],
#  [94.4, 21.5, 'Klassrum'],
#  [69.5, 26.7, 'Lärarrum'],
#  [66.5, 23.7, 'Lärarrum'],
#  [89.4, 17.1, 'Lärarrum'],
#  [72.5, 18.8, 'Klassrum'],
#  [96.4, 25.5, 'Klassrum'],
#  [76.5, 20.7, 'Lärarrum'],
#  [87.4, 24.5, 'Klassrum'],
#  [69.5, 18.7, 'Lärarrum'],
#  [83.4, 21.1, 'Lärarrum'],
#  [83.4, 20.5, 'Klassrum'],
#  [83.4, 18.1, 'Lärarrum'],
#  [93.4, 23.5, 'Klassrum'],
#  [89.4, 28.5, 'Klassrum'],
#  [92.4, 21.5, 'Klassrum'],
#  [87.4, 25.1, 'Lärarrum'],
#  [73.4, 21.1, 'Lärarrum'],
#  [76.5, 22.8, 'Klassrum'],
#  [62.5, 21.7, 'Lärarrum'],
#  [64.5, 19.8, 'Klassrum'],
#  [63.4, 9.4, 'Kylrum'],
#  [89.4, 26.1, 'Lärarrum'],
#  [71.5, 17.8, 'Klassrum'],
#  [96.4, 21.5, 'Klassrum'],
#  [83.4, 19.5, 'Klassrum'],
#  [77.4, 18.1, 'Lärarrum'],
#  [84.4, 13.100000000000001, 'Lärarrum'],
#  [79.4, 19.1, 'Lärarrum'],
#  [87.4, 19.5, 'Klassrum'],
#  [85.4, 24.4, 'Klassrum'],
#  [92.4, 25.4, 'Klassrum'],
#  [61.4, 23.1, 'Lärarrum'],
#  [73.5, 14.8, 'Klassrum'],
#  [84.4, 23.1, 'Lärarrum'],
#  [89.4, 22.1, 'Lärarrum'],
#  [80.5, 17.8, 'Klassrum'],
#  [93.4, 19.4, 'Klassrum'],
#  [77.5, 28.8, 'Klassrum'],
#  [88.4, 21.4, 'Klassrum'],
#  [83.4, 22.4, 'Klassrum'],
#  [97.4, 28.4, 'Klassrum'],
#  [81.4, 21.5, 'Klassrum'],
#  [104.4, 21.4, 'Klassrum'],
#  [91.4, 25.5, 'Klassrum'],
#  [62.5, 18.8, 'Klassrum'],
#  [73.4, 15.5, 'Klassrum'],
#  [89.4, 25.1, 'Lärarrum'],
#  [80.5, 17.8, 'Klassrum'],
#  [83.4, 20.1, 'Lärarrum'],
#  [58.4, 10.4, 'Kylrum'],
#  [83.4, 24.1, 'Lärarrum'],
#  [65.5, 20.8, 'Klassrum'],
#  [83.4, 24.5, 'Klassrum'],
#  [60.4, 13.4, 'Kylrum'],
#  [68.5, 21.8, 'Klassrum'],
#  [87.4, 24.1, 'Lärarrum'],
#  [91.4, 17.5, 'Klassrum'],
#  [87.4, 27.4, 'Klassrum'],
#  [72.5, 13.8, 'Klassrum'],
#  [77.4, 19.1, 'Lärarrum'],
#  [68.5, 16.8, 'Klassrum'],
#  [84.4, 16.4, 'Klassrum'],
#  [58.4, 17.1, 'Lärarrum'],
#  [93.4, 19.1, 'Lärarrum'],
#  [84.4, 24.1, 'Lärarrum'],
#  [97.4, 15.5, 'Klassrum'],
#  [62.5, 16.7, 'Lärarrum'],
#  [75.5, 21.7, 'Lärarrum'],
#  [77.4, 15.100000000000001, 'Lärarrum'],
#  [69.5, 20.7, 'Lärarrum'],
#  [96.4, 18.5, 'Klassrum'],
#  [110.4, 28.5, 'Klassrum'],
#  [76.4, 17.1, 'Lärarrum'],
#  [74.4, 20.1, 'Lärarrum'],
#  [81.4, 17.1, 'Lärarrum'],
#  [82.4, 21.4, 'Klassrum'],
#  [60.5, 15.8, 'Klassrum'],
#  [93.4, 23.1, 'Lärarrum'],
#  [86.4, 19.4, 'Klassrum'],
#  [74.5, 24.8, 'Klassrum'],
#  [92.4, 19.1, 'Lärarrum'],
#  [73.5, 20.8, 'Klassrum'],
#  [84.4, 24.1, 'Lärarrum'],
#  [74.4, 14.5, 'Klassrum'],
#  [63.5, 21.7, 'Lärarrum'],
#  [90.4, 28.4, 'Klassrum'],
#  [74.5, 21.7, 'Lärarrum'],
#  [79.5, 20.8, 'Klassrum'],
#  [72.4, 20.1, 'Lärarrum'],
#  [79.4, 20.1, 'Lärarrum'],
#  [71.5, 22.7, 'Lärarrum'],
#  [65.5, 22.7, 'Lärarrum'],
#  [57.4, 8.4, 'Kylrum'],
#  [83.4, 18.1, 'Lärarrum'],
#  [83.4, 11.100000000000001, 'Lärarrum'],
#  [63.5, 24.7, 'Lärarrum'],
#  [77.5, 21.7, 'Lärarrum'],
#  [77.4, 16.1, 'Lärarrum'],
#  [72.5, 27.7, 'Lärarrum'],
#  [71.4, 20.1, 'Lärarrum'],
#  [63.4, 22.1, 'Lärarrum'],
#  [83.4, 21.1, 'Lärarrum'],
#  [78.4, 13.100000000000001, 'Lärarrum'],
#  [75.4, 21.1, 'Lärarrum'],
#  [89.4, 22.1, 'Lärarrum'],
#  [88.4, 20.4, 'Klassrum'],
#  [90.4, 23.1, 'Lärarrum'],
#  [86.4, 21.5, 'Klassrum'],
#  [92.4, 21.5, 'Klassrum'],
#  [78.4, 21.1, 'Lärarrum'],
#  [74.5, 23.7, 'Lärarrum'],
#  [94.4, 24.4, 'Klassrum'],
#  [106.4, 16.5, 'Klassrum'],
#  [89.4, 18.5, 'Klassrum'],
#  [94.4, 18.1, 'Lärarrum'],
#  [77.4, 10.100000000000001, 'Lärarrum'],
#  [63.5, 20.8, 'Klassrum'],
#  [81.4, 16.1, 'Lärarrum'],
#  [80.4, 22.1, 'Lärarrum'],
#  [83.4, 26.5, 'Klassrum'],
#  [57.4, 20.1, 'Lärarrum'],
#  [97.4, 23.5, 'Klassrum'],
#  [109.4, 19.5, 'Klassrum'],
#  [68.5, 23.7, 'Lärarrum'],
#  [81.4, 20.1, 'Lärarrum'],
#  [62.5, 19.8, 'Klassrum'],
#  [82.4, 22.4, 'Klassrum'],
#  [76.5, 17.7, 'Lärarrum'],
#  [98.4, 16.5, 'Klassrum'],
#  [57.4, 19.1, 'Lärarrum'],
#  [81.4, 15.100000000000001, 'Lärarrum'],
#  [78.5, 24.8, 'Klassrum'],
#  [90.4, 18.5, 'Klassrum'],
#  [85.4, 23.5, 'Klassrum'],
#  [97.4, 12.5, 'Klassrum'],
#  [72.5, 17.7, 'Lärarrum'],
#  [62.4, 25.1, 'Lärarrum'],
#  [83.4, 24.5, 'Klassrum'],
#  [82.4, 23.4, 'Klassrum'],
#  [104.4, 15.5, 'Klassrum'],
#  [69.5, 17.8, 'Klassrum'],
#  [88.4, 18.1, 'Lärarrum'],
#  [88.4, 18.5, 'Klassrum'],
#  [83.4, 20.4, 'Klassrum'],
#  [93.4, 29.4, 'Klassrum'],
#  [91.4, 21.5, 'Klassrum'],
#  [81.4, 19.1, 'Lärarrum'],
#  [57.5, 20.8, 'Klassrum'],
#  [107.4, 20.5, 'Klassrum'],
#  [76.5, 21.7, 'Lärarrum'],
#  [91.4, 22.4, 'Klassrum'],
#  [80.4, 15.100000000000001, 'Lärarrum'],
#  [61.4, 16.4, 'Kylrum'],
#  [77.5, 27.7, 'Lärarrum'],
#  [88.4, 21.1, 'Lärarrum'],
#  [97.4, 29.5, 'Klassrum'],
#  [75.5, 24.7, 'Lärarrum'],
#  [100.4, 21.4, 'Klassrum'],
#  [101.4, 22.5, 'Klassrum'],
#  [71.5, 21.7, 'Lärarrum'],
#  [97.4, 13.100000000000001, 'Lärarrum'],
#  [60.4, 11.4, 'Kylrum'],
#  [73.4, 19.1, 'Lärarrum'],
#  [92.4, 21.4, 'Klassrum'],
#  [64.5, 19.8, 'Klassrum'],
#  [69.5, 14.7, 'Lärarrum'],
#  [73.4, 19.1, 'Lärarrum'],
#  [93.4, 21.5, 'Klassrum'],
#  [79.4, 20.1, 'Lärarrum'],
#  [89.4, 19.1, 'Lärarrum'],
#  [84.5, 18.8, 'Klassrum'],
#  [77.5, 17.7, 'Lärarrum'],
#  [88.4, 25.5, 'Klassrum'],
#  [86.4, 27.1, 'Lärarrum'],
#  [87.4, 15.100000000000001, 'Lärarrum'],
#  [102.4, 20.4, 'Klassrum'],
#  [84.4, 16.1, 'Lärarrum'],
#  [100.4, 15.5, 'Klassrum'],
#  [73.4, 20.1, 'Lärarrum'],
#  [92.4, 18.5, 'Klassrum'],
#  [81.4, 16.5, 'Klassrum'],
#  [93.4, 24.5, 'Klassrum'],
#  [81.5, 20.7, 'Lärarrum'],
#  [78.5, 20.8, 'Klassrum'],
#  [85.4, 13.5, 'Klassrum'],
#  [93.4, 19.5, 'Klassrum'],
#  [80.4, 27.4, 'Klassrum'],
#  [89.4, 17.5, 'Klassrum'],
#  [87.4, 20.4, 'Klassrum'],
#  [80.4, 24.4, 'Klassrum'],
#  [88.4, 19.5, 'Klassrum'],
#  [92.4, 20.4, 'Klassrum'],
#  [104.4, 15.399999999999999, 'Klassrum'],
#  [84.4, 23.4, 'Klassrum'],
#  [89.4, 10.100000000000001, 'Lärarrum'],
#  [61.4, 17.1, 'Lärarrum'],
#  [83.4, 17.5, 'Klassrum'],
#  [58.5, 20.8, 'Klassrum'],
#  [77.4, 20.1, 'Lärarrum'],
#  [64.5, 20.8, 'Klassrum'],
#  [88.4, 18.1, 'Lärarrum'],
#  [79.4, 25.1, 'Lärarrum'],
#  [67.5, 23.7, 'Lärarrum'],
#  [91.4, 26.4, 'Klassrum'],
#  [76.5, 24.8, 'Klassrum'],
#  [98.4, 26.4, 'Klassrum'],
#  [67.5, 18.7, 'Lärarrum'],
#  [74.5, 17.8, 'Klassrum'],
#  [78.4, 11.100000000000001, 'Lärarrum'],
#  [72.5, 19.7, 'Lärarrum'],
#  [88.4, 14.100000000000001, 'Lärarrum'],
#  [59.4, 15.4, 'Kylrum'],
#  [82.4, 23.1, 'Lärarrum'],
#  [79.4, 22.1, 'Lärarrum'],
#  [84.4, 19.1, 'Lärarrum'],
#  [86.4, 22.5, 'Klassrum'],
#  [71.5, 19.7, 'Lärarrum'],
#  [59.4, 26.1, 'Lärarrum'],
#  [85.4, 22.1, 'Lärarrum'],
#  [90.4, 25.1, 'Lärarrum'],
#  [57.4, 12.4, 'Kylrum'],
#  [68.4, 23.1, 'Lärarrum'],
#  [80.5, 23.7, 'Lärarrum'],
#  [64.4, 11.4, 'Kylrum'],
#  [69.5, 18.8, 'Klassrum'],
#  [82.4, 22.5, 'Klassrum'],
#  [85.4, 17.5, 'Klassrum'],
#  [68.5, 18.8, 'Klassrum'],
#  [81.4, 22.5, 'Klassrum'],
#  [94.4, 26.4, 'Klassrum'],
#  [88.4, 17.1, 'Lärarrum'],
#  [86.4, 19.1, 'Lärarrum'],
#  [99.4, 18.5, 'Klassrum'],
#  [83.4, 20.5, 'Klassrum'],
#  [82.4, 18.1, 'Lärarrum'],
#  [88.4, 24.1, 'Lärarrum'],
#  [97.4, 27.4, 'Klassrum'],
#  [99.4, 20.5, 'Klassrum'],
#  [72.5, 23.7, 'Lärarrum'],
#  [67.5, 19.7, 'Lärarrum'],
#  [71.5, 13.7, 'Lärarrum'],
#  [84.4, 16.5, 'Klassrum'],
#  [95.4, 22.5, 'Klassrum'],
#  [78.4, 28.4, 'Klassrum'],
#  [102.4, 19.4, 'Klassrum'],
#  [84.4, 20.4, 'Klassrum'],
#  [94.4, 20.4, 'Klassrum'],
#  [82.4, 24.4, 'Klassrum'],
#  [100.4, 17.5, 'Klassrum'],
#  [79.4, 18.1, 'Lärarrum'],
#  [61.4, 15.4, 'Kylrum'],
#  [81.4, 22.5, 'Klassrum'],
#  [86.4, 17.1, 'Lärarrum'],
#  [86.4, 24.4, 'Klassrum'],
#  [88.4, 20.5, 'Klassrum'],
#  [91.4, 26.5, 'Klassrum'],
#  [83.4, 18.4, 'Klassrum'],
#  [81.5, 22.7, 'Lärarrum'],
#  [81.5, 19.7, 'Lärarrum'],
#  [60.5, 20.8, 'Klassrum'],
#  [86.4, 15.5, 'Klassrum'],
#  [81.4, 9.100000000000001, 'Lärarrum'],
#  [77.4, 18.1, 'Lärarrum'],
#  ...]

# %%
# And the false rows contain two types of fruit. Not too bad.
false_rows
# Out:
# [[54.4, 14.4, 'Kylrum'],
#  [45.4, 12.4, 'Kylrum'],
#  [22.4, 8.6, 'Kylrum'],
#  [24.4, 11.24, 'Kylrum'],
#  [23.4, 5.6, 'Kylrum'],
#  [18.4, 4.6, 'Kylrum'],
#  [26.4, 11.6, 'Kylrum'],
#  [41.4, 11.4, 'Kylrum'],
#  [20.4, 3.5999999999999996, 'Kylrum'],
#  [16.4, 5.6, 'Kylrum'],
#  [43.4, 13.4, 'Kylrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [43.4, 12.4, 'Kylrum'],
#  [53.4, 13.4, 'Kylrum'],
#  [18.4, 0.5999999999999996, 'Kylrum'],
#  [16.4, 6.6, 'Kylrum'],
#  [17.4, -2.4000000000000004, 'Kylrum'],
#  [44.4, 13.4, 'Kylrum'],
#  [38.4, 13.4, 'Kylrum'],
#  [13.399999999999999, 6.6, 'Kylrum'],
#  [19.4, 11.6, 'Kylrum'],
#  [19.4, -1.4000000000000004, 'Kylrum'],
#  [41.4, 9.4, 'Kylrum'],
#  [22.4, 5.6, 'Kylrum'],
#  [38.4, 11.4, 'Kylrum'],
#  [19.4, 1.5999999999999996, 'Kylrum'],
#  [51.4, 13.4, 'Kylrum'],
#  [16.4, 13.6, 'Kylrum'],
#  [27.4, 9.6, 'Kylrum'],
#  [23.4, 0.5999999999999996, 'Kylrum'],
#  [39.4, 13.4, 'Kylrum'],
#  [47.4, 10.4, 'Kylrum'],
#  [17.4, 6.6, 'Kylrum'],
#  [15.399999999999999, 1.5999999999999996, 'Kylrum'],
#  [21.4, -1.4000000000000004, 'Kylrum'],
#  [53.4, 11.4, 'Kylrum'],
#  [42.4, 13.4, 'Kylrum'],
#  [20.4, -0.40000000000000036, 'Kylrum'],
#  [18.4, 8.6, 'Kylrum'],
#  [20.4, 1.5999999999999996, 'Kylrum'],
#  [18.4, 3.5999999999999996, 'Kylrum'],
#  [36.4, 11.4, 'Kylrum'],
#  [38.4, 13.4, 'Kylrum'],
#  [24.4, 2.5999999999999996, 'Kylrum'],
#  [44.4, 12.4, 'Kylrum'],
#  [24.4, 9.6, 'Kylrum'],
#  [15.399999999999999, 5.6, 'Kylrum'],
#  [14.399999999999999, -2.4000000000000004, 'Kylrum'],
#  [55.4, 21.1, 'Lärarrum'],
#  [43.4, 13.4, 'Kylrum'],
#  [27.4, 10.6, 'Kylrum'],
#  [56.4, 13.4, 'Kylrum'],
#  [19.4, 6.6, 'Kylrum'],
#  [47.4, 11.4, 'Kylrum'],
#  [46.4, 10.4, 'Kylrum'],
#  [23.4, 2.5999999999999996, 'Kylrum'],
#  [18.4, 2.5999999999999996, 'Kylrum'],
#  [41.4, 13.4, 'Kylrum'],
#  [14.399999999999999, -1.4000000000000004, 'Kylrum'],
#  [44.4, 10.4, 'Kylrum'],
#  [13.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [51.4, 12.4, 'Kylrum'],
#  [20.4, 7.6, 'Kylrum'],
#  [39.4, 11.4, 'Kylrum'],
#  [20.4, 6.6, 'Kylrum'],
#  [54.4, 15.4, 'Kylrum'],
#  [36.4, 11.4, 'Kylrum'],
#  [51.4, 14.4, 'Kylrum'],
#  [56.4, 13.4, 'Kylrum'],
#  [38.4, 14.4, 'Kylrum'],
#  [55.4, 9.4, 'Kylrum'],
#  [26.4, 2.5999999999999996, 'Kylrum'],
#  [36.4, 11.4, 'Kylrum'],
#  [23.4, 9.6, 'Kylrum'],
#  [16.4, 4.6, 'Kylrum'],
#  [9.399999999999999, 4.6, 'Kylrum'],
#  [12.399999999999999, 7.6, 'Kylrum'],
#  [56.4, 12.4, 'Kylrum'],
#  [24.4, -2.4000000000000004, 'Kylrum'],
#  [18.4, 6.6, 'Kylrum'],
#  [25.4, 9.6, 'Kylrum'],
#  [26.4, 11.6, 'Kylrum'],
#  [33.4, 11.4, 'Kylrum'],
#  [21.4, 7.6, 'Kylrum'],
#  [40.4, 14.4, 'Kylrum'],
#  [16.4, 4.6, 'Kylrum'],
#  [25.4, 10.6, 'Kylrum'],
#  [14.399999999999999, 4.6, 'Kylrum'],
#  [16.4, -2.4000000000000004, 'Kylrum'],
#  [19.4, -1.4000000000000004, 'Kylrum'],
#  [54.4, 13.4, 'Kylrum'],
#  [20.4, 9.6, 'Kylrum'],
#  [37.4, 9.4, 'Kylrum'],
#  [23.4, 10.6, 'Kylrum'],
#  [11.399999999999999, 4.6, 'Kylrum'],
#  [11.399999999999999, 2.5999999999999996, 'Kylrum'],
#  [18.4, -2.4000000000000004, 'Kylrum'],
#  [16.4, -0.40000000000000036, 'Kylrum'],
#  [25.4, 8.6, 'Kylrum'],
#  [23.4, 0.5999999999999996, 'Kylrum'],
#  [56.4, 14.4, 'Kylrum'],
#  [53.4, 11.4, 'Kylrum'],
#  [19.4, 5.6, 'Kylrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [15.399999999999999, 7.6, 'Kylrum'],
#  [52.4, 11.4, 'Kylrum'],
#  [53.4, 19.1, 'Lärarrum'],
#  [50.4, 8.4, 'Kylrum'],
#  [45.4, 10.4, 'Kylrum'],
#  [18.4, 8.6, 'Kylrum'],
#  [24.4, 10.6, 'Kylrum'],
#  [13.399999999999999, 0.5999999999999996, 'Kylrum'],
#  [48.4, 11.4, 'Kylrum'],
#  [13.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [37.4, 11.4, 'Kylrum'],
#  [37.4, 13.4, 'Kylrum'],
#  [46.4, 12.4, 'Kylrum'],
#  [46.4, 10.4, 'Kylrum'],
#  [22.4, -0.40000000000000036, 'Kylrum'],
#  [14.399999999999999, -3.4000000000000004, 'Kylrum'],
#  [24.4, 2.5999999999999996, 'Kylrum'],
#  [38.4, 12.4, 'Kylrum'],
#  [27.4, 10.6, 'Kylrum'],
#  [37.4, 11.4, 'Kylrum'],
#  [13.399999999999999, 0.5999999999999996, 'Kylrum'],
#  [20.4, 5.6, 'Kylrum'],
#  [40.4, 13.4, 'Kylrum'],
#  [49.4, 8.4, 'Kylrum'],
#  [15.399999999999999, 0.5999999999999996, 'Kylrum'],
#  [21.4, -3.4000000000000004, 'Kylrum'],
#  [17.4, -5.4, 'Kylrum'],
#  [26.4, 7.6, 'Kylrum'],
#  [17.4, 14.6, 'Kylrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [14.399999999999999, -6.4, 'Kylrum'],
#  [43.4, 13.4, 'Kylrum'],
#  [54.4, 16.4, 'Kylrum'],
#  [13.399999999999999, 5.6, 'Kylrum'],
#  [34.4, 15.4, 'Kylrum'],
#  [15.399999999999999, 1.5999999999999996, 'Kylrum'],
#  [42.4, 13.4, 'Kylrum'],
#  [22.4, 0.5999999999999996, 'Kylrum'],
#  [20.4, 5.6, 'Kylrum'],
#  [24.4, 5.6, 'Kylrum'],
#  [14.399999999999999, 16.6, 'Kylrum'],
#  [17.4, 4.6, 'Kylrum'],
#  [17.4, -1.4000000000000004, 'Kylrum'],
#  [18.4, -0.40000000000000036, 'Kylrum'],
#  [40.4, 11.4, 'Kylrum'],
#  [43.4, 10.4, 'Kylrum'],
#  [42.4, 11.4, 'Kylrum'],
#  [46.4, 12.4, 'Kylrum'],
#  [52.4, 15.4, 'Kylrum'],
#  [21.4, -1.4000000000000004, 'Kylrum'],
#  [17.4, 4.6, 'Kylrum'],
#  [25.4, 6.6, 'Kylrum'],
#  [36.4, 13.4, 'Kylrum'],
#  [41.4, 9.4, 'Kylrum'],
#  [14.399999999999999, -3.4000000000000004, 'Kylrum'],
#  [25.4, -3.4000000000000004, 'Kylrum'],
#  [29.4, 7.6, 'Kylrum'],
#  [37.4, 9.4, 'Kylrum'],
#  [15.399999999999999, 6.6, 'Kylrum'],
#  [19.4, -2.4000000000000004, 'Kylrum'],
#  [25.4, 10.6, 'Kylrum'],
#  [17.4, 0.5999999999999996, 'Kylrum'],
#  [31.4, 13.6, 'Kylrum'],
#  [39.4, 10.4, 'Kylrum'],
#  [51.4, 13.399999999999999, 'Kylrum'],
#  [28.4, 8.6, 'Kylrum'],
#  [17.4, 7.6, 'Kylrum'],
#  [36.4, 10.4, 'Kylrum'],
#  [24.4, 0.5999999999999996, 'Kylrum'],
#  [24.4, 7.6, 'Kylrum'],
#  [28.4, 1.5999999999999996, 'Kylrum'],
#  [55.4, 15.4, 'Kylrum'],
#  [49.4, 12.4, 'Kylrum'],
#  [30.4, 12.6, 'Kylrum'],
#  [37.4, 11.4, 'Kylrum'],
#  [11.399999999999999, -8.4, 'Kylrum'],
#  [40.4, 11.4, 'Kylrum'],
#  [51.4, 17.4, 'Kylrum'],
#  [20.4, 4.6, 'Kylrum'],
#  [33.4, 13.4, 'Kylrum'],
#  [38.4, 14.4, 'Kylrum'],
#  [16.4, 1.5999999999999996, 'Kylrum'],
#  [18.4, 7.6, 'Kylrum'],
#  [14.399999999999999, -3.4000000000000004, 'Kylrum'],
#  [45.4, 14.4, 'Kylrum'],
#  [11.399999999999999, -9.4, 'Kylrum'],
#  [44.4, 11.4, 'Kylrum'],
#  [53.4, 14.4, 'Kylrum'],
#  [15.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [51.4, 15.4, 'Kylrum'],
#  [49.4, 12.4, 'Kylrum'],
#  [35.4, 13.4, 'Kylrum'],
#  [39.4, 10.4, 'Kylrum'],
#  [13.399999999999999, 4.6, 'Kylrum'],
#  [44.4, 10.4, 'Kylrum'],
#  [17.4, 0.5999999999999996, 'Kylrum'],
#  [29.4, 10.6, 'Kylrum'],
#  [36.4, 15.4, 'Kylrum'],
#  [41.4, 12.4, 'Kylrum'],
#  [17.4, 13.600000000000001, 'Kylrum'],
#  [35.4, 14.6, 'Kylrum'],
#  [21.4, 1.5999999999999996, 'Kylrum'],
#  [44.4, 8.4, 'Kylrum'],
#  [21.4, 8.6, 'Kylrum'],
#  [17.4, 3.5999999999999996, 'Kylrum'],
#  [45.4, 14.4, 'Kylrum'],
#  [25.4, 3.5999999999999996, 'Kylrum'],
#  [39.4, 13.4, 'Kylrum'],
#  [36.4, 12.4, 'Kylrum'],
#  [18.4, 0.5999999999999996, 'Kylrum'],
#  [48.4, 12.4, 'Kylrum'],
#  [42.4, 11.4, 'Kylrum'],
#  [23.4, 8.6, 'Kylrum'],
#  [49.4, 11.4, 'Kylrum'],
#  [18.4, 7.6, 'Kylrum'],
#  [46.4, 8.4, 'Kylrum'],
#  [21.4, 10.6, 'Kylrum'],
#  [15.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [16.4, 5.6, 'Kylrum'],
#  [23.4, 10.6, 'Kylrum'],
#  [28.4, 2.5999999999999996, 'Kylrum'],
#  [23.4, 7.6, 'Kylrum'],
#  [24.4, 12.6, 'Kylrum'],
#  [14.399999999999999, 7.6, 'Kylrum'],
#  [40.4, 14.4, 'Kylrum'],
#  [24.4, -0.40000000000000036, 'Kylrum'],
#  [24.4, 9.6, 'Kylrum'],
#  [15.399999999999999, 6.6, 'Kylrum'],
#  [14.399999999999999, -2.4000000000000004, 'Kylrum'],
#  [20.4, 10.6, 'Kylrum'],
#  [37.4, 17.4, 'Kylrum'],
#  [32.4, 8.6, 'Kylrum'],
#  [19.4, 0.5999999999999996, 'Kylrum'],
#  [20.4, 6.6, 'Kylrum'],
#  [46.4, 11.4, 'Kylrum'],
#  [33.4, 15.4, 'Kylrum'],
#  [41.4, 9.4, 'Kylrum'],
#  [44.4, 12.4, 'Kylrum'],
#  [24.4, 7.6, 'Kylrum'],
#  [20.4, 0.5999999999999996, 'Kylrum'],
#  [23.4, -4.4, 'Kylrum'],
#  [37.4, 10.4, 'Kylrum'],
#  [12.399999999999999, 0.5999999999999996, 'Kylrum'],
#  [14.399999999999999, 6.6, 'Kylrum'],
#  [51.4, 15.4, 'Kylrum'],
#  [21.4, 2.5999999999999996, 'Kylrum'],
#  [18.4, 5.6, 'Kylrum'],
#  [26.4, 13.6, 'Kylrum'],
#  [43.4, 13.4, 'Kylrum'],
#  [18.4, 1.5999999999999996, 'Kylrum'],
#  [15.399999999999999, -4.4, 'Kylrum'],
#  [44.4, 9.4, 'Kylrum'],
#  [14.399999999999999, 10.6, 'Kylrum'],
#  [56.4, 14.4, 'Kylrum'],
#  [43.4, 9.4, 'Kylrum'],
#  [24.4, 11.6, 'Kylrum'],
#  [10.399999999999999, -4.4, 'Kylrum'],
#  [30.4, 8.6, 'Kylrum'],
#  [16.4, -2.4000000000000004, 'Kylrum'],
#  [40.4, 14.4, 'Kylrum'],
#  [13.399999999999999, -4.4, 'Kylrum'],
#  [42.4, 9.4, 'Kylrum'],
#  [32.4, 12.4, 'Kylrum'],
#  [10.399999999999999, 5.6, 'Kylrum'],
#  [49.4, 11.4, 'Kylrum'],
#  [21.4, 8.6, 'Kylrum'],
#  [16.4, 2.5999999999999996, 'Kylrum'],
#  [24.4, -3.4000000000000004, 'Kylrum'],
#  [54.4, 15.4, 'Kylrum'],
#  [24.4, 5.6, 'Kylrum'],
#  [39.4, 9.4, 'Kylrum'],
#  [29.4, 10.6, 'Kylrum'],
#  [43.4, 12.4, 'Kylrum'],
#  [18.4, 4.6, 'Kylrum'],
#  [53.4, 14.4, 'Kylrum'],
#  [43.4, 9.4, 'Kylrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [16.4, -7.4, 'Kylrum'],
#  [26.4, 7.6, 'Kylrum'],
#  [31.4, 7.6, 'Kylrum'],
#  [10.399999999999999, -9.4, 'Kylrum'],
#  [45.4, 10.4, 'Kylrum'],
#  [53.4, 14.4, 'Kylrum'],
#  [37.4, 13.4, 'Kylrum'],
#  [28.4, 12.6, 'Kylrum'],
#  [41.4, 14.4, 'Kylrum'],
#  [48.4, 10.4, 'Kylrum'],
#  [25.4, 6.6, 'Kylrum'],
#  [25.4, 9.6, 'Kylrum'],
#  [40.4, 10.4, 'Kylrum'],
#  [12.399999999999999, -1.4000000000000004, 'Kylrum'],
#  [14.399999999999999, 2.5999999999999996, 'Kylrum'],
#  [51.4, 7.4, 'Kylrum'],
#  [24.4, 7.6, 'Kylrum'],
#  [8.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [50.4, 13.4, 'Kylrum'],
#  [28.4, 11.6, 'Kylrum'],
#  [15.399999999999999, 6.6, 'Kylrum'],
#  [15.399999999999999, -1.4000000000000004, 'Kylrum'],
#  [12.399999999999999, -5.4, 'Kylrum'],
#  [19.4, 3.5999999999999996, 'Kylrum'],
#  [36.4, 17.4, 'Kylrum'],
#  [25.4, 7.6, 'Kylrum'],
#  [16.4, -1.4000000000000004, 'Kylrum'],
#  [42.4, 14.4, 'Kylrum'],
#  [37.4, 14.4, 'Kylrum'],
#  [51.4, 17.1, 'Lärarrum'],
#  [14.399999999999999, -7.4, 'Kylrum'],
#  [52.4, 13.4, 'Kylrum'],
#  [27.4, 2.5999999999999996, 'Kylrum'],
#  [19.4, 4.6, 'Kylrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [51.4, 11.4, 'Kylrum'],
#  [54.4, 16.4, 'Kylrum'],
#  [41.4, 11.4, 'Kylrum'],
#  [53.4, 11.4, 'Kylrum'],
#  [54.4, 13.4, 'Kylrum'],
#  [17.4, 4.6, 'Kylrum'],
#  [34.4, 16.4, 'Kylrum'],
#  [42.4, 14.4, 'Kylrum'],
#  [10.399999999999999, 2.5999999999999996, 'Kylrum'],
#  [43.4, 12.4, 'Kylrum'],
#  [19.4, 6.6, 'Kylrum'],
#  [29.4, 14.6, 'Kylrum'],
#  [16.4, -6.4, 'Kylrum'],
#  [24.4, 4.6, 'Kylrum'],
#  [45.4, 15.4, 'Kylrum'],
#  [32.4, 7.4, 'Kylrum'],
#  [27.4, 2.5999999999999996, 'Kylrum'],
#  [56.4, 14.4, 'Kylrum'],
#  [12.399999999999999, -6.4, 'Kylrum'],
#  [15.399999999999999, 4.6, 'Kylrum'],
#  [17.4, 13.6, 'Kylrum'],
#  [42.4, 8.4, 'Kylrum'],
#  [14.399999999999999, 0.5999999999999996, 'Kylrum'],
#  [38.4, 12.4, 'Kylrum'],
#  [53.4, 16.4, 'Kylrum'],
#  [41.4, 10.4, 'Kylrum'],
#  [27.4, 0.5999999999999996, 'Kylrum'],
#  [27.4, 8.6, 'Kylrum'],
#  [21.4, 5.6, 'Kylrum'],
#  [33.4, 15.6, 'Kylrum'],
#  [23.4, 9.6, 'Kylrum'],
#  [30.4, 5.6, 'Kylrum'],
#  [40.4, 13.4, 'Kylrum'],
#  [36.4, 17.4, 'Kylrum'],
#  [51.4, 15.4, 'Kylrum'],
#  [25.4, 2.5999999999999996, 'Kylrum'],
#  [20.4, 7.6, 'Kylrum'],
#  [18.4, 5.6, 'Kylrum'],
#  [19.4, 11.6, 'Kylrum'],
#  [33.4, 15.4, 'Kylrum'],
#  [16.4, 6.6, 'Kylrum'],
#  [34.4, 13.4, 'Kylrum'],
#  [45.4, 12.4, 'Kylrum'],
#  [22.4, 5.6, 'Kylrum'],
#  [39.4, 11.4, 'Kylrum'],
#  [13.399999999999999, -3.4000000000000004, 'Kylrum'],
#  [23.4, 9.6, 'Kylrum'],
#  [30.4, -0.40000000000000036, 'Kylrum'],
#  [18.4, -3.4000000000000004, 'Kylrum'],
#  [42.4, 15.4, 'Kylrum'],
#  [15.399999999999999, -8.4, 'Kylrum'],
#  [54.4, 17.4, 'Kylrum'],
#  [17.4, 5.6, 'Kylrum'],
#  [26.4, 12.6, 'Kylrum'],
#  [16.4, 4.6, 'Kylrum'],
#  [38.4, 16.4, 'Kylrum'],
#  [12.399999999999999, -4.4, 'Kylrum'],
#  [18.4, 8.6, 'Kylrum'],
#  [54.4, 15.399999999999999, 'Kylrum'],
#  [14.399999999999999, 2.5999999999999996, 'Kylrum'],
#  [20.4, 10.6, 'Kylrum'],
#  [18.4, 1.5999999999999996, 'Kylrum'],
#  [17.4, 0.5999999999999996, 'Kylrum'],
#  [26.4, 11.6, 'Kylrum'],
#  [16.4, 7.6, 'Kylrum'],
#  [21.4, 10.6, 'Kylrum'],
#  [20.4, 0.5999999999999996, 'Kylrum'],
#  [35.4, 14.4, 'Kylrum'],
#  [52.4, 16.4, 'Kylrum'],
#  [35.4, 14.4, 'Kylrum'],
#  [24.4, -2.4000000000000004, 'Kylrum'],
#  [17.4, 5.6, 'Kylrum'],
#  [23.4, 11.6, 'Kylrum'],
#  [16.4, -11.4, 'Kylrum'],
#  [22.4, 2.5999999999999996, 'Kylrum'],
#  [52.4, 12.4, 'Kylrum'],
#  [18.4, 8.6, 'Kylrum'],
#  [14.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [18.4, 7.6, 'Kylrum'],
#  [43.4, 14.4, 'Kylrum'],
#  [16.4, -0.40000000000000036, 'Kylrum'],
#  [52.4, 12.4, 'Kylrum'],
#  [20.4, 4.6, 'Kylrum'],
#  [33.4, 12.4, 'Kylrum'],
#  [38.4, 13.4, 'Kylrum'],
#  [16.4, 6.6, 'Kylrum'],
#  [13.399999999999999, -3.4000000000000004, 'Kylrum'],
#  [48.4, 9.4, 'Kylrum'],
#  [16.4, 3.5999999999999996, 'Kylrum'],
#  [37.4, 12.4, 'Kylrum'],
#  [44.4, 9.4, 'Kylrum'],
#  [10.399999999999999, -0.40000000000000036, 'Kylrum'],
#  [48.4, 11.4, 'Kylrum'],
#  [54.4, 18.4, 'Kylrum'],
#  [21.4, -2.4000000000000004, 'Kylrum'],
#  [21.4, -3.4000000000000004, 'Kylrum'],
#  [36.4, 14.4, 'Kylrum'],
#  [25.4, 8.6, 'Kylrum'],
#  [44.4, 8.4, 'Kylrum'],
#  [17.4, 4.6, 'Kylrum'],
#  [25.4, 9.6, 'Kylrum'],
#  [39.4, 10.4, 'Kylrum'],
#  [32.4, 13.4, 'Kylrum'],
#  [23.4, 3.5999999999999996, 'Kylrum'],
#  [38.4, 15.4, 'Kylrum'],
#  [44.4, 15.4, 'Kylrum'],
#  [14.399999999999999, 12.6, 'Kylrum'],
#  [21.4, 11.6, 'Kylrum'],
#  [36.4, 12.4, 'Kylrum'],
#  [40.4, 15.4, 'Kylrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [30.4, 6.6, 'Kylrum'],
#  [12.399999999999999, 8.6, 'Kylrum'],
#  [23.4, 5.6, 'Kylrum'],
#  [52.4, 8.4, 'Kylrum'],
#  [54.4, 9.4, 'Kylrum'],
#  [23.4, 3.5999999999999996, 'Kylrum'],
#  [42.4, 14.4, 'Kylrum'],
#  [38.4, 13.4, 'Kylrum'],
#  [19.4, -0.40000000000000036, 'Kylrum'],
#  [34.4, -2.4000000000000004, 'Kylrum'],
#  [56.4, 13.4, 'Kylrum'],
#  [27.4, -0.40000000000000036, 'Kylrum'],
#  [46.4, 14.4, 'Kylrum'],
#  [44.4, 11.4, 'Kylrum'],
#  [13.399999999999999, 15.6, 'Kylrum'],
#  [14.399999999999999, -0.40000000000000036, 'Kylrum'],
#  [22.4, 3.5999999999999996, 'Kylrum'],
#  [20.4, 4.6, 'Kylrum'],
#  [42.4, 13.4, 'Kylrum'],
#  [49.4, 11.4, 'Kylrum'],
#  [18.4, -5.4, 'Kylrum'],
#  [27.4, 7.6, 'Kylrum'],
#  [8.399999999999999, -5.4, 'Kylrum'],
#  [35.4, -0.40000000000000036, 'Kylrum'],
#  [48.4, 17.4, 'Kylrum'],
#  [42.4, 14.4, 'Kylrum'],
#  [13.399999999999999, -8.4, 'Kylrum'],
#  [18.4, 7.6, 'Kylrum'],
#  [41.4, 17.4, 'Kylrum'],
#  [15.399999999999999, 4.6, 'Kylrum'],
#  [21.4, 1.5999999999999996, 'Kylrum'],
#  [16.4, 12.6, 'Kylrum'],
#  [56.4, 15.4, 'Kylrum'],
#  [29.4, 5.6, 'Kylrum'],
#  [21.4, 4.6, 'Kylrum'],
#  [10.399999999999999, 0.5999999999999996, 'Kylrum'],
#  [28.4, 2.5999999999999996, 'Kylrum'],
#  [27.4, 13.6, 'Kylrum'],
#  [31.4, 13.6, 'Kylrum'],
#  [11.399999999999999, 1.5999999999999996, 'Kylrum'],
#  [53.4, 17.4, 'Kylrum'],
#  [35.4, 14.4, 'Kylrum'],
#  [17.4, 1.5999999999999996, 'Kylrum'],
#  [27.4, 8.6, 'Kylrum'],
#  [54.4, 15.4, 'Kylrum'],
#  [32.4, 9.4, 'Kylrum'],
#  [53.4, 13.4, 'Kylrum'],
#  [39.4, 15.399999999999999, 'Kylrum'],
#  [12.399999999999999, -0.40000000000000036, 'Kylrum'],
#  [56.4, 14.4, 'Kylrum'],
#  [26.4, 2.5999999999999996, 'Kylrum'],
#  [31.4, 12.6, 'Kylrum'],
#  [24.4, 13.6, 'Kylrum'],
#  [31.4, 10.4, 'Kylrum'],
#  [32.4, 11.4, 'Kylrum'],
#  [21.4, 3.5999999999999996, 'Kylrum'],
#  [40.4, 13.4, 'Kylrum'],
#  [20.4, 1.5999999999999996, 'Kylrum'],
#  [39.4, 7.4, 'Kylrum'],
#  [16.4, 8.6, 'Kylrum'],
#  [16.4, 6.6, 'Kylrum'],
#  [56.4, 15.4, 'Kylrum'],
#  [16.4, 3.5999999999999996, 'Kylrum'],
#  [15.399999999999999, 0.5999999999999996, 'Kylrum'],
#  [23.4, 8.6, 'Kylrum'],
#  [25.4, 4.6, 'Kylrum'],
#  [43.4, 12.4, 'Kylrum'],
#  [31.4, 5.6, 'Kylrum'],
#  [19.4, 8.6, 'Kylrum'],
#  [17.4, 1.5999999999999996, 'Kylrum'],
#  [14.399999999999999, 17.6, 'Kylrum'],
#  [19.4, 4.6, 'Kylrum'],
#  [13.399999999999999, 6.6, 'Kylrum'],
#  [16.4, -6.4, 'Kylrum'],
#  [13.399999999999999, -8.4, 'Kylrum'],
#  [39.4, 15.4, 'Kylrum'],
#  [51.4, 14.4, 'Kylrum'],
#  [28.4, 14.6, 'Kylrum'],
#  [27.4, 10.6, 'Kylrum'],
#  [45.4, 5.4, 'Kylrum'],
#  [38.4, 9.4, 'Kylrum'],
#  [33.4, 17.4, 'Kylrum'],
#  [12.399999999999999, 4.6, 'Kylrum'],
#  [25.4, -0.40000000000000036, 'Kylrum'],
#  [51.4, 21.1, 'Lärarrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [20.4, 1.5999999999999996, 'Kylrum'],
#  [56.4, 19.4, 'Kylrum'],
#  [45.4, 12.4, 'Kylrum'],
#  [42.4, 12.4, 'Kylrum'],
#  [26.4, 1.5999999999999996, 'Kylrum'],
#  [28.4, 10.4, 'Kylrum'],
#  [8.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [51.4, 11.4, 'Kylrum'],
#  [26.4, 6.6, 'Kylrum'],
#  [22.4, 3.5999999999999996, 'Kylrum'],
#  [18.4, -4.4, 'Kylrum'],
#  [47.4, 9.4, 'Kylrum'],
#  [26.4, -4.4, 'Kylrum'],
#  [27.4, 6.6, 'Kylrum'],
#  [49.4, 15.399999999999999, 'Kylrum'],
#  [25.4, 9.24, 'Kylrum'],
#  [39.4, 13.4, 'Kylrum'],
#  [28.4, 5.6, 'Kylrum'],
#  [35.4, 10.4, 'Kylrum'],
#  [19.4, -4.4, 'Kylrum'],
#  [27.4, 11.6, 'Kylrum'],
#  [21.4, 8.6, 'Kylrum'],
#  [19.4, 8.6, 'Kylrum'],
#  [49.4, 20.4, 'Kylrum'],
#  [24.4, -2.4000000000000004, 'Kylrum'],
#  [18.4, 0.5999999999999996, 'Kylrum'],
#  [22.4, -3.4000000000000004, 'Kylrum'],
#  [21.4, 7.6, 'Kylrum'],
#  [51.4, 8.4, 'Kylrum'],
#  [12.399999999999999, -7.4, 'Kylrum'],
#  [31.4, 3.5999999999999996, 'Kylrum'],
#  [51.4, 7.4, 'Kylrum'],
#  [43.4, 16.4, 'Kylrum'],
#  [18.4, 1.5999999999999996, 'Kylrum'],
#  [53.4, 12.4, 'Kylrum'],
#  [13.399999999999999, -8.4, 'Kylrum'],
#  [54.4, 13.4, 'Kylrum'],
#  [5.399999999999999, 5.6, 'Kylrum'],
#  [12.399999999999999, 0.5999999999999996, 'Kylrum'],
#  [54.4, 11.4, 'Kylrum'],
#  [43.4, 14.4, 'Kylrum'],
#  [17.4, -7.4, 'Kylrum'],
#  [23.4, 7.6, 'Kylrum'],
#  [46.4, 10.4, 'Kylrum'],
#  [21.4, 9.6, 'Kylrum'],
#  [42.4, 16.4, 'Kylrum'],
#  [14.399999999999999, 7.6, 'Kylrum'],
#  [23.4, 4.6, 'Kylrum'],
#  [28.4, 9.6, 'Kylrum'],
#  [9.399999999999999, 13.6, 'Kylrum'],
#  [54.4, 8.4, 'Kylrum'],
#  [31.4, 16.4, 'Kylrum'],
#  [18.4, 1.5999999999999996, 'Kylrum'],
#  [16.4, 7.6, 'Kylrum'],
#  [17.4, 8.6, 'Kylrum'],
#  [20.4, 5.6, 'Kylrum'],
#  [17.4, -1.4000000000000004, 'Kylrum'],
#  [53.4, 17.4, 'Kylrum'],
#  [13.399999999999999, 7.6, 'Kylrum'],
#  [16.4, 7.6, 'Kylrum'],
#  [41.4, 17.4, 'Kylrum'],
#  [46.4, 10.4, 'Kylrum'],
#  [22.4, 5.6, 'Kylrum'],
#  [53.4, 6.4, 'Kylrum'],
#  [15.399999999999999, 5.6, 'Kylrum'],
#  [17.4, -3.4000000000000004, 'Kylrum'],
#  [16.4, 9.6, 'Kylrum'],
#  [27.4, 2.5999999999999996, 'Kylrum'],
#  [10.399999999999999, 1.5999999999999996, 'Kylrum'],
#  [27.4, 5.6, 'Kylrum'],
#  [47.4, 14.4, 'Kylrum'],
#  [49.4, 11.4, 'Kylrum'],
#  [45.4, 11.4, 'Kylrum'],
#  [38.4, 7.4, 'Kylrum'],
#  [15.399999999999999, -0.40000000000000036, 'Kylrum'],
#  [20.4, 1.5999999999999996, 'Kylrum'],
#  [40.4, 9.4, 'Kylrum'],
#  [17.4, 7.6, 'Kylrum'],
#  [18.4, 10.6, 'Kylrum'],
#  [19.4, 11.6, 'Kylrum'],
#  [54.4, 14.4, 'Kylrum'],
#  [30.4, 9.6, 'Kylrum'],
#  [32.4, 4.6, 'Kylrum'],
#  [14.399999999999999, 8.6, 'Kylrum'],
#  [41.4, 10.4, 'Kylrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [45.4, 11.4, 'Kylrum'],
#  [22.4, -0.40000000000000036, 'Kylrum'],
#  [41.4, 8.4, 'Kylrum'],
#  [29.4, 8.6, 'Kylrum'],
#  [21.4, 11.6, 'Kylrum'],
#  [14.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [38.4, 11.4, 'Kylrum'],
#  [43.4, 15.4, 'Kylrum'],
#  [53.4, 4.4, 'Kylrum'],
#  [26.4, 8.6, 'Kylrum'],
#  [45.4, 10.4, 'Kylrum'],
#  [16.4, 4.6, 'Kylrum'],
#  [12.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [13.399999999999999, -11.4, 'Kylrum'],
#  [24.4, 0.5999999999999996, 'Kylrum'],
#  [29.4, 8.6, 'Kylrum'],
#  [39.4, 12.4, 'Kylrum'],
#  [17.4, -0.40000000000000036, 'Kylrum'],
#  [24.4, 8.6, 'Kylrum'],
#  [41.4, 14.399999999999999, 'Kylrum'],
#  [56.4, 14.399999999999999, 'Kylrum'],
#  [27.4, 5.6, 'Kylrum'],
#  [56.4, 14.4, 'Kylrum'],
#  [18.4, 5.6, 'Kylrum'],
#  [19.4, 10.6, 'Kylrum'],
#  [17.4, -0.40000000000000036, 'Kylrum'],
#  [21.4, 0.5999999999999996, 'Kylrum'],
#  [16.4, 4.6, 'Kylrum'],
#  [48.4, 9.4, 'Kylrum'],
#  [7.399999999999999, 1.5999999999999996, 'Kylrum'],
#  [26.4, 9.6, 'Kylrum'],
#  [40.4, 10.4, 'Kylrum'],
#  [31.4, 0.5999999999999996, 'Kylrum'],
#  [15.399999999999999, -1.4000000000000004, 'Kylrum'],
#  [31.4, 16.4, 'Kylrum'],
#  [20.4, 10.6, 'Kylrum'],
#  [20.4, 9.6, 'Kylrum'],
#  [37.4, 16.4, 'Kylrum'],
#  [40.4, 10.4, 'Kylrum'],
#  [19.4, 5.6, 'Kylrum'],
#  [9.399999999999999, 1.5999999999999996, 'Kylrum'],
#  [20.4, 1.5999999999999996, 'Kylrum'],
#  [50.4, 13.4, 'Kylrum'],
#  [40.4, 8.4, 'Kylrum'],
#  [16.4, 3.5999999999999996, 'Kylrum'],
#  [7.399999999999999, 2.5999999999999996, 'Kylrum'],
#  [24.4, 10.6, 'Kylrum'],
#  [17.4, -0.40000000000000036, 'Kylrum'],
#  [42.4, 11.4, 'Kylrum'],
#  [20.4, 1.5999999999999996, 'Kylrum'],
#  [41.4, 13.4, 'Kylrum'],
#  [28.4, 6.6, 'Kylrum'],
#  [25.4, 11.6, 'Kylrum'],
#  [55.5, 19.7, 'Lärarrum'],
#  [26.4, 8.6, 'Kylrum'],
#  [36.4, 9.4, 'Kylrum'],
#  [49.4, 10.4, 'Kylrum'],
#  [50.4, 16.1, 'Lärarrum'],
#  [33.4, 8.6, 'Kylrum'],
#  [32.4, 8.4, 'Kylrum'],
#  [18.4, 4.6, 'Kylrum'],
#  [54.4, 14.4, 'Kylrum'],
#  [15.399999999999999, 6.6, 'Kylrum'],
#  [7.399999999999999, 5.6, 'Kylrum'],
#  [6.399999999999999, 2.5999999999999996, 'Kylrum'],
#  [49.4, 11.4, 'Kylrum'],
#  [23.4, 2.5999999999999996, 'Kylrum'],
#  [16.4, -2.4000000000000004, 'Kylrum'],
#  [35.4, 15.4, 'Kylrum'],
#  [13.399999999999999, 6.6, 'Kylrum'],
#  [44.4, 10.4, 'Kylrum'],
#  [27.4, 17.6, 'Kylrum'],
#  [39.4, 11.4, 'Kylrum'],
#  [19.4, 11.600000000000001, 'Kylrum'],
#  [28.4, 5.4, 'Kylrum'],
#  [16.4, 4.6, 'Kylrum'],
#  [13.399999999999999, -0.40000000000000036, 'Kylrum'],
#  [28.4, 11.6, 'Kylrum'],
#  [21.4, -2.4000000000000004, 'Kylrum'],
#  [51.4, 13.4, 'Kylrum'],
#  [14.399999999999999, -5.4, 'Kylrum'],
#  [19.4, -0.40000000000000036, 'Kylrum'],
#  [24.4, 5.6, 'Kylrum'],
#  [20.4, 7.6, 'Kylrum'],
#  [33.4, 5.6, 'Kylrum'],
#  [27.4, 13.6, 'Kylrum'],
#  [53.4, 11.4, 'Kylrum'],
#  [18.4, -4.4, 'Kylrum'],
#  [29.4, 16.6, 'Kylrum'],
#  [39.4, 8.4, 'Kylrum'],
#  [36.4, 14.399999999999999, 'Kylrum'],
#  [9.399999999999999, 12.6, 'Kylrum'],
#  [24.4, 7.6, 'Kylrum'],
#  [21.4, 13.6, 'Kylrum'],
#  [38.4, 15.4, 'Kylrum'],
#  [54.4, 12.4, 'Kylrum'],
#  [40.4, 10.4, 'Kylrum'],
#  [31.4, 12.4, 'Kylrum'],
#  [3.3999999999999986, 4.6, 'Kylrum'],
#  [38.4, 12.4, 'Kylrum'],
#  [19.4, 10.6, 'Kylrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [9.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [14.399999999999999, 6.6, 'Kylrum'],
#  [30.4, 12.4, 'Kylrum'],
#  [17.4, 5.6, 'Kylrum'],
#  [24.4, 3.5999999999999996, 'Kylrum'],
#  [36.4, 18.4, 'Kylrum'],
#  [15.399999999999999, 2.5999999999999996, 'Kylrum'],
#  [40.4, 14.4, 'Kylrum'],
#  [37.4, 13.4, 'Kylrum'],
#  [45.4, 15.4, 'Kylrum'],
#  [32.4, 13.6, 'Kylrum'],
#  [19.4, 4.6, 'Kylrum'],
#  [17.4, 7.6, 'Kylrum'],
#  [23.4, 0.5999999999999996, 'Kylrum'],
#  [41.4, 11.4, 'Kylrum'],
#  [52.4, 14.4, 'Kylrum'],
#  [31.4, 8.6, 'Kylrum'],
#  [17.4, 10.6, 'Kylrum'],
#  [54.4, 14.4, 'Kylrum'],
#  [38.4, 11.4, 'Kylrum'],
#  [53.4, 13.4, 'Kylrum'],
#  [43.4, 9.4, 'Kylrum'],
#  [13.399999999999999, 7.6, 'Kylrum'],
#  [21.4, -2.4000000000000004, 'Kylrum'],
#  [36.4, 11.4, 'Kylrum'],
#  [24.4, 1.5999999999999996, 'Kylrum'],
#  [17.4, 4.6, 'Kylrum'],
#  [12.399999999999999, -4.4, 'Kylrum'],
#  [23.4, 2.5999999999999996, 'Kylrum'],
#  [56.4, 11.4, 'Kylrum'],
#  [31.4, 12.4, 'Kylrum'],
#  [17.4, -1.4000000000000004, 'Kylrum'],
#  [22.4, 0.5999999999999996, 'Kylrum'],
#  [56.4, 12.4, 'Kylrum'],
#  [13.399999999999999, 2.5999999999999996, 'Kylrum'],
#  [48.4, 6.4, 'Kylrum'],
#  [27.4, 1.5999999999999996, 'Kylrum'],
#  [29.4, 11.6, 'Kylrum'],
#  [20.4, -3.4000000000000004, 'Kylrum'],
#  [56.4, 12.4, 'Kylrum'],
#  [20.4, 5.6, 'Kylrum'],
#  [13.399999999999999, 2.5999999999999996, 'Kylrum'],
#  [20.4, 9.6, 'Kylrum'],
#  [15.399999999999999, 4.6, 'Kylrum'],
#  [19.4, 0.5999999999999996, 'Kylrum'],
#  [39.4, 12.4, 'Kylrum'],
#  [25.4, 12.6, 'Kylrum'],
#  [19.4, 3.5999999999999996, 'Kylrum'],
#  [16.4, 6.6, 'Kylrum'],
#  [46.4, 11.4, 'Kylrum'],
#  [12.399999999999999, 1.5999999999999996, 'Kylrum'],
#  [27.4, 9.6, 'Kylrum'],
#  [16.4, 3.5999999999999996, 'Kylrum'],
#  [55.4, 17.4, 'Kylrum'],
#  [21.4, 5.6, 'Kylrum'],
#  [17.4, -2.4000000000000004, 'Kylrum'],
#  [36.4, 5.4, 'Kylrum'],
#  [34.4, 9.4, 'Kylrum'],
#  [30.4, 11.4, 'Kylrum'],
#  [51.4, 15.399999999999999, 'Kylrum'],
#  [36.4, 16.4, 'Kylrum'],
#  [13.399999999999999, -1.4000000000000004, 'Kylrum'],
#  [53.4, 14.4, 'Kylrum'],
#  [20.4, 12.6, 'Kylrum'],
#  [21.4, 11.6, 'Kylrum'],
#  [6.399999999999999, 1.5999999999999996, 'Kylrum'],
#  [22.4, 3.5999999999999996, 'Kylrum'],
#  [18.4, 1.5999999999999996, 'Kylrum'],
#  [55.4, 5.4, 'Kylrum'],
#  [18.4, 4.6, 'Kylrum'],
#  [36.4, 14.4, 'Kylrum'],
#  [56.4, 12.4, 'Kylrum'],
#  [34.4, 11.6, 'Kylrum'],
#  [16.4, 7.6, 'Kylrum'],
#  [32.4, 13.4, 'Kylrum'],
#  [56.4, 12.4, 'Kylrum'],
#  [27.4, 12.6, 'Kylrum'],
#  [17.4, -0.40000000000000036, 'Kylrum'],
#  [14.399999999999999, -7.4, 'Kylrum'],
#  [22.4, -3.4000000000000004, 'Kylrum'],
#  [19.4, 2.5999999999999996, 'Kylrum'],
#  [28.4, 6.6, 'Kylrum'],
#  [50.4, 4.4, 'Kylrum'],
#  [18.4, 1.5999999999999996, 'Kylrum'],
#  [31.4, 16.4, 'Kylrum'],
#  [46.4, 6.4, 'Kylrum'],
#  [22.4, 3.5999999999999996, 'Kylrum'],
#  [34.4, 13.4, 'Kylrum'],
#  [13.399999999999999, 5.6, 'Kylrum'],
#  [8.399999999999999, -7.4, 'Kylrum'],
#  [40.4, 12.4, 'Kylrum'],
#  [26.4, 12.6, 'Kylrum'],
#  [54.4, 19.1, 'Lärarrum'],
#  [18.4, 4.6, 'Kylrum'],
#  [15.399999999999999, 5.6, 'Kylrum'],
#  [44.4, 13.4, 'Kylrum'],
#  [22.4, -1.4000000000000004, 'Kylrum'],
#  [25.4, -1.4000000000000004, 'Kylrum'],
#  [42.4, 14.399999999999999, 'Kylrum'],
#  [39.4, 9.4, 'Kylrum'],
#  [22.4, 12.6, 'Kylrum'],
#  [43.4, 13.4, 'Kylrum'],
#  [18.4, -4.4, 'Kylrum'],
#  [53.4, 12.4, 'Kylrum'],
#  [20.4, 10.6, 'Kylrum'],
#  [23.4, 5.6, 'Kylrum'],
#  [20.4, 12.6, 'Kylrum'],
#  [39.4, 10.4, 'Kylrum'],
#  [16.4, 15.6, 'Kylrum'],
#  [31.4, 12.6, 'Kylrum'],
#  [15.399999999999999, 6.6, 'Kylrum'],
#  [56.4, 13.4, 'Kylrum'],
#  [19.4, 6.6, 'Kylrum'],
#  [49.4, 3.4000000000000004, 'Kylrum'],
#  [13.399999999999999, 9.6, 'Kylrum'],
#  [15.399999999999999, -9.4, 'Kylrum'],
#  [21.4, 3.5999999999999996, 'Kylrum'],
#  [22.4, 12.6, 'Kylrum'],
#  [32.4, 14.4, 'Kylrum'],
#  [5.399999999999999, 5.6, 'Kylrum'],
#  [22.4, 13.6, 'Kylrum'],
#  [21.4, 6.6, 'Kylrum'],
#  [36.4, 7.4, 'Kylrum'],
#  [33.4, 12.4, 'Kylrum'],
#  [54.4, 20.1, 'Lärarrum'],
#  [20.4, 6.6, 'Kylrum'],
#  [50.4, 14.4, 'Kylrum'],
#  [4.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [44.4, 11.4, 'Kylrum'],
#  [15.399999999999999, -5.4, 'Kylrum'],
#  [32.4, 7.6, 'Kylrum'],
#  [19.4, -7.4, 'Kylrum'],
#  [17.4, 7.6, 'Kylrum'],
#  [18.4, 2.5999999999999996, 'Kylrum'],
#  [49.4, 19.1, 'Lärarrum'],
#  [50.4, 11.4, 'Kylrum'],
#  [5.399999999999999, 6.6, 'Kylrum'],
#  [52.4, 4.4, 'Kylrum'],
#  [55.4, 7.4, 'Kylrum'],
#  [20.4, 6.6, 'Kylrum'],
#  [29.4, 4.6, 'Kylrum'],
#  [26.4, 0.5999999999999996, 'Kylrum'],
#  [40.4, 12.4, 'Kylrum'],
#  [19.4, -3.4000000000000004, 'Kylrum'],
#  [31.4, 3.5999999999999996, 'Kylrum'],
#  [14.399999999999999, 7.6, 'Kylrum'],
#  [26.4, 2.5999999999999996, 'Kylrum'],
#  [32.4, 11.4, 'Kylrum'],
#  [35.4, 10.4, 'Kylrum'],
#  [17.4, 10.6, 'Kylrum'],
#  [16.4, 6.6, 'Kylrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [10.399999999999999, 8.6, 'Kylrum'],
#  [7.399999999999999, -9.4, 'Kylrum'],
#  [21.4, 9.6, 'Kylrum'],
#  [17.4, 1.5999999999999996, 'Kylrum'],
#  [18.4, 6.6, 'Kylrum'],
#  [22.4, 4.6, 'Kylrum'],
#  [20.4, 6.6, 'Kylrum'],
#  [19.4, 9.6, 'Kylrum'],
#  [20.4, -0.40000000000000036, 'Kylrum'],
#  [39.4, 12.4, 'Kylrum'],
#  [22.4, 7.6, 'Kylrum'],
#  [18.4, 12.6, 'Kylrum'],
#  [30.4, 16.4, 'Kylrum'],
#  [37.4, 9.6, 'Kylrum'],
#  [19.4, 4.6, 'Kylrum'],
#  [33.4, 13.4, 'Kylrum'],
#  [15.399999999999999, -3.4000000000000004, 'Kylrum'],
#  [19.4, -1.4000000000000004, 'Kylrum'],
#  [54.4, 22.1, 'Lärarrum'],
#  [53.4, 13.4, 'Kylrum'],
#  [45.4, 16.4, 'Kylrum'],
#  [25.4, 4.6, 'Kylrum'],
#  [17.4, -6.4, 'Kylrum'],
#  [19.4, 5.6, 'Kylrum'],
#  [38.4, 7.4, 'Kylrum'],
#  [38.4, 9.4, 'Kylrum'],
#  [53.4, 6.4, 'Kylrum'],
#  [29.4, 9.4, 'Kylrum'],
#  [38.4, 10.4, 'Kylrum'],
#  [27.4, 1.5999999999999996, 'Kylrum'],
#  [46.4, 12.4, 'Kylrum'],
#  [56.4, 11.399999999999999, 'Kylrum'],
#  [55.4, 7.4, 'Kylrum'],
#  [14.399999999999999, -7.4, 'Kylrum'],
#  [25.4, 9.6, 'Kylrum'],
#  [23.4, 3.5999999999999996, 'Kylrum']]

# %%
# On the other hand, partitioning by Green doesn't help so much.
true_rows, false_rows = partition(training_data, Question(0, 30))

# We've isolated one apple in the true rows.
true_rows
# Out:
# [[54.4, 14.4, 'Kylrum'],
#  [45.4, 12.4, 'Kylrum'],
#  [89.4, 19.5, 'Klassrum'],
#  [57.4, 18.1, 'Lärarrum'],
#  [84.4, 24.4, 'Klassrum'],
#  [95.4, 22.4, 'Klassrum'],
#  [81.4, 20.1, 'Lärarrum'],
#  [70.5, 19.7, 'Lärarrum'],
#  [70.5, 19.8, 'Klassrum'],
#  [93.4, 22.4, 'Klassrum'],
#  [88.4, 22.5, 'Klassrum'],
#  [90.4, 20.5, 'Klassrum'],
#  [84.4, 18.1, 'Lärarrum'],
#  [82.4, 18.1, 'Lärarrum'],
#  [67.5, 18.7, 'Lärarrum'],
#  [78.4, 19.1, 'Lärarrum'],
#  [41.4, 11.4, 'Kylrum'],
#  [74.5, 19.8, 'Klassrum'],
#  [91.4, 21.5, 'Klassrum'],
#  [93.4, 21.5, 'Klassrum'],
#  [88.4, 20.1, 'Lärarrum'],
#  [84.4, 21.5, 'Klassrum'],
#  [43.4, 13.4, 'Kylrum'],
#  [94.4, 22.5, 'Klassrum'],
#  [43.4, 12.4, 'Kylrum'],
#  [53.4, 13.4, 'Kylrum'],
#  [89.4, 20.5, 'Klassrum'],
#  [63.5, 17.7, 'Lärarrum'],
#  [76.5, 18.8, 'Klassrum'],
#  [70.5, 21.7, 'Lärarrum'],
#  [84.4, 20.1, 'Lärarrum'],
#  [44.4, 13.4, 'Kylrum'],
#  [88.4, 24.4, 'Klassrum'],
#  [38.4, 13.4, 'Kylrum'],
#  [75.5, 22.8, 'Klassrum'],
#  [72.5, 21.8, 'Klassrum'],
#  [85.4, 18.1, 'Lärarrum'],
#  [83.4, 18.1, 'Lärarrum'],
#  [84.4, 22.1, 'Lärarrum'],
#  [41.4, 9.4, 'Kylrum'],
#  [38.4, 11.4, 'Kylrum'],
#  [51.4, 13.4, 'Kylrum'],
#  [81.4, 16.1, 'Lärarrum'],
#  [67.5, 15.7, 'Lärarrum'],
#  [70.5, 17.7, 'Lärarrum'],
#  [86.4, 22.4, 'Klassrum'],
#  [39.4, 13.4, 'Kylrum'],
#  [92.4, 24.4, 'Klassrum'],
#  [78.4, 22.1, 'Lärarrum'],
#  [87.4, 20.1, 'Lärarrum'],
#  [81.4, 23.1, 'Lärarrum'],
#  [47.4, 10.4, 'Kylrum'],
#  [92.4, 22.4, 'Klassrum'],
#  [73.5, 20.8, 'Klassrum'],
#  [78.4, 18.1, 'Lärarrum'],
#  [53.4, 11.4, 'Kylrum'],
#  [42.4, 13.4, 'Kylrum'],
#  [89.4, 23.4, 'Klassrum'],
#  [91.4, 21.4, 'Klassrum'],
#  [88.4, 23.4, 'Klassrum'],
#  [84.4, 15.100000000000001, 'Lärarrum'],
#  [87.4, 20.1, 'Lärarrum'],
#  [84.4, 18.1, 'Lärarrum'],
#  [80.4, 15.100000000000001, 'Lärarrum'],
#  [36.4, 11.4, 'Kylrum'],
#  [85.4, 21.4, 'Klassrum'],
#  [38.4, 13.4, 'Kylrum'],
#  [44.4, 12.4, 'Kylrum'],
#  [76.4, 15.100000000000001, 'Lärarrum'],
#  [94.4, 22.5, 'Klassrum'],
#  [71.5, 19.7, 'Lärarrum'],
#  [67.5, 20.7, 'Lärarrum'],
#  [91.4, 19.5, 'Klassrum'],
#  [55.4, 21.1, 'Lärarrum'],
#  [43.4, 13.4, 'Kylrum'],
#  [69.5, 24.8, 'Klassrum'],
#  [86.4, 17.1, 'Lärarrum'],
#  [75.5, 19.8, 'Klassrum'],
#  [72.5, 16.7, 'Lärarrum'],
#  [56.4, 13.4, 'Kylrum'],
#  [72.5, 20.8, 'Klassrum'],
#  [86.4, 19.4, 'Klassrum'],
#  [81.4, 22.1, 'Lärarrum'],
#  [47.4, 11.4, 'Kylrum'],
#  [73.5, 18.8, 'Klassrum'],
#  [74.5, 23.7, 'Lärarrum'],
#  [46.4, 10.4, 'Kylrum'],
#  [74.5, 21.8, 'Klassrum'],
#  [90.4, 26.4, 'Klassrum'],
#  [41.4, 13.4, 'Kylrum'],
#  [75.5, 17.8, 'Klassrum'],
#  [99.4, 24.5, 'Klassrum'],
#  [44.4, 10.4, 'Kylrum'],
#  [84.4, 20.5, 'Klassrum'],
#  [51.4, 12.4, 'Kylrum'],
#  [78.4, 23.1, 'Lärarrum'],
#  [78.4, 16.1, 'Lärarrum'],
#  [63.5, 22.7, 'Lärarrum'],
#  [72.5, 18.8, 'Klassrum'],
#  [39.4, 11.4, 'Kylrum'],
#  [82.4, 14.100000000000001, 'Lärarrum'],
#  [83.4, 19.1, 'Lärarrum'],
#  [94.4, 20.5, 'Klassrum'],
#  [54.4, 15.4, 'Kylrum'],
#  [36.4, 11.4, 'Kylrum'],
#  [51.4, 14.4, 'Kylrum'],
#  [90.4, 22.5, 'Klassrum'],
#  [56.4, 13.4, 'Kylrum'],
#  [38.4, 14.4, 'Kylrum'],
#  [92.4, 20.5, 'Klassrum'],
#  [59.4, 19.1, 'Lärarrum'],
#  [89.4, 19.5, 'Klassrum'],
#  [84.4, 16.1, 'Lärarrum'],
#  [93.4, 26.4, 'Klassrum'],
#  [93.4, 22.4, 'Klassrum'],
#  [55.4, 9.4, 'Kylrum'],
#  [36.4, 11.4, 'Kylrum'],
#  [95.4, 23.5, 'Klassrum'],
#  [93.4, 22.1, 'Lärarrum'],
#  [70.5, 17.8, 'Klassrum'],
#  [92.4, 24.5, 'Klassrum'],
#  [73.5, 18.8, 'Klassrum'],
#  [75.5, 25.7, 'Lärarrum'],
#  [58.4, 13.4, 'Kylrum'],
#  [56.4, 12.4, 'Kylrum'],
#  [59.4, 19.1, 'Lärarrum'],
#  [101.4, 22.5, 'Klassrum'],
#  [72.5, 16.8, 'Klassrum'],
#  [74.5, 21.7, 'Lärarrum'],
#  [72.5, 18.7, 'Lärarrum'],
#  [92.4, 28.4, 'Klassrum'],
#  [88.4, 25.5, 'Klassrum'],
#  [33.4, 11.4, 'Kylrum'],
#  [75.5, 23.8, 'Klassrum'],
#  [73.5, 22.7, 'Lärarrum'],
#  [85.4, 20.5, 'Klassrum'],
#  [78.5, 23.8, 'Klassrum'],
#  [95.4, 20.5, 'Klassrum'],
#  [73.5, 17.7, 'Lärarrum'],
#  [40.4, 14.4, 'Kylrum'],
#  [54.4, 13.4, 'Kylrum'],
#  [89.4, 20.5, 'Klassrum'],
#  [77.5, 23.8, 'Klassrum'],
#  [78.4, 19.1, 'Lärarrum'],
#  [66.5, 18.8, 'Klassrum'],
#  [76.5, 20.8, 'Klassrum'],
#  [74.5, 27.7, 'Lärarrum'],
#  [37.4, 9.4, 'Kylrum'],
#  [77.4, 15.100000000000001, 'Lärarrum'],
#  [82.4, 21.1, 'Lärarrum'],
#  [91.4, 23.5, 'Klassrum'],
#  [57.4, 13.4, 'Kylrum'],
#  [85.4, 23.5, 'Klassrum'],
#  [92.4, 21.4, 'Klassrum'],
#  [77.4, 21.1, 'Lärarrum'],
#  [79.5, 21.8, 'Klassrum'],
#  [68.5, 16.8, 'Klassrum'],
#  [74.5, 19.7, 'Lärarrum'],
#  [56.4, 14.4, 'Kylrum'],
#  [73.5, 15.8, 'Klassrum'],
#  [53.4, 11.4, 'Kylrum'],
#  [59.5, 21.7, 'Lärarrum'],
#  [87.4, 19.5, 'Klassrum'],
#  [69.5, 19.8, 'Klassrum'],
#  [83.4, 21.1, 'Lärarrum'],
#  [80.4, 25.1, 'Lärarrum'],
#  [52.4, 11.4, 'Kylrum'],
#  [53.4, 19.1, 'Lärarrum'],
#  [66.5, 18.8, 'Klassrum'],
#  [83.4, 22.4, 'Klassrum'],
#  [83.4, 18.5, 'Klassrum'],
#  [50.4, 8.4, 'Kylrum'],
#  [93.4, 20.5, 'Klassrum'],
#  [87.4, 17.1, 'Lärarrum'],
#  [45.4, 10.4, 'Kylrum'],
#  [73.5, 15.7, 'Lärarrum'],
#  [91.4, 20.1, 'Lärarrum'],
#  [84.4, 16.1, 'Lärarrum'],
#  [69.5, 15.8, 'Klassrum'],
#  [69.5, 23.7, 'Lärarrum'],
#  [84.4, 19.5, 'Klassrum'],
#  [94.4, 24.5, 'Klassrum'],
#  [65.5, 21.8, 'Klassrum'],
#  [48.4, 11.4, 'Kylrum'],
#  [94.4, 25.5, 'Klassrum'],
#  [87.4, 16.5, 'Klassrum'],
#  [37.4, 11.4, 'Kylrum'],
#  [37.4, 13.4, 'Kylrum'],
#  [46.4, 12.4, 'Kylrum'],
#  [79.5, 26.8, 'Klassrum'],
#  [46.4, 10.4, 'Kylrum'],
#  [80.4, 21.4, 'Klassrum'],
#  [80.4, 24.4, 'Klassrum'],
#  [78.4, 19.1, 'Lärarrum'],
#  [78.5, 16.7, 'Lärarrum'],
#  [85.4, 19.5, 'Klassrum'],
#  [100.4, 26.5, 'Klassrum'],
#  [105.4, 26.5, 'Klassrum'],
#  [68.5, 20.8, 'Klassrum'],
#  [78.5, 19.8, 'Klassrum'],
#  [81.4, 13.100000000000001, 'Lärarrum'],
#  [89.4, 20.1, 'Lärarrum'],
#  [72.5, 24.7, 'Lärarrum'],
#  [73.5, 16.7, 'Lärarrum'],
#  [38.4, 12.4, 'Kylrum'],
#  [37.4, 11.4, 'Kylrum'],
#  [90.4, 26.5, 'Klassrum'],
#  [87.4, 19.5, 'Klassrum'],
#  [88.4, 19.5, 'Klassrum'],
#  [105.4, 20.5, 'Klassrum'],
#  [40.4, 13.4, 'Kylrum'],
#  [72.5, 17.7, 'Lärarrum'],
#  [49.4, 8.4, 'Kylrum'],
#  [65.5, 21.7, 'Lärarrum'],
#  [89.4, 23.4, 'Klassrum'],
#  [85.4, 14.100000000000001, 'Lärarrum'],
#  [66.5, 19.8, 'Klassrum'],
#  [69.5, 17.8, 'Klassrum'],
#  [69.5, 24.7, 'Lärarrum'],
#  [84.4, 18.1, 'Lärarrum'],
#  [105.4, 18.5, 'Klassrum'],
#  [43.4, 13.4, 'Kylrum'],
#  [66.5, 17.8, 'Klassrum'],
#  [104.4, 21.5, 'Klassrum'],
#  [54.4, 16.4, 'Kylrum'],
#  [34.4, 15.4, 'Kylrum'],
#  [75.5, 17.8, 'Klassrum'],
#  [76.5, 20.8, 'Klassrum'],
#  [81.4, 19.1, 'Lärarrum'],
#  [82.4, 22.1, 'Lärarrum'],
#  [69.5, 21.7, 'Lärarrum'],
#  [72.5, 15.8, 'Klassrum'],
#  [86.4, 21.5, 'Klassrum'],
#  [42.4, 13.4, 'Kylrum'],
#  [84.4, 25.4, 'Klassrum'],
#  [83.4, 20.5, 'Klassrum'],
#  [84.4, 13.100000000000001, 'Lärarrum'],
#  [72.5, 23.7, 'Lärarrum'],
#  [59.4, 18.1, 'Lärarrum'],
#  [70.5, 14.8, 'Klassrum'],
#  [59.4, 12.4, 'Kylrum'],
#  [40.4, 11.4, 'Kylrum'],
#  [43.4, 10.4, 'Kylrum'],
#  [93.4, 19.4, 'Klassrum'],
#  [98.4, 21.4, 'Klassrum'],
#  [42.4, 11.4, 'Kylrum'],
#  [46.4, 12.4, 'Kylrum'],
#  [89.4, 21.1, 'Lärarrum'],
#  [52.4, 15.4, 'Kylrum'],
#  [97.4, 21.5, 'Klassrum'],
#  [36.4, 13.4, 'Kylrum'],
#  [41.4, 9.4, 'Kylrum'],
#  [84.4, 15.100000000000001, 'Lärarrum'],
#  [37.4, 9.4, 'Kylrum'],
#  [96.4, 20.4, 'Klassrum'],
#  [88.4, 23.5, 'Klassrum'],
#  [69.5, 21.7, 'Lärarrum'],
#  [98.4, 24.5, 'Klassrum'],
#  [31.4, 13.6, 'Kylrum'],
#  [39.4, 10.4, 'Kylrum'],
#  [51.4, 13.399999999999999, 'Kylrum'],
#  [87.4, 19.1, 'Lärarrum'],
#  [91.4, 22.5, 'Klassrum'],
#  [81.4, 22.1, 'Lärarrum'],
#  [36.4, 10.4, 'Kylrum'],
#  [81.4, 13.100000000000001, 'Lärarrum'],
#  [97.4, 24.4, 'Klassrum'],
#  [92.4, 21.5, 'Klassrum'],
#  [82.4, 22.5, 'Klassrum'],
#  [89.4, 23.4, 'Klassrum'],
#  [68.5, 18.7, 'Lärarrum'],
#  [83.4, 21.1, 'Lärarrum'],
#  [55.4, 15.4, 'Kylrum'],
#  [75.5, 16.7, 'Lärarrum'],
#  [49.4, 12.4, 'Kylrum'],
#  [92.4, 25.4, 'Klassrum'],
#  [76.5, 19.8, 'Klassrum'],
#  [57.4, 15.4, 'Kylrum'],
#  [30.4, 12.6, 'Kylrum'],
#  [37.4, 11.4, 'Kylrum'],
#  [85.4, 20.5, 'Klassrum'],
#  [102.4, 26.5, 'Klassrum'],
#  [89.4, 19.1, 'Lärarrum'],
#  [85.4, 15.100000000000001, 'Lärarrum'],
#  [87.4, 17.5, 'Klassrum'],
#  [72.5, 18.8, 'Klassrum'],
#  [40.4, 11.4, 'Kylrum'],
#  [51.4, 17.4, 'Kylrum'],
#  [83.4, 25.4, 'Klassrum'],
#  [65.5, 20.8, 'Klassrum'],
#  [90.4, 20.5, 'Klassrum'],
#  [33.4, 13.4, 'Kylrum'],
#  [85.4, 24.4, 'Klassrum'],
#  [38.4, 14.4, 'Kylrum'],
#  [93.4, 22.5, 'Klassrum'],
#  [82.4, 24.1, 'Lärarrum'],
#  [77.5, 28.8, 'Klassrum'],
#  [45.4, 14.4, 'Kylrum'],
#  [88.4, 22.5, 'Klassrum'],
#  [90.4, 21.5, 'Klassrum'],
#  [44.4, 11.4, 'Kylrum'],
#  [53.4, 14.4, 'Kylrum'],
#  [75.5, 20.8, 'Klassrum'],
#  [84.4, 14.100000000000001, 'Lärarrum'],
#  [51.4, 15.4, 'Kylrum'],
#  [49.4, 12.4, 'Kylrum'],
#  [65.5, 19.8, 'Klassrum'],
#  [35.4, 13.4, 'Kylrum'],
#  [89.4, 25.4, 'Klassrum'],
#  [74.5, 22.7, 'Lärarrum'],
#  [87.4, 23.4, 'Klassrum'],
#  [39.4, 10.4, 'Kylrum'],
#  [44.4, 10.4, 'Kylrum'],
#  [89.4, 22.5, 'Klassrum'],
#  [105.4, 21.5, 'Klassrum'],
#  [98.4, 20.4, 'Klassrum'],
#  [36.4, 15.4, 'Kylrum'],
#  [41.4, 12.4, 'Kylrum'],
#  [94.4, 26.4, 'Klassrum'],
#  [86.4, 20.5, 'Klassrum'],
#  [35.4, 14.6, 'Kylrum'],
#  [59.4, 12.4, 'Kylrum'],
#  [44.4, 8.4, 'Kylrum'],
#  [68.5, 18.7, 'Lärarrum'],
#  [85.4, 26.4, 'Klassrum'],
#  [59.4, 15.4, 'Kylrum'],
#  [72.5, 16.7, 'Lärarrum'],
#  [81.4, 20.1, 'Lärarrum'],
#  [68.5, 26.7, 'Lärarrum'],
#  [45.4, 14.4, 'Kylrum'],
#  [81.4, 27.4, 'Klassrum'],
#  [76.4, 19.1, 'Lärarrum'],
#  [57.4, 13.4, 'Kylrum'],
#  [39.4, 13.4, 'Kylrum'],
#  [36.4, 12.4, 'Kylrum'],
#  [71.5, 16.8, 'Klassrum'],
#  [80.4, 17.1, 'Lärarrum'],
#  [86.4, 22.4, 'Klassrum'],
#  [76.4, 15.100000000000001, 'Lärarrum'],
#  [93.4, 25.4, 'Klassrum'],
#  [74.5, 20.8, 'Klassrum'],
#  [76.5, 21.8, 'Klassrum'],
#  [91.4, 19.5, 'Klassrum'],
#  [68.5, 18.8, 'Klassrum'],
#  [90.4, 23.1, 'Lärarrum'],
#  [58.4, 23.1, 'Lärarrum'],
#  [92.4, 25.4, 'Klassrum'],
#  [73.5, 22.8, 'Klassrum'],
#  [48.4, 12.4, 'Kylrum'],
#  [42.4, 11.4, 'Kylrum'],
#  [82.4, 22.5, 'Klassrum'],
#  [83.4, 17.1, 'Lärarrum'],
#  [82.4, 21.4, 'Klassrum'],
#  [49.4, 11.4, 'Kylrum'],
#  [46.4, 8.4, 'Kylrum'],
#  [72.5, 20.7, 'Lärarrum'],
#  [71.5, 19.8, 'Klassrum'],
#  [80.4, 20.1, 'Lärarrum'],
#  [83.4, 22.5, 'Klassrum'],
#  [62.5, 22.8, 'Klassrum'],
#  [88.4, 17.1, 'Lärarrum'],
#  [71.5, 24.7, 'Lärarrum'],
#  [86.4, 14.100000000000001, 'Lärarrum'],
#  [92.4, 21.4, 'Klassrum'],
#  [79.5, 24.8, 'Klassrum'],
#  [40.4, 14.4, 'Kylrum'],
#  [82.4, 21.5, 'Klassrum'],
#  [74.5, 18.8, 'Klassrum'],
#  [81.4, 18.1, 'Lärarrum'],
#  [79.5, 19.8, 'Klassrum'],
#  [86.4, 18.1, 'Lärarrum'],
#  [85.4, 24.1, 'Lärarrum'],
#  [108.4, 23.5, 'Klassrum'],
#  [37.4, 17.4, 'Kylrum'],
#  [32.4, 8.6, 'Kylrum'],
#  [79.4, 13.100000000000001, 'Lärarrum'],
#  [87.4, 23.5, 'Klassrum'],
#  [46.4, 11.4, 'Kylrum'],
#  [33.4, 15.4, 'Kylrum'],
#  [41.4, 9.4, 'Kylrum'],
#  [44.4, 12.4, 'Kylrum'],
#  [78.5, 23.8, 'Klassrum'],
#  [76.4, 20.1, 'Lärarrum'],
#  [82.4, 19.1, 'Lärarrum'],
#  [37.4, 10.4, 'Kylrum'],
#  [81.4, 26.4, 'Klassrum'],
#  [68.5, 13.8, 'Klassrum'],
#  [90.4, 23.4, 'Klassrum'],
#  [58.4, 9.4, 'Kylrum'],
#  [51.4, 15.4, 'Kylrum'],
#  [82.4, 22.1, 'Lärarrum'],
#  [74.5, 20.7, 'Lärarrum'],
#  [67.5, 20.8, 'Klassrum'],
#  [75.5, 20.8, 'Klassrum'],
#  [70.5, 19.8, 'Klassrum'],
#  [43.4, 13.4, 'Kylrum'],
#  [70.5, 22.7, 'Lärarrum'],
#  [97.4, 17.4, 'Klassrum'],
#  [63.5, 20.8, 'Klassrum'],
#  [74.5, 18.8, 'Klassrum'],
#  [102.4, 26.4, 'Klassrum'],
#  [86.4, 19.1, 'Lärarrum'],
#  [77.4, 17.1, 'Lärarrum'],
#  [44.4, 9.4, 'Kylrum'],
#  [56.4, 14.4, 'Kylrum'],
#  [43.4, 9.4, 'Kylrum'],
#  [83.4, 16.1, 'Lärarrum'],
#  [81.4, 25.1, 'Lärarrum'],
#  [86.4, 19.1, 'Lärarrum'],
#  [82.4, 16.1, 'Lärarrum'],
#  [61.5, 17.8, 'Klassrum'],
#  [88.4, 20.5, 'Klassrum'],
#  [30.4, 8.6, 'Kylrum'],
#  [40.4, 14.4, 'Kylrum'],
#  [42.4, 9.4, 'Kylrum'],
#  [32.4, 12.4, 'Kylrum'],
#  [80.4, 17.1, 'Lärarrum'],
#  [78.5, 20.8, 'Klassrum'],
#  [84.4, 20.5, 'Klassrum'],
#  [61.4, 19.1, 'Lärarrum'],
#  [49.4, 11.4, 'Kylrum'],
#  [65.5, 24.7, 'Lärarrum'],
#  [78.5, 25.8, 'Klassrum'],
#  [74.5, 19.8, 'Klassrum'],
#  [85.4, 21.5, 'Klassrum'],
#  [65.5, 23.8, 'Klassrum'],
#  [54.4, 15.4, 'Kylrum'],
#  [86.4, 19.5, 'Klassrum'],
#  [39.4, 9.4, 'Kylrum'],
#  [71.5, 19.7, 'Lärarrum'],
#  [66.5, 19.7, 'Lärarrum'],
#  [43.4, 12.4, 'Kylrum'],
#  [76.5, 15.8, 'Klassrum'],
#  [61.5, 25.7, 'Lärarrum'],
#  [85.4, 22.5, 'Klassrum'],
#  [53.4, 14.4, 'Kylrum'],
#  [66.5, 21.7, 'Lärarrum'],
#  [43.4, 9.4, 'Kylrum'],
#  [93.4, 23.5, 'Klassrum'],
#  [87.4, 20.5, 'Klassrum'],
#  [84.4, 19.1, 'Lärarrum'],
#  [86.4, 17.5, 'Klassrum'],
#  [97.4, 17.5, 'Klassrum'],
#  [94.4, 22.5, 'Klassrum'],
#  [94.4, 22.5, 'Klassrum'],
#  [77.5, 17.8, 'Klassrum'],
#  [84.4, 20.4, 'Klassrum'],
#  [31.4, 7.6, 'Kylrum'],
#  [45.4, 10.4, 'Kylrum'],
#  [86.4, 18.1, 'Lärarrum'],
#  [89.4, 20.5, 'Klassrum'],
#  [53.4, 14.4, 'Kylrum'],
#  [92.4, 19.5, 'Klassrum'],
#  [37.4, 13.4, 'Kylrum'],
#  [41.4, 14.4, 'Kylrum'],
#  [48.4, 10.4, 'Kylrum'],
#  [108.4, 20.5, 'Klassrum'],
#  [40.4, 10.4, 'Kylrum'],
#  [79.4, 16.1, 'Lärarrum'],
#  [76.5, 24.7, 'Lärarrum'],
#  [51.4, 7.4, 'Kylrum'],
#  [78.5, 21.8, 'Klassrum'],
#  [90.4, 22.4, 'Klassrum'],
#  [83.4, 19.5, 'Klassrum'],
#  [80.5, 22.7, 'Lärarrum'],
#  [85.4, 22.5, 'Klassrum'],
#  [50.4, 13.4, 'Kylrum'],
#  [101.4, 19.5, 'Klassrum'],
#  [96.4, 18.5, 'Klassrum'],
#  [84.4, 22.5, 'Klassrum'],
#  [92.4, 18.5, 'Klassrum'],
#  [73.4, 16.1, 'Lärarrum'],
#  [85.4, 21.1, 'Lärarrum'],
#  [96.4, 23.5, 'Klassrum'],
#  [79.5, 19.8, 'Klassrum'],
#  [82.4, 23.5, 'Klassrum'],
#  [103.4, 19.5, 'Klassrum'],
#  [67.5, 23.7, 'Lärarrum'],
#  [85.4, 22.1, 'Lärarrum'],
#  [73.5, 15.7, 'Lärarrum'],
#  [99.4, 23.5, 'Klassrum'],
#  [86.4, 17.5, 'Klassrum'],
#  [73.5, 24.8, 'Klassrum'],
#  [77.4, 19.1, 'Lärarrum'],
#  [105.4, 18.5, 'Klassrum'],
#  [80.4, 13.100000000000001, 'Lärarrum'],
#  [58.4, 20.1, 'Lärarrum'],
#  [84.4, 21.5, 'Klassrum'],
#  [36.4, 17.4, 'Kylrum'],
#  [57.4, 11.4, 'Kylrum'],
#  [96.4, 22.4, 'Klassrum'],
#  [108.4, 21.5, 'Klassrum'],
#  [89.4, 24.4, 'Klassrum'],
#  [42.4, 14.4, 'Kylrum'],
#  [68.5, 17.8, 'Klassrum'],
#  [97.4, 20.4, 'Klassrum'],
#  [37.4, 14.4, 'Kylrum'],
#  [69.5, 15.8, 'Klassrum'],
#  [83.4, 19.1, 'Lärarrum'],
#  [51.4, 17.1, 'Lärarrum'],
#  [85.4, 25.1, 'Lärarrum'],
#  [87.4, 23.1, 'Lärarrum'],
#  [72.5, 20.7, 'Lärarrum'],
#  [52.4, 13.4, 'Kylrum'],
#  [51.4, 11.4, 'Kylrum'],
#  [54.4, 16.4, 'Kylrum'],
#  [86.4, 17.5, 'Klassrum'],
#  [41.4, 11.4, 'Kylrum'],
#  [101.4, 20.4, 'Klassrum'],
#  [53.4, 11.4, 'Kylrum'],
#  [54.4, 13.4, 'Kylrum'],
#  [82.4, 17.5, 'Klassrum'],
#  [34.4, 16.4, 'Kylrum'],
#  [85.4, 28.4, 'Klassrum'],
#  [42.4, 14.4, 'Kylrum'],
#  [86.4, 26.5, 'Klassrum'],
#  [43.4, 12.4, 'Kylrum'],
#  [81.4, 23.1, 'Lärarrum'],
#  [72.5, 21.7, 'Lärarrum'],
#  [69.5, 19.7, 'Lärarrum'],
#  [86.4, 19.5, 'Klassrum'],
#  [104.4, 19.5, 'Klassrum'],
#  [88.4, 20.5, 'Klassrum'],
#  [73.5, 21.7, 'Lärarrum'],
#  [45.4, 15.4, 'Kylrum'],
#  [78.5, 25.8, 'Klassrum'],
#  [82.4, 24.1, 'Lärarrum'],
#  [88.4, 21.5, 'Klassrum'],
#  [32.4, 7.4, 'Kylrum'],
#  [77.4, 12.100000000000001, 'Lärarrum'],
#  [56.4, 14.4, 'Kylrum'],
#  [90.4, 22.5, 'Klassrum'],
#  [73.5, 21.8, 'Klassrum'],
#  [90.4, 20.5, 'Klassrum'],
#  [76.4, 20.1, 'Lärarrum'],
#  [62.4, 9.4, 'Kylrum'],
#  [68.5, 19.8, 'Klassrum'],
#  [81.4, 23.5, 'Klassrum'],
#  [85.4, 23.4, 'Klassrum'],
#  [70.5, 26.7, 'Lärarrum'],
#  [73.5, 15.8, 'Klassrum'],
#  [42.4, 8.4, 'Kylrum'],
#  [78.5, 20.8, 'Klassrum'],
#  [69.5, 18.7, 'Lärarrum'],
#  [72.5, 22.8, 'Klassrum'],
#  [89.4, 19.5, 'Klassrum'],
#  [38.4, 12.4, 'Kylrum'],
#  [85.4, 20.5, 'Klassrum'],
#  [68.5, 18.7, 'Lärarrum'],
#  [72.5, 17.8, 'Klassrum'],
#  [69.5, 16.8, 'Klassrum'],
#  [53.4, 16.4, 'Kylrum'],
#  [74.5, 23.7, 'Lärarrum'],
#  [41.4, 10.4, 'Kylrum'],
#  [103.4, 22.5, 'Klassrum'],
#  [74.4, 18.1, 'Lärarrum'],
#  [60.4, 25.1, 'Lärarrum'],
#  [93.4, 23.4, 'Klassrum'],
#  [82.4, 20.5, 'Klassrum'],
#  [80.4, 23.1, 'Lärarrum'],
#  [74.5, 18.8, 'Klassrum'],
#  [92.4, 21.5, 'Klassrum'],
#  [33.4, 15.6, 'Kylrum'],
#  [76.5, 19.7, 'Lärarrum'],
#  [72.5, 18.8, 'Klassrum'],
#  [30.4, 5.6, 'Kylrum'],
#  [101.4, 14.399999999999999, 'Klassrum'],
#  [79.4, 16.5, 'Klassrum'],
#  [85.4, 21.1, 'Lärarrum'],
#  [40.4, 13.4, 'Kylrum'],
#  [97.4, 20.4, 'Klassrum'],
#  [77.5, 17.7, 'Lärarrum'],
#  [80.4, 22.1, 'Lärarrum'],
#  [36.4, 17.4, 'Kylrum'],
#  [51.4, 15.4, 'Kylrum'],
#  [89.4, 16.1, 'Lärarrum'],
#  [63.5, 16.7, 'Lärarrum'],
#  [65.5, 22.7, 'Lärarrum'],
#  [33.4, 15.4, 'Kylrum'],
#  [78.4, 21.4, 'Klassrum'],
#  [84.4, 16.1, 'Lärarrum'],
#  [75.5, 22.8, 'Klassrum'],
#  [34.4, 13.4, 'Kylrum'],
#  [45.4, 12.4, 'Kylrum'],
#  [94.4, 15.5, 'Klassrum'],
#  [81.4, 18.1, 'Lärarrum'],
#  [39.4, 11.4, 'Kylrum'],
#  [105.4, 23.5, 'Klassrum'],
#  [67.5, 24.7, 'Lärarrum'],
#  [95.4, 13.5, 'Klassrum'],
#  [30.4, -0.40000000000000036, 'Kylrum'],
#  [86.4, 17.1, 'Lärarrum'],
#  [85.4, 17.5, 'Klassrum'],
#  [87.4, 16.5, 'Klassrum'],
#  [42.4, 15.4, 'Kylrum'],
#  [81.4, 11.100000000000001, 'Lärarrum'],
#  [83.4, 16.5, 'Klassrum'],
#  [90.4, 20.1, 'Lärarrum'],
#  [54.4, 17.4, 'Kylrum'],
#  [107.4, 19.5, 'Klassrum'],
#  [38.4, 16.4, 'Kylrum'],
#  [60.4, 22.1, 'Lärarrum'],
#  [54.4, 15.399999999999999, 'Kylrum'],
#  [63.5, 19.8, 'Klassrum'],
#  [86.4, 24.5, 'Klassrum'],
#  [79.4, 25.1, 'Lärarrum'],
#  [75.5, 16.8, 'Klassrum'],
#  [90.4, 26.4, 'Klassrum'],
#  [73.5, 17.7, 'Lärarrum'],
#  [35.4, 14.4, 'Kylrum'],
#  [69.5, 25.7, 'Lärarrum'],
#  [73.5, 18.8, 'Klassrum'],
#  [52.4, 16.4, 'Kylrum'],
#  [87.4, 27.5, 'Klassrum'],
#  [35.4, 14.4, 'Kylrum'],
#  [108.4, 19.5, 'Klassrum'],
#  [82.4, 18.5, 'Klassrum'],
#  [87.4, 17.5, 'Klassrum'],
#  [81.4, 28.4, 'Klassrum'],
#  [82.4, 24.4, 'Klassrum'],
#  [52.4, 12.4, 'Kylrum'],
#  [84.4, 22.4, 'Klassrum'],
#  [65.5, 25.8, 'Klassrum'],
#  [104.4, 22.5, 'Klassrum'],
#  [82.4, 14.5, 'Klassrum'],
#  [90.4, 20.5, 'Klassrum'],
#  [75.5, 14.8, 'Klassrum'],
#  [80.4, 17.1, 'Lärarrum'],
#  [88.4, 26.1, 'Lärarrum'],
#  [43.4, 14.4, 'Kylrum'],
#  [83.4, 20.1, 'Lärarrum'],
#  [82.4, 19.5, 'Klassrum'],
#  [93.4, 23.5, 'Klassrum'],
#  [65.5, 17.7, 'Lärarrum'],
#  [71.5, 16.7, 'Lärarrum'],
#  [100.4, 23.4, 'Klassrum'],
#  [97.4, 23.5, 'Klassrum'],
#  [52.4, 12.4, 'Kylrum'],
#  [33.4, 12.4, 'Kylrum'],
#  [38.4, 13.4, 'Kylrum'],
#  [61.4, 12.4, 'Kylrum'],
#  [72.5, 15.8, 'Klassrum'],
#  [89.4, 19.1, 'Lärarrum'],
#  [81.4, 23.1, 'Lärarrum'],
#  [79.4, 20.5, 'Klassrum'],
#  [73.5, 20.7, 'Lärarrum'],
#  [74.5, 13.8, 'Klassrum'],
#  [66.5, 13.8, 'Klassrum'],
#  [92.4, 16.4, 'Klassrum'],
#  [91.4, 18.5, 'Klassrum'],
#  [95.4, 24.4, 'Klassrum'],
#  [48.4, 9.4, 'Kylrum'],
#  [77.5, 16.8, 'Klassrum'],
#  [75.5, 19.7, 'Lärarrum'],
#  [82.5, 24.8, 'Klassrum'],
#  [93.4, 15.100000000000001, 'Lärarrum'],
#  [37.4, 12.4, 'Kylrum'],
#  [83.4, 18.1, 'Lärarrum'],
#  [78.5, 22.8, 'Klassrum'],
#  [44.4, 9.4, 'Kylrum'],
#  [89.4, 18.1, 'Lärarrum'],
#  [82.4, 18.1, 'Lärarrum'],
#  [73.5, 19.8, 'Klassrum'],
#  [96.4, 21.5, 'Klassrum'],
#  [48.4, 11.4, 'Kylrum'],
#  [54.4, 18.4, 'Kylrum'],
#  [89.4, 24.4, 'Klassrum'],
#  [36.4, 14.4, 'Kylrum'],
#  [65.5, 25.8, 'Klassrum'],
#  [94.4, 21.5, 'Klassrum'],
#  [44.4, 8.4, 'Kylrum'],
#  [61.5, 19.8, 'Klassrum'],
#  [92.4, 22.5, 'Klassrum'],
#  [39.4, 10.4, 'Kylrum'],
#  [98.4, 26.4, 'Klassrum'],
#  [32.4, 13.4, 'Kylrum'],
#  [89.4, 19.5, 'Klassrum'],
#  [83.4, 20.1, 'Lärarrum'],
#  [57.4, 9.4, 'Kylrum'],
#  [91.4, 27.4, 'Klassrum'],
#  [38.4, 15.4, 'Kylrum'],
#  [77.4, 17.1, 'Lärarrum'],
#  [75.4, 22.1, 'Lärarrum'],
#  [75.5, 18.7, 'Lärarrum'],
#  [44.4, 15.4, 'Kylrum'],
#  [94.4, 22.4, 'Klassrum'],
#  [79.4, 20.5, 'Klassrum'],
#  [93.4, 20.4, 'Klassrum'],
#  [100.4, 18.5, 'Klassrum'],
#  [84.4, 14.100000000000001, 'Lärarrum'],
#  [108.4, 27.5, 'Klassrum'],
#  [85.4, 23.4, 'Klassrum'],
#  [91.4, 23.4, 'Klassrum'],
#  [85.4, 21.1, 'Lärarrum'],
#  [95.4, 19.5, 'Klassrum'],
#  [93.4, 21.4, 'Klassrum'],
#  [36.4, 12.4, 'Kylrum'],
#  [40.4, 15.4, 'Kylrum'],
#  [84.4, 21.1, 'Lärarrum'],
#  [71.5, 27.7, 'Lärarrum'],
#  [73.5, 19.7, 'Lärarrum'],
#  [30.4, 6.6, 'Kylrum'],
#  [68.5, 19.7, 'Lärarrum'],
#  [83.4, 19.5, 'Klassrum'],
#  [73.5, 25.8, 'Klassrum'],
#  [86.4, 17.1, 'Lärarrum'],
#  [90.4, 20.5, 'Klassrum'],
#  [79.4, 9.100000000000001, 'Lärarrum'],
#  [57.4, 11.4, 'Kylrum'],
#  [82.4, 21.1, 'Lärarrum'],
#  [78.4, 22.1, 'Lärarrum'],
#  [81.4, 15.100000000000001, 'Lärarrum'],
#  [52.4, 8.4, 'Kylrum'],
#  [54.4, 9.4, 'Kylrum'],
#  [42.4, 14.4, 'Kylrum'],
#  [100.4, 11.399999999999999, 'Klassrum'],
#  [38.4, 13.4, 'Kylrum'],
#  [93.4, 19.5, 'Klassrum'],
#  [71.5, 14.8, 'Klassrum'],
#  [34.4, -2.4000000000000004, 'Kylrum'],
#  [56.4, 13.4, 'Kylrum'],
#  [83.4, 22.4, 'Klassrum'],
#  [46.4, 14.4, 'Kylrum'],
#  [97.4, 20.5, 'Klassrum'],
#  [66.5, 14.7, 'Lärarrum'],
#  [82.4, 19.5, 'Klassrum'],
#  [82.4, 14.100000000000001, 'Lärarrum'],
#  [44.4, 11.4, 'Kylrum'],
#  [84.4, 16.4, 'Klassrum'],
#  [69.5, 18.7, 'Lärarrum'],
#  [85.4, 20.1, 'Lärarrum'],
#  [76.5, 23.8, 'Klassrum'],
#  [77.4, 16.5, 'Klassrum'],
#  [75.4, 25.1, 'Lärarrum'],
#  [87.4, 24.4, 'Klassrum'],
#  [68.5, 21.7, 'Lärarrum'],
#  [90.4, 15.100000000000001, 'Lärarrum'],
#  [81.4, 18.5, 'Klassrum'],
#  [42.4, 13.4, 'Kylrum'],
#  [93.4, 10.5, 'Klassrum'],
#  [86.4, 21.5, 'Klassrum'],
#  [106.4, 21.5, 'Klassrum'],
#  [49.4, 11.4, 'Kylrum'],
#  [63.5, 19.8, 'Klassrum'],
#  [58.4, 25.1, 'Lärarrum'],
#  [68.5, 17.8, 'Klassrum'],
#  [35.4, -0.40000000000000036, 'Kylrum'],
#  [94.4, 21.5, 'Klassrum'],
#  [82.5, 19.8, 'Klassrum'],
#  [48.4, 17.4, 'Kylrum'],
#  [42.4, 14.4, 'Kylrum'],
#  [84.4, 20.1, 'Lärarrum'],
#  [79.4, 17.1, 'Lärarrum'],
#  [93.4, 22.4, 'Klassrum'],
#  [82.4, 19.1, 'Lärarrum'],
#  [41.4, 17.4, 'Kylrum'],
#  [90.4, 24.5, 'Klassrum'],
#  [72.5, 17.7, 'Lärarrum'],
#  [56.4, 15.4, 'Kylrum'],
#  [73.5, 25.7, 'Lärarrum'],
#  [88.4, 18.5, 'Klassrum'],
#  [31.4, 13.6, 'Kylrum'],
#  [66.5, 24.8, 'Klassrum'],
#  [53.4, 17.4, 'Kylrum'],
#  [77.4, 27.1, 'Lärarrum'],
#  [67.5, 19.8, 'Klassrum'],
#  [73.4, 17.1, 'Lärarrum'],
#  [35.4, 14.4, 'Kylrum'],
#  [96.4, 20.4, 'Klassrum'],
#  [81.4, 16.1, 'Lärarrum'],
#  [85.4, 20.1, 'Lärarrum'],
#  [54.4, 15.4, 'Kylrum'],
#  [82.4, 24.1, 'Lärarrum'],
#  [81.4, 21.5, 'Klassrum'],
#  [57.4, 12.4, 'Kylrum'],
#  [32.4, 9.4, 'Kylrum'],
#  [84.4, 23.1, 'Lärarrum'],
#  [75.5, 20.7, 'Lärarrum'],
#  [78.4, 19.1, 'Lärarrum'],
#  [73.5, 15.8, 'Klassrum'],
#  [53.4, 13.4, 'Kylrum'],
#  [39.4, 15.399999999999999, 'Kylrum'],
#  [85.4, 19.5, 'Klassrum'],
#  [90.4, 24.4, 'Klassrum'],
#  [89.4, 23.5, 'Klassrum'],
#  [56.4, 14.4, 'Kylrum'],
#  [80.5, 25.7, 'Lärarrum'],
#  [59.4, 10.4, 'Kylrum'],
#  [71.5, 15.8, 'Klassrum'],
#  [89.4, 21.1, 'Lärarrum'],
#  [31.4, 12.6, 'Kylrum'],
#  [68.5, 13.7, 'Lärarrum'],
#  [71.5, 19.7, 'Lärarrum'],
#  [31.4, 10.4, 'Kylrum'],
#  [32.4, 11.4, 'Kylrum'],
#  [79.4, 21.1, 'Lärarrum'],
#  [77.4, 28.1, 'Lärarrum'],
#  [84.4, 16.1, 'Lärarrum'],
#  [90.4, 20.5, 'Klassrum'],
#  [93.4, 19.5, 'Klassrum'],
#  [40.4, 13.4, 'Kylrum'],
#  [68.5, 15.7, 'Lärarrum'],
#  [39.4, 7.4, 'Kylrum'],
#  [57.4, 12.4, 'Kylrum'],
#  [69.5, 24.7, 'Lärarrum'],
#  [86.4, 16.1, 'Lärarrum'],
#  [79.4, 23.5, 'Klassrum'],
#  [71.5, 18.8, 'Klassrum'],
#  [90.4, 25.5, 'Klassrum'],
#  [71.5, 22.8, 'Klassrum'],
#  [70.4, 18.1, 'Lärarrum'],
#  [90.4, 18.4, 'Klassrum'],
#  [56.4, 15.4, 'Kylrum'],
#  [92.4, 21.4, 'Klassrum'],
#  [87.4, 20.1, 'Lärarrum'],
#  [79.4, 19.1, 'Lärarrum'],
#  [106.4, 16.5, 'Klassrum'],
#  [85.4, 25.5, 'Klassrum'],
#  [65.5, 27.7, 'Lärarrum'],
#  [78.4, 23.4, 'Klassrum'],
#  [102.4, 14.399999999999999, 'Klassrum'],
#  [74.4, 14.100000000000001, 'Lärarrum'],
#  [43.4, 12.4, 'Kylrum'],
#  [82.4, 21.5, 'Klassrum'],
#  [31.4, 5.6, 'Kylrum'],
#  [92.4, 23.5, 'Klassrum'],
#  [89.4, 25.4, 'Klassrum'],
#  [74.5, 21.8, 'Klassrum'],
#  [63.4, 25.1, 'Lärarrum'],
#  [84.4, 20.4, 'Klassrum'],
#  [73.5, 15.7, 'Lärarrum'],
#  [103.4, 14.5, 'Klassrum'],
#  [72.5, 18.8, 'Klassrum'],
#  [62.5, 18.7, 'Lärarrum'],
#  [75.4, 14.100000000000001, 'Lärarrum'],
#  [39.4, 15.4, 'Kylrum'],
#  [51.4, 14.4, 'Kylrum'],
#  [76.5, 24.7, 'Lärarrum'],
#  [74.5, 18.7, 'Lärarrum'],
#  [45.4, 5.4, 'Kylrum'],
#  [38.4, 9.4, 'Kylrum'],
#  [88.4, 16.1, 'Lärarrum'],
#  [100.4, 17.5, 'Klassrum'],
#  [33.4, 17.4, 'Kylrum'],
#  [83.4, 18.5, 'Klassrum'],
#  [97.4, 21.5, 'Klassrum'],
#  [78.4, 19.4, 'Klassrum'],
#  [82.4, 22.5, 'Klassrum'],
#  [51.4, 21.1, 'Lärarrum'],
#  [98.4, 22.4, 'Klassrum'],
#  [69.5, 24.8, 'Klassrum'],
#  [56.4, 19.4, 'Kylrum'],
#  [45.4, 12.4, 'Kylrum'],
#  [77.4, 22.1, 'Lärarrum'],
#  [95.4, 25.4, 'Klassrum'],
#  [60.4, 13.4, 'Kylrum'],
#  [42.4, 12.4, 'Kylrum'],
#  [84.4, 21.1, 'Lärarrum'],
#  [86.4, 22.5, 'Klassrum'],
#  [51.4, 11.4, 'Kylrum'],
#  [92.4, 20.5, 'Klassrum'],
#  [47.4, 9.4, 'Kylrum'],
#  [74.5, 17.7, 'Lärarrum'],
#  [89.4, 22.5, 'Klassrum'],
#  [95.4, 24.4, 'Klassrum'],
#  [108.4, 29.5, 'Klassrum'],
#  [75.5, 17.8, 'Klassrum'],
#  [67.5, 19.7, 'Lärarrum'],
#  [49.4, 15.399999999999999, 'Kylrum'],
#  [86.4, 20.5, 'Klassrum'],
#  [97.4, 27.5, 'Klassrum'],
#  [61.4, 19.1, 'Lärarrum'],
#  [86.4, 26.5, 'Klassrum'],
#  [85.4, 22.1, 'Lärarrum'],
#  [89.4, 20.5, 'Klassrum'],
#  [39.4, 13.4, 'Kylrum'],
#  [35.4, 10.4, 'Kylrum'],
#  [62.5, 17.8, 'Klassrum'],
#  [79.4, 15.100000000000001, 'Lärarrum'],
#  [60.4, 12.4, 'Kylrum'],
#  [73.5, 17.8, 'Klassrum'],
#  [76.4, 22.1, 'Lärarrum'],
#  [87.4, 25.4, 'Klassrum'],
#  [76.4, 20.1, 'Lärarrum'],
#  [64.5, 15.8, 'Klassrum'],
#  [88.4, 22.4, 'Klassrum'],
#  [49.4, 20.4, 'Kylrum'],
#  [72.5, 22.8, 'Klassrum'],
#  [74.4, 12.100000000000001, 'Lärarrum'],
#  [51.4, 8.4, 'Kylrum'],
#  [31.4, 3.5999999999999996, 'Kylrum'],
#  [75.5, 19.7, 'Lärarrum'],
#  [67.5, 24.7, 'Lärarrum'],
#  [77.4, 20.1, 'Lärarrum'],
#  [51.4, 7.4, 'Kylrum'],
#  [43.4, 16.4, 'Kylrum'],
#  [79.4, 19.5, 'Klassrum'],
#  [92.4, 22.5, 'Klassrum'],
#  [95.4, 29.4, 'Klassrum'],
#  [94.4, 26.4, 'Klassrum'],
#  [77.5, 18.8, 'Klassrum'],
#  [73.5, 18.8, 'Klassrum'],
#  [53.4, 12.4, 'Kylrum'],
#  [71.4, 19.1, 'Lärarrum'],
#  [54.4, 13.4, 'Kylrum'],
#  [68.5, 21.8, 'Klassrum'],
#  [87.4, 14.5, 'Klassrum'],
#  [63.5, 22.7, 'Lärarrum'],
#  [79.4, 11.100000000000001, 'Lärarrum'],
#  [66.5, 16.7, 'Lärarrum'],
#  [94.4, 20.4, 'Klassrum'],
#  [82.4, 25.4, 'Klassrum'],
#  [83.4, 17.5, 'Klassrum'],
#  [82.4, 20.1, 'Lärarrum'],
#  [54.4, 11.4, 'Kylrum'],
#  [43.4, 14.4, 'Kylrum'],
#  [82.4, 21.5, 'Klassrum'],
#  [79.5, 20.8, 'Klassrum'],
#  [80.4, 24.1, 'Lärarrum'],
#  [46.4, 10.4, 'Kylrum'],
#  [91.4, 21.5, 'Klassrum'],
#  [85.4, 16.5, 'Klassrum'],
#  [77.5, 28.7, 'Lärarrum'],
#  [67.5, 21.8, 'Klassrum'],
#  [71.5, 19.7, 'Lärarrum'],
#  [42.4, 16.4, 'Kylrum'],
#  [87.4, 19.1, 'Lärarrum'],
#  [92.4, 15.100000000000001, 'Lärarrum'],
#  [88.4, 21.4, 'Klassrum'],
#  [75.5, 18.7, 'Lärarrum'],
#  [54.4, 8.4, 'Kylrum'],
#  [31.4, 16.4, 'Kylrum'],
#  [72.5, 18.8, 'Klassrum'],
#  [73.5, 23.7, 'Lärarrum'],
#  [93.4, 28.4, 'Klassrum'],
#  [74.5, 23.7, 'Lärarrum'],
#  [79.5, 21.7, 'Lärarrum'],
#  [72.5, 22.7, 'Lärarrum'],
#  [81.4, 29.4, 'Klassrum'],
#  [53.4, 17.4, 'Kylrum'],
#  [71.5, 18.8, 'Klassrum'],
#  [87.4, 13.399999999999999, 'Klassrum'],
#  [90.4, 20.4, 'Klassrum'],
#  [84.4, 21.1, 'Lärarrum'],
#  [41.4, 17.4, 'Kylrum'],
#  [87.4, 24.4, 'Klassrum'],
#  [79.4, 26.5, 'Klassrum'],
#  [46.4, 10.4, 'Kylrum'],
#  [79.5, 26.8, 'Klassrum'],
#  [81.4, 20.1, 'Lärarrum'],
#  [84.4, 18.1, 'Lärarrum'],
#  [67.5, 21.8, 'Klassrum'],
#  [53.4, 6.4, 'Kylrum'],
#  [76.5, 21.7, 'Lärarrum'],
#  [70.5, 20.7, 'Lärarrum'],
#  [81.5, 15.8, 'Klassrum'],
#  [73.5, 17.8, 'Klassrum'],
#  [95.4, 23.4, 'Klassrum'],
#  [80.4, 23.5, 'Klassrum'],
#  [69.5, 16.8, 'Klassrum'],
#  [70.5, 17.8, 'Klassrum'],
#  [76.4, 19.4, 'Klassrum'],
#  [105.4, 20.5, 'Klassrum'],
#  [76.5, 19.7, 'Lärarrum'],
#  [47.4, 14.4, 'Kylrum'],
#  [89.4, 25.4, 'Klassrum'],
#  [88.4, 20.5, 'Klassrum'],
#  [89.4, 24.5, 'Klassrum'],
#  [49.4, 11.4, 'Kylrum'],
#  [45.4, 11.4, 'Kylrum'],
#  [65.5, 22.7, 'Lärarrum'],
#  [38.4, 7.4, 'Kylrum'],
#  [100.4, 26.5, 'Klassrum'],
#  [90.4, 19.1, 'Lärarrum'],
#  [67.5, 19.7, 'Lärarrum'],
#  [85.4, 14.100000000000001, 'Lärarrum'],
#  [78.4, 10.100000000000001, 'Lärarrum'],
#  [40.4, 9.4, 'Kylrum'],
#  [101.4, 17.5, 'Klassrum'],
#  [63.4, 22.1, 'Lärarrum'],
#  [54.4, 14.4, 'Kylrum'],
#  [96.4, 15.5, 'Klassrum'],
#  [74.4, 18.5, 'Klassrum'],
#  [30.4, 9.6, 'Kylrum'],
#  [64.5, 22.8, 'Klassrum'],
#  [96.4, 19.5, 'Klassrum'],
#  [32.4, 4.6, 'Kylrum'],
#  [76.5, 19.7, 'Lärarrum'],
#  [87.4, 17.1, 'Lärarrum'],
#  [76.5, 19.7, 'Lärarrum'],
#  [79.4, 6.100000000000001, 'Lärarrum'],
#  [79.5, 21.8, 'Klassrum'],
#  [41.4, 10.4, 'Kylrum'],
#  [94.4, 21.5, 'Klassrum'],
#  [69.5, 26.7, 'Lärarrum'],
#  [45.4, 11.4, 'Kylrum'],
#  [41.4, 8.4, 'Kylrum'],
#  [66.5, 23.7, 'Lärarrum'],
#  [89.4, 17.1, 'Lärarrum'],
#  [72.5, 18.8, 'Klassrum'],
#  ...]

# %%
# But, the false-rows are badly mixed up.
false_rows
#######
# Out:
# [[22.4, 8.6, 'Kylrum'],
#  [24.4, 11.24, 'Kylrum'],
#  [23.4, 5.6, 'Kylrum'],
#  [18.4, 4.6, 'Kylrum'],
#  [26.4, 11.6, 'Kylrum'],
#  [20.4, 3.5999999999999996, 'Kylrum'],
#  [16.4, 5.6, 'Kylrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [18.4, 0.5999999999999996, 'Kylrum'],
#  [16.4, 6.6, 'Kylrum'],
#  [17.4, -2.4000000000000004, 'Kylrum'],
#  [13.399999999999999, 6.6, 'Kylrum'],
#  [19.4, 11.6, 'Kylrum'],
#  [19.4, -1.4000000000000004, 'Kylrum'],
#  [22.4, 5.6, 'Kylrum'],
#  [19.4, 1.5999999999999996, 'Kylrum'],
#  [16.4, 13.6, 'Kylrum'],
#  [27.4, 9.6, 'Kylrum'],
#  [23.4, 0.5999999999999996, 'Kylrum'],
#  [17.4, 6.6, 'Kylrum'],
#  [15.399999999999999, 1.5999999999999996, 'Kylrum'],
#  [21.4, -1.4000000000000004, 'Kylrum'],
#  [20.4, -0.40000000000000036, 'Kylrum'],
#  [18.4, 8.6, 'Kylrum'],
#  [20.4, 1.5999999999999996, 'Kylrum'],
#  [18.4, 3.5999999999999996, 'Kylrum'],
#  [24.4, 2.5999999999999996, 'Kylrum'],
#  [24.4, 9.6, 'Kylrum'],
#  [15.399999999999999, 5.6, 'Kylrum'],
#  [14.399999999999999, -2.4000000000000004, 'Kylrum'],
#  [27.4, 10.6, 'Kylrum'],
#  [19.4, 6.6, 'Kylrum'],
#  [23.4, 2.5999999999999996, 'Kylrum'],
#  [18.4, 2.5999999999999996, 'Kylrum'],
#  [14.399999999999999, -1.4000000000000004, 'Kylrum'],
#  [13.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [20.4, 7.6, 'Kylrum'],
#  [20.4, 6.6, 'Kylrum'],
#  [26.4, 2.5999999999999996, 'Kylrum'],
#  [23.4, 9.6, 'Kylrum'],
#  [16.4, 4.6, 'Kylrum'],
#  [9.399999999999999, 4.6, 'Kylrum'],
#  [12.399999999999999, 7.6, 'Kylrum'],
#  [24.4, -2.4000000000000004, 'Kylrum'],
#  [18.4, 6.6, 'Kylrum'],
#  [25.4, 9.6, 'Kylrum'],
#  [26.4, 11.6, 'Kylrum'],
#  [21.4, 7.6, 'Kylrum'],
#  [16.4, 4.6, 'Kylrum'],
#  [25.4, 10.6, 'Kylrum'],
#  [14.399999999999999, 4.6, 'Kylrum'],
#  [16.4, -2.4000000000000004, 'Kylrum'],
#  [19.4, -1.4000000000000004, 'Kylrum'],
#  [20.4, 9.6, 'Kylrum'],
#  [23.4, 10.6, 'Kylrum'],
#  [11.399999999999999, 4.6, 'Kylrum'],
#  [11.399999999999999, 2.5999999999999996, 'Kylrum'],
#  [18.4, -2.4000000000000004, 'Kylrum'],
#  [16.4, -0.40000000000000036, 'Kylrum'],
#  [25.4, 8.6, 'Kylrum'],
#  [23.4, 0.5999999999999996, 'Kylrum'],
#  [19.4, 5.6, 'Kylrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [15.399999999999999, 7.6, 'Kylrum'],
#  [18.4, 8.6, 'Kylrum'],
#  [24.4, 10.6, 'Kylrum'],
#  [13.399999999999999, 0.5999999999999996, 'Kylrum'],
#  [13.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [22.4, -0.40000000000000036, 'Kylrum'],
#  [14.399999999999999, -3.4000000000000004, 'Kylrum'],
#  [24.4, 2.5999999999999996, 'Kylrum'],
#  [27.4, 10.6, 'Kylrum'],
#  [13.399999999999999, 0.5999999999999996, 'Kylrum'],
#  [20.4, 5.6, 'Kylrum'],
#  [15.399999999999999, 0.5999999999999996, 'Kylrum'],
#  [21.4, -3.4000000000000004, 'Kylrum'],
#  [17.4, -5.4, 'Kylrum'],
#  [26.4, 7.6, 'Kylrum'],
#  [17.4, 14.6, 'Kylrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [14.399999999999999, -6.4, 'Kylrum'],
#  [13.399999999999999, 5.6, 'Kylrum'],
#  [15.399999999999999, 1.5999999999999996, 'Kylrum'],
#  [22.4, 0.5999999999999996, 'Kylrum'],
#  [20.4, 5.6, 'Kylrum'],
#  [24.4, 5.6, 'Kylrum'],
#  [14.399999999999999, 16.6, 'Kylrum'],
#  [17.4, 4.6, 'Kylrum'],
#  [17.4, -1.4000000000000004, 'Kylrum'],
#  [18.4, -0.40000000000000036, 'Kylrum'],
#  [21.4, -1.4000000000000004, 'Kylrum'],
#  [17.4, 4.6, 'Kylrum'],
#  [25.4, 6.6, 'Kylrum'],
#  [14.399999999999999, -3.4000000000000004, 'Kylrum'],
#  [25.4, -3.4000000000000004, 'Kylrum'],
#  [29.4, 7.6, 'Kylrum'],
#  [15.399999999999999, 6.6, 'Kylrum'],
#  [19.4, -2.4000000000000004, 'Kylrum'],
#  [25.4, 10.6, 'Kylrum'],
#  [17.4, 0.5999999999999996, 'Kylrum'],
#  [28.4, 8.6, 'Kylrum'],
#  [17.4, 7.6, 'Kylrum'],
#  [24.4, 0.5999999999999996, 'Kylrum'],
#  [24.4, 7.6, 'Kylrum'],
#  [28.4, 1.5999999999999996, 'Kylrum'],
#  [11.399999999999999, -8.4, 'Kylrum'],
#  [20.4, 4.6, 'Kylrum'],
#  [16.4, 1.5999999999999996, 'Kylrum'],
#  [18.4, 7.6, 'Kylrum'],
#  [14.399999999999999, -3.4000000000000004, 'Kylrum'],
#  [11.399999999999999, -9.4, 'Kylrum'],
#  [15.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [13.399999999999999, 4.6, 'Kylrum'],
#  [17.4, 0.5999999999999996, 'Kylrum'],
#  [29.4, 10.6, 'Kylrum'],
#  [17.4, 13.600000000000001, 'Kylrum'],
#  [21.4, 1.5999999999999996, 'Kylrum'],
#  [21.4, 8.6, 'Kylrum'],
#  [17.4, 3.5999999999999996, 'Kylrum'],
#  [25.4, 3.5999999999999996, 'Kylrum'],
#  [18.4, 0.5999999999999996, 'Kylrum'],
#  [23.4, 8.6, 'Kylrum'],
#  [18.4, 7.6, 'Kylrum'],
#  [21.4, 10.6, 'Kylrum'],
#  [15.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [16.4, 5.6, 'Kylrum'],
#  [23.4, 10.6, 'Kylrum'],
#  [28.4, 2.5999999999999996, 'Kylrum'],
#  [23.4, 7.6, 'Kylrum'],
#  [24.4, 12.6, 'Kylrum'],
#  [14.399999999999999, 7.6, 'Kylrum'],
#  [24.4, -0.40000000000000036, 'Kylrum'],
#  [24.4, 9.6, 'Kylrum'],
#  [15.399999999999999, 6.6, 'Kylrum'],
#  [14.399999999999999, -2.4000000000000004, 'Kylrum'],
#  [20.4, 10.6, 'Kylrum'],
#  [19.4, 0.5999999999999996, 'Kylrum'],
#  [20.4, 6.6, 'Kylrum'],
#  [24.4, 7.6, 'Kylrum'],
#  [20.4, 0.5999999999999996, 'Kylrum'],
#  [23.4, -4.4, 'Kylrum'],
#  [12.399999999999999, 0.5999999999999996, 'Kylrum'],
#  [14.399999999999999, 6.6, 'Kylrum'],
#  [21.4, 2.5999999999999996, 'Kylrum'],
#  [18.4, 5.6, 'Kylrum'],
#  [26.4, 13.6, 'Kylrum'],
#  [18.4, 1.5999999999999996, 'Kylrum'],
#  [15.399999999999999, -4.4, 'Kylrum'],
#  [14.399999999999999, 10.6, 'Kylrum'],
#  [24.4, 11.6, 'Kylrum'],
#  [10.399999999999999, -4.4, 'Kylrum'],
#  [16.4, -2.4000000000000004, 'Kylrum'],
#  [13.399999999999999, -4.4, 'Kylrum'],
#  [10.399999999999999, 5.6, 'Kylrum'],
#  [21.4, 8.6, 'Kylrum'],
#  [16.4, 2.5999999999999996, 'Kylrum'],
#  [24.4, -3.4000000000000004, 'Kylrum'],
#  [24.4, 5.6, 'Kylrum'],
#  [29.4, 10.6, 'Kylrum'],
#  [18.4, 4.6, 'Kylrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [16.4, -7.4, 'Kylrum'],
#  [26.4, 7.6, 'Kylrum'],
#  [10.399999999999999, -9.4, 'Kylrum'],
#  [28.4, 12.6, 'Kylrum'],
#  [25.4, 6.6, 'Kylrum'],
#  [25.4, 9.6, 'Kylrum'],
#  [12.399999999999999, -1.4000000000000004, 'Kylrum'],
#  [14.399999999999999, 2.5999999999999996, 'Kylrum'],
#  [24.4, 7.6, 'Kylrum'],
#  [8.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [28.4, 11.6, 'Kylrum'],
#  [15.399999999999999, 6.6, 'Kylrum'],
#  [15.399999999999999, -1.4000000000000004, 'Kylrum'],
#  [12.399999999999999, -5.4, 'Kylrum'],
#  [19.4, 3.5999999999999996, 'Kylrum'],
#  [25.4, 7.6, 'Kylrum'],
#  [16.4, -1.4000000000000004, 'Kylrum'],
#  [14.399999999999999, -7.4, 'Kylrum'],
#  [27.4, 2.5999999999999996, 'Kylrum'],
#  [19.4, 4.6, 'Kylrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [17.4, 4.6, 'Kylrum'],
#  [10.399999999999999, 2.5999999999999996, 'Kylrum'],
#  [19.4, 6.6, 'Kylrum'],
#  [29.4, 14.6, 'Kylrum'],
#  [16.4, -6.4, 'Kylrum'],
#  [24.4, 4.6, 'Kylrum'],
#  [27.4, 2.5999999999999996, 'Kylrum'],
#  [12.399999999999999, -6.4, 'Kylrum'],
#  [15.399999999999999, 4.6, 'Kylrum'],
#  [17.4, 13.6, 'Kylrum'],
#  [14.399999999999999, 0.5999999999999996, 'Kylrum'],
#  [27.4, 0.5999999999999996, 'Kylrum'],
#  [27.4, 8.6, 'Kylrum'],
#  [21.4, 5.6, 'Kylrum'],
#  [23.4, 9.6, 'Kylrum'],
#  [25.4, 2.5999999999999996, 'Kylrum'],
#  [20.4, 7.6, 'Kylrum'],
#  [18.4, 5.6, 'Kylrum'],
#  [19.4, 11.6, 'Kylrum'],
#  [16.4, 6.6, 'Kylrum'],
#  [22.4, 5.6, 'Kylrum'],
#  [13.399999999999999, -3.4000000000000004, 'Kylrum'],
#  [23.4, 9.6, 'Kylrum'],
#  [18.4, -3.4000000000000004, 'Kylrum'],
#  [15.399999999999999, -8.4, 'Kylrum'],
#  [17.4, 5.6, 'Kylrum'],
#  [26.4, 12.6, 'Kylrum'],
#  [16.4, 4.6, 'Kylrum'],
#  [12.399999999999999, -4.4, 'Kylrum'],
#  [18.4, 8.6, 'Kylrum'],
#  [14.399999999999999, 2.5999999999999996, 'Kylrum'],
#  [20.4, 10.6, 'Kylrum'],
#  [18.4, 1.5999999999999996, 'Kylrum'],
#  [17.4, 0.5999999999999996, 'Kylrum'],
#  [26.4, 11.6, 'Kylrum'],
#  [16.4, 7.6, 'Kylrum'],
#  [21.4, 10.6, 'Kylrum'],
#  [20.4, 0.5999999999999996, 'Kylrum'],
#  [24.4, -2.4000000000000004, 'Kylrum'],
#  [17.4, 5.6, 'Kylrum'],
#  [23.4, 11.6, 'Kylrum'],
#  [16.4, -11.4, 'Kylrum'],
#  [22.4, 2.5999999999999996, 'Kylrum'],
#  [18.4, 8.6, 'Kylrum'],
#  [14.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [18.4, 7.6, 'Kylrum'],
#  [16.4, -0.40000000000000036, 'Kylrum'],
#  [20.4, 4.6, 'Kylrum'],
#  [16.4, 6.6, 'Kylrum'],
#  [13.399999999999999, -3.4000000000000004, 'Kylrum'],
#  [16.4, 3.5999999999999996, 'Kylrum'],
#  [10.399999999999999, -0.40000000000000036, 'Kylrum'],
#  [21.4, -2.4000000000000004, 'Kylrum'],
#  [21.4, -3.4000000000000004, 'Kylrum'],
#  [25.4, 8.6, 'Kylrum'],
#  [17.4, 4.6, 'Kylrum'],
#  [25.4, 9.6, 'Kylrum'],
#  [23.4, 3.5999999999999996, 'Kylrum'],
#  [14.399999999999999, 12.6, 'Kylrum'],
#  [21.4, 11.6, 'Kylrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [12.399999999999999, 8.6, 'Kylrum'],
#  [23.4, 5.6, 'Kylrum'],
#  [23.4, 3.5999999999999996, 'Kylrum'],
#  [19.4, -0.40000000000000036, 'Kylrum'],
#  [27.4, -0.40000000000000036, 'Kylrum'],
#  [13.399999999999999, 15.6, 'Kylrum'],
#  [14.399999999999999, -0.40000000000000036, 'Kylrum'],
#  [22.4, 3.5999999999999996, 'Kylrum'],
#  [20.4, 4.6, 'Kylrum'],
#  [18.4, -5.4, 'Kylrum'],
#  [27.4, 7.6, 'Kylrum'],
#  [8.399999999999999, -5.4, 'Kylrum'],
#  [13.399999999999999, -8.4, 'Kylrum'],
#  [18.4, 7.6, 'Kylrum'],
#  [15.399999999999999, 4.6, 'Kylrum'],
#  [21.4, 1.5999999999999996, 'Kylrum'],
#  [16.4, 12.6, 'Kylrum'],
#  [29.4, 5.6, 'Kylrum'],
#  [21.4, 4.6, 'Kylrum'],
#  [10.399999999999999, 0.5999999999999996, 'Kylrum'],
#  [28.4, 2.5999999999999996, 'Kylrum'],
#  [27.4, 13.6, 'Kylrum'],
#  [11.399999999999999, 1.5999999999999996, 'Kylrum'],
#  [17.4, 1.5999999999999996, 'Kylrum'],
#  [27.4, 8.6, 'Kylrum'],
#  [12.399999999999999, -0.40000000000000036, 'Kylrum'],
#  [26.4, 2.5999999999999996, 'Kylrum'],
#  [24.4, 13.6, 'Kylrum'],
#  [21.4, 3.5999999999999996, 'Kylrum'],
#  [20.4, 1.5999999999999996, 'Kylrum'],
#  [16.4, 8.6, 'Kylrum'],
#  [16.4, 6.6, 'Kylrum'],
#  [16.4, 3.5999999999999996, 'Kylrum'],
#  [15.399999999999999, 0.5999999999999996, 'Kylrum'],
#  [23.4, 8.6, 'Kylrum'],
#  [25.4, 4.6, 'Kylrum'],
#  [19.4, 8.6, 'Kylrum'],
#  [17.4, 1.5999999999999996, 'Kylrum'],
#  [14.399999999999999, 17.6, 'Kylrum'],
#  [19.4, 4.6, 'Kylrum'],
#  [13.399999999999999, 6.6, 'Kylrum'],
#  [16.4, -6.4, 'Kylrum'],
#  [13.399999999999999, -8.4, 'Kylrum'],
#  [28.4, 14.6, 'Kylrum'],
#  [27.4, 10.6, 'Kylrum'],
#  [12.399999999999999, 4.6, 'Kylrum'],
#  [25.4, -0.40000000000000036, 'Kylrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [20.4, 1.5999999999999996, 'Kylrum'],
#  [26.4, 1.5999999999999996, 'Kylrum'],
#  [28.4, 10.4, 'Kylrum'],
#  [8.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [26.4, 6.6, 'Kylrum'],
#  [22.4, 3.5999999999999996, 'Kylrum'],
#  [18.4, -4.4, 'Kylrum'],
#  [26.4, -4.4, 'Kylrum'],
#  [27.4, 6.6, 'Kylrum'],
#  [25.4, 9.24, 'Kylrum'],
#  [28.4, 5.6, 'Kylrum'],
#  [19.4, -4.4, 'Kylrum'],
#  [27.4, 11.6, 'Kylrum'],
#  [21.4, 8.6, 'Kylrum'],
#  [19.4, 8.6, 'Kylrum'],
#  [24.4, -2.4000000000000004, 'Kylrum'],
#  [18.4, 0.5999999999999996, 'Kylrum'],
#  [22.4, -3.4000000000000004, 'Kylrum'],
#  [21.4, 7.6, 'Kylrum'],
#  [12.399999999999999, -7.4, 'Kylrum'],
#  [18.4, 1.5999999999999996, 'Kylrum'],
#  [13.399999999999999, -8.4, 'Kylrum'],
#  [5.399999999999999, 5.6, 'Kylrum'],
#  [12.399999999999999, 0.5999999999999996, 'Kylrum'],
#  [17.4, -7.4, 'Kylrum'],
#  [23.4, 7.6, 'Kylrum'],
#  [21.4, 9.6, 'Kylrum'],
#  [14.399999999999999, 7.6, 'Kylrum'],
#  [23.4, 4.6, 'Kylrum'],
#  [28.4, 9.6, 'Kylrum'],
#  [9.399999999999999, 13.6, 'Kylrum'],
#  [18.4, 1.5999999999999996, 'Kylrum'],
#  [16.4, 7.6, 'Kylrum'],
#  [17.4, 8.6, 'Kylrum'],
#  [20.4, 5.6, 'Kylrum'],
#  [17.4, -1.4000000000000004, 'Kylrum'],
#  [13.399999999999999, 7.6, 'Kylrum'],
#  [16.4, 7.6, 'Kylrum'],
#  [22.4, 5.6, 'Kylrum'],
#  [15.399999999999999, 5.6, 'Kylrum'],
#  [17.4, -3.4000000000000004, 'Kylrum'],
#  [16.4, 9.6, 'Kylrum'],
#  [27.4, 2.5999999999999996, 'Kylrum'],
#  [10.399999999999999, 1.5999999999999996, 'Kylrum'],
#  [27.4, 5.6, 'Kylrum'],
#  [15.399999999999999, -0.40000000000000036, 'Kylrum'],
#  [20.4, 1.5999999999999996, 'Kylrum'],
#  [17.4, 7.6, 'Kylrum'],
#  [18.4, 10.6, 'Kylrum'],
#  [19.4, 11.6, 'Kylrum'],
#  [14.399999999999999, 8.6, 'Kylrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [22.4, -0.40000000000000036, 'Kylrum'],
#  [29.4, 8.6, 'Kylrum'],
#  [21.4, 11.6, 'Kylrum'],
#  [14.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [26.4, 8.6, 'Kylrum'],
#  [16.4, 4.6, 'Kylrum'],
#  [12.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [13.399999999999999, -11.4, 'Kylrum'],
#  [24.4, 0.5999999999999996, 'Kylrum'],
#  [29.4, 8.6, 'Kylrum'],
#  [17.4, -0.40000000000000036, 'Kylrum'],
#  [24.4, 8.6, 'Kylrum'],
#  [27.4, 5.6, 'Kylrum'],
#  [18.4, 5.6, 'Kylrum'],
#  [19.4, 10.6, 'Kylrum'],
#  [17.4, -0.40000000000000036, 'Kylrum'],
#  [21.4, 0.5999999999999996, 'Kylrum'],
#  [16.4, 4.6, 'Kylrum'],
#  [7.399999999999999, 1.5999999999999996, 'Kylrum'],
#  [26.4, 9.6, 'Kylrum'],
#  [15.399999999999999, -1.4000000000000004, 'Kylrum'],
#  [20.4, 10.6, 'Kylrum'],
#  [20.4, 9.6, 'Kylrum'],
#  [19.4, 5.6, 'Kylrum'],
#  [9.399999999999999, 1.5999999999999996, 'Kylrum'],
#  [20.4, 1.5999999999999996, 'Kylrum'],
#  [16.4, 3.5999999999999996, 'Kylrum'],
#  [7.399999999999999, 2.5999999999999996, 'Kylrum'],
#  [24.4, 10.6, 'Kylrum'],
#  [17.4, -0.40000000000000036, 'Kylrum'],
#  [20.4, 1.5999999999999996, 'Kylrum'],
#  [28.4, 6.6, 'Kylrum'],
#  [25.4, 11.6, 'Kylrum'],
#  [26.4, 8.6, 'Kylrum'],
#  [18.4, 4.6, 'Kylrum'],
#  [15.399999999999999, 6.6, 'Kylrum'],
#  [7.399999999999999, 5.6, 'Kylrum'],
#  [6.399999999999999, 2.5999999999999996, 'Kylrum'],
#  [23.4, 2.5999999999999996, 'Kylrum'],
#  [16.4, -2.4000000000000004, 'Kylrum'],
#  [13.399999999999999, 6.6, 'Kylrum'],
#  [27.4, 17.6, 'Kylrum'],
#  [19.4, 11.600000000000001, 'Kylrum'],
#  [28.4, 5.4, 'Kylrum'],
#  [16.4, 4.6, 'Kylrum'],
#  [13.399999999999999, -0.40000000000000036, 'Kylrum'],
#  [28.4, 11.6, 'Kylrum'],
#  [21.4, -2.4000000000000004, 'Kylrum'],
#  [14.399999999999999, -5.4, 'Kylrum'],
#  [19.4, -0.40000000000000036, 'Kylrum'],
#  [24.4, 5.6, 'Kylrum'],
#  [20.4, 7.6, 'Kylrum'],
#  [27.4, 13.6, 'Kylrum'],
#  [18.4, -4.4, 'Kylrum'],
#  [29.4, 16.6, 'Kylrum'],
#  [9.399999999999999, 12.6, 'Kylrum'],
#  [24.4, 7.6, 'Kylrum'],
#  [21.4, 13.6, 'Kylrum'],
#  [3.3999999999999986, 4.6, 'Kylrum'],
#  [19.4, 10.6, 'Kylrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [9.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [14.399999999999999, 6.6, 'Kylrum'],
#  [17.4, 5.6, 'Kylrum'],
#  [24.4, 3.5999999999999996, 'Kylrum'],
#  [15.399999999999999, 2.5999999999999996, 'Kylrum'],
#  [19.4, 4.6, 'Kylrum'],
#  [17.4, 7.6, 'Kylrum'],
#  [23.4, 0.5999999999999996, 'Kylrum'],
#  [17.4, 10.6, 'Kylrum'],
#  [13.399999999999999, 7.6, 'Kylrum'],
#  [21.4, -2.4000000000000004, 'Kylrum'],
#  [24.4, 1.5999999999999996, 'Kylrum'],
#  [17.4, 4.6, 'Kylrum'],
#  [12.399999999999999, -4.4, 'Kylrum'],
#  [23.4, 2.5999999999999996, 'Kylrum'],
#  [17.4, -1.4000000000000004, 'Kylrum'],
#  [22.4, 0.5999999999999996, 'Kylrum'],
#  [13.399999999999999, 2.5999999999999996, 'Kylrum'],
#  [27.4, 1.5999999999999996, 'Kylrum'],
#  [29.4, 11.6, 'Kylrum'],
#  [20.4, -3.4000000000000004, 'Kylrum'],
#  [20.4, 5.6, 'Kylrum'],
#  [13.399999999999999, 2.5999999999999996, 'Kylrum'],
#  [20.4, 9.6, 'Kylrum'],
#  [15.399999999999999, 4.6, 'Kylrum'],
#  [19.4, 0.5999999999999996, 'Kylrum'],
#  [25.4, 12.6, 'Kylrum'],
#  [19.4, 3.5999999999999996, 'Kylrum'],
#  [16.4, 6.6, 'Kylrum'],
#  [12.399999999999999, 1.5999999999999996, 'Kylrum'],
#  [27.4, 9.6, 'Kylrum'],
#  [16.4, 3.5999999999999996, 'Kylrum'],
#  [21.4, 5.6, 'Kylrum'],
#  [17.4, -2.4000000000000004, 'Kylrum'],
#  [13.399999999999999, -1.4000000000000004, 'Kylrum'],
#  [20.4, 12.6, 'Kylrum'],
#  [21.4, 11.6, 'Kylrum'],
#  [6.399999999999999, 1.5999999999999996, 'Kylrum'],
#  [22.4, 3.5999999999999996, 'Kylrum'],
#  [18.4, 1.5999999999999996, 'Kylrum'],
#  [18.4, 4.6, 'Kylrum'],
#  [16.4, 7.6, 'Kylrum'],
#  [27.4, 12.6, 'Kylrum'],
#  [17.4, -0.40000000000000036, 'Kylrum'],
#  [14.399999999999999, -7.4, 'Kylrum'],
#  [22.4, -3.4000000000000004, 'Kylrum'],
#  [19.4, 2.5999999999999996, 'Kylrum'],
#  [28.4, 6.6, 'Kylrum'],
#  [18.4, 1.5999999999999996, 'Kylrum'],
#  [22.4, 3.5999999999999996, 'Kylrum'],
#  [13.399999999999999, 5.6, 'Kylrum'],
#  [8.399999999999999, -7.4, 'Kylrum'],
#  [26.4, 12.6, 'Kylrum'],
#  [18.4, 4.6, 'Kylrum'],
#  [15.399999999999999, 5.6, 'Kylrum'],
#  [22.4, -1.4000000000000004, 'Kylrum'],
#  [25.4, -1.4000000000000004, 'Kylrum'],
#  [22.4, 12.6, 'Kylrum'],
#  [18.4, -4.4, 'Kylrum'],
#  [20.4, 10.6, 'Kylrum'],
#  [23.4, 5.6, 'Kylrum'],
#  [20.4, 12.6, 'Kylrum'],
#  [16.4, 15.6, 'Kylrum'],
#  [15.399999999999999, 6.6, 'Kylrum'],
#  [19.4, 6.6, 'Kylrum'],
#  [13.399999999999999, 9.6, 'Kylrum'],
#  [15.399999999999999, -9.4, 'Kylrum'],
#  [21.4, 3.5999999999999996, 'Kylrum'],
#  [22.4, 12.6, 'Kylrum'],
#  [5.399999999999999, 5.6, 'Kylrum'],
#  [22.4, 13.6, 'Kylrum'],
#  [21.4, 6.6, 'Kylrum'],
#  [20.4, 6.6, 'Kylrum'],
#  [4.399999999999999, 3.5999999999999996, 'Kylrum'],
#  [15.399999999999999, -5.4, 'Kylrum'],
#  [19.4, -7.4, 'Kylrum'],
#  [17.4, 7.6, 'Kylrum'],
#  [18.4, 2.5999999999999996, 'Kylrum'],
#  [5.399999999999999, 6.6, 'Kylrum'],
#  [20.4, 6.6, 'Kylrum'],
#  [29.4, 4.6, 'Kylrum'],
#  [26.4, 0.5999999999999996, 'Kylrum'],
#  [19.4, -3.4000000000000004, 'Kylrum'],
#  [14.399999999999999, 7.6, 'Kylrum'],
#  [26.4, 2.5999999999999996, 'Kylrum'],
#  [17.4, 10.6, 'Kylrum'],
#  [16.4, 6.6, 'Kylrum'],
#  [20.4, 2.5999999999999996, 'Kylrum'],
#  [10.399999999999999, 8.6, 'Kylrum'],
#  [7.399999999999999, -9.4, 'Kylrum'],
#  [21.4, 9.6, 'Kylrum'],
#  [17.4, 1.5999999999999996, 'Kylrum'],
#  [18.4, 6.6, 'Kylrum'],
#  [22.4, 4.6, 'Kylrum'],
#  [20.4, 6.6, 'Kylrum'],
#  [19.4, 9.6, 'Kylrum'],
#  [20.4, -0.40000000000000036, 'Kylrum'],
#  [22.4, 7.6, 'Kylrum'],
#  [18.4, 12.6, 'Kylrum'],
#  [19.4, 4.6, 'Kylrum'],
#  [15.399999999999999, -3.4000000000000004, 'Kylrum'],
#  [19.4, -1.4000000000000004, 'Kylrum'],
#  [25.4, 4.6, 'Kylrum'],
#  [17.4, -6.4, 'Kylrum'],
#  [19.4, 5.6, 'Kylrum'],
#  [29.4, 9.4, 'Kylrum'],
#  [27.4, 1.5999999999999996, 'Kylrum'],
#  [14.399999999999999, -7.4, 'Kylrum'],
#  [25.4, 9.6, 'Kylrum'],
#  [23.4, 3.5999999999999996, 'Kylrum']]

# %%
def find_best_split(rows):
    """Find the best question to ask by iterating over every feature / value
    and calculating the information gain."""
    best_gain = 0  # keep track of the best information gain
    best_question = None  # keep train of the feature / value that produced it
    current_uncertainty = gini(rows)
    n_features = len(rows[0]) - 1  # number of columns

    for col in range(n_features):  # for each feature

        values = set([row[col] for row in rows])  # unique values in the column

        for val in values:  # for each value

            question = Question(col, val)

            # try splitting the dataset
            true_rows, false_rows = partition(rows, question)

            # Skip this split if it doesn't divide the
            # dataset.
            if len(true_rows) == 0 or len(false_rows) == 0:
                continue

            # Calculate the information gain from this split
            gain = info_gain(true_rows, false_rows, current_uncertainty)

            # You actually can use '>' instead of '>=' here
            # but I wanted the tree to look a certain way for our
            # toy dataset.
            if gain >= best_gain:
                best_gain, best_question = gain, question

    return best_gain, best_question

# %%
#######
# Demo:
# Find the best question to ask first for our toy dataset.
best_gain, best_question = find_best_split(training_data)
best_question
# FYI: is color == Red is just as good. See the note in the code above
# where I used '>='.
#######
# Out:
# Is size >= 60.5?

# %%
class Leaf:
    """A Leaf node classifies data.

    This holds a dictionary of class (e.g., "Apple") -> number of times
    it appears in the rows from the training data that reach this leaf.
    """

    def __init__(self, rows):
        self.predictions = class_counts(rows)

# %%
class Decision_Node:
    """A Decision Node asks a question.

    This holds a reference to the question, and to the two child nodes.
    """

    def __init__(self,
                 question,
                 true_branch,
                 false_branch):
        self.question = question
        self.true_branch = true_branch
        self.false_branch = false_branch

# %%
def build_tree(rows):
    """Builds the tree.

    Rules of recursion: 1) Believe that it works. 2) Start by checking
    for the base case (no further information gain). 3) Prepare for
    giant stack traces.
    """

    # try partitioning the dataset on each of the unique attribute,
    # calculate the information gain,
    # and return the question that produces the highest gain.
    gain, question = find_best_split(rows)

    # Base case: no further info gain
    # Since we can ask no further questions,
    # we'll return a leaf.
    if gain == 0:
        return Leaf(rows)

    # If we reach here, we have found a useful feature / value
    # to partition on.
    true_rows, false_rows = partition(rows, question)

    # Recursively build the true branch.
    true_branch = build_tree(true_rows)

    # Recursively build the false branch.
    false_branch = build_tree(false_rows)

    # Return a Question node.
    # This records the best feature / value to ask at this point,
    # as well as the branches to follow
    # dependingo on the answer.
    return Decision_Node(question, true_branch, false_branch)

# %%
def print_tree(node, spacing=""):
    """World's most elegant tree printing function."""

    # Base case: we've reached a leaf
    if isinstance(node, Leaf):
        print (spacing + "Predict", node.predictions)
        return

    # Print the question at this node
    print (spacing + str(node.question))

    # Call this function recursively on the true branch
    print (spacing + '--> True:')
    print_tree(node.true_branch, spacing + "  ")

    # Call this function recursively on the false branch
    print (spacing + '--> False:')
    print_tree(node.false_branch, spacing + "  ")

# %%
my_tree = build_tree(training_data)

# %%
print_tree(my_tree)
# Out:
# Is size >= 60.5?
# --> True:
#   Is size >= 90.4?
#   --> True:
#     Is temp >= 20.4?
#     --> True:
#       Is size >= 91.4?
#       --> True:
#         Is size >= 94.4?
#         --> True:
#           Predict {'Klassrum': 86}
#         --> False:
#           Is temp >= 23.4?
#           --> True:
#             Predict {'Klassrum': 26}
#           --> False:
#             Is temp >= 23.1?
#             --> True:
#               Predict {'Lärarrum': 1}
#             --> False:
#               Is temp >= 21.4?
#               --> True:
#                 Is size >= 93.4?
#                 --> True:
#                   Is temp >= 22.4?
#                   --> True:
#                     Predict {'Klassrum': 4}
#                   --> False:
#                     Is temp >= 22.1?
#                     --> True:
#                       Predict {'Lärarrum': 1}
#                     --> False:
#                       Predict {'Klassrum': 3}
#                 --> False:
#                   Predict {'Klassrum': 18}
#               --> False:
#                 Is temp >= 21.1?
#                 --> True:
#                   Predict {'Lärarrum': 1}
#                 --> False:
#                   Predict {'Klassrum': 6}
#       --> False:
#         Is temp >= 23.1?
#         --> True:
#           Is temp >= 23.4?
#           --> True:
#             Is temp >= 25.5?
#             --> True:
#               Predict {'Klassrum': 5}
#             --> False:
#               Is temp >= 25.1?
#               --> True:
#                 Predict {'Lärarrum': 1}
#               --> False:
#                 Predict {'Klassrum': 3}
#           --> False:
#             Predict {'Lärarrum': 2}
#         --> False:
#           Predict {'Klassrum': 12}
#     --> False:
#       Is temp >= 20.1?
#       --> True:
#         Predict {'Lärarrum': 4}
#       --> False:
#         Is size >= 95.4?
#         --> True:
#           Is temp >= 13.5?
#           --> True:
#             Predict {'Klassrum': 34}
#           --> False:
#             Is temp >= 13.100000000000001?
#             --> True:
#               Predict {'Lärarrum': 1}
#             --> False:
#               Predict {'Klassrum': 2}
#         --> False:
#           Is temp >= 19.4?
#           --> True:
#             Predict {'Klassrum': 8}
#           --> False:
#             Is temp >= 19.1?
#             --> True:
#               Predict {'Lärarrum': 3}
#             --> False:
#               Is temp >= 18.4?
#               --> True:
#                 Predict {'Klassrum': 6}
#               --> False:
#                 Is temp >= 18.1?
#                 --> True:
#                   Predict {'Lärarrum': 3}
#                 --> False:
#                   Is temp >= 15.5?
#                   --> True:
#                     Predict {'Klassrum': 5}
#                   --> False:
#                     Is temp >= 15.100000000000001?
#                     --> True:
#                       Predict {'Lärarrum': 3}
#                     --> False:
#                       Predict {'Klassrum': 1}
#   --> False:
#     Is size >= 82.4?
#     --> True:
#       Is temp >= 19.4?
#       --> True:
#         Is temp >= 20.1?
#         --> True:
#           Is temp >= 20.4?
#           --> True:
#             Is temp >= 21.1?
#             --> True:
#               Is temp >= 21.4?
#               --> True:
#                 Is temp >= 22.1?
#                 --> True:
#                   Is temp >= 22.4?
#                   --> True:
#                     Is temp >= 23.1?
#                     --> True:
#                       Is temp >= 23.4?
#                       --> True:
#                         Is temp >= 24.1?
#                         --> True:
#                           Is temp >= 24.4?
#                           --> True:
#                             Is temp >= 25.1?
#                             --> True:
#                               Is temp >= 25.4?
#                               --> True:
#                                 Is temp >= 26.1?
#                                 --> True:
#                                   Is temp >= 26.4?
#                                   --> True:
#                                     Is temp >= 27.4?
#                                     --> True:
#                                       Predict {'Klassrum': 8}
#                                     --> False:
#                                       Is temp >= 27.1?
#                                       --> True:
#                                         Predict {'Lärarrum': 1}
#                                       --> False:
#                                         Predict {'Klassrum': 4}
#                                   --> False:
#                                     Predict {'Lärarrum': 2}
#                                 --> False:
#                                   Predict {'Klassrum': 10}
#                               --> False:
#                                 Predict {'Lärarrum': 4}
#                             --> False:
#                               Predict {'Klassrum': 20}
#                           --> False:
#                             Predict {'Lärarrum': 12}
#                         --> False:
#                           Predict {'Klassrum': 18}
#                       --> False:
#                         Predict {'Lärarrum': 5}
#                     --> False:
#                       Predict {'Klassrum': 23}
#                   --> False:
#                     Predict {'Lärarrum': 9}
#                 --> False:
#                   Predict {'Klassrum': 17}
#               --> False:
#                 Predict {'Lärarrum': 16}
#             --> False:
#               Predict {'Klassrum': 26}
#           --> False:
#             Predict {'Lärarrum': 17}
#         --> False:
#           Predict {'Klassrum': 25}
#       --> False:
#         Is temp >= 19.1?
#         --> True:
#           Predict {'Lärarrum': 16}
#         --> False:
#           Is temp >= 18.4?
#           --> True:
#             Predict {'Klassrum': 10}
#           --> False:
#             Is temp >= 18.1?
#             --> True:
#               Predict {'Lärarrum': 18}
#             --> False:
#               Is temp >= 17.5?
#               --> True:
#                 Predict {'Klassrum': 12}
#               --> False:
#                 Is temp >= 17.1?
#                 --> True:
#                   Predict {'Lärarrum': 11}
#                 --> False:
#                   Is temp >= 16.4?
#                   --> True:
#                     Predict {'Klassrum': 7}
#                   --> False:
#                     Is size >= 85.4?
#                     --> True:
#                       Is size >= 88.4?
#                       --> True:
#                         Predict {'Lärarrum': 4}
#                       --> False:
#                         Is temp >= 14.100000000000001?
#                         --> True:
#                           Is temp >= 14.5?
#                           --> True:
#                             Is temp >= 15.100000000000001?
#                             --> True:
#                               Is temp >= 15.5?
#                               --> True:
#                                 Is temp >= 16.1?
#                                 --> True:
#                                   Predict {'Lärarrum': 1}
#                                 --> False:
#                                   Predict {'Klassrum': 1}
#                               --> False:
#                                 Predict {'Lärarrum': 2}
#                             --> False:
#                               Predict {'Klassrum': 2}
#                           --> False:
#                             Predict {'Lärarrum': 3}
#                         --> False:
#                           Is temp >= 13.399999999999999?
#                           --> True:
#                             Predict {'Klassrum': 2}
#                           --> False:
#                             Predict {'Lärarrum': 1}
#                     --> False:
#                       Is size >= 83.4?
#                       --> True:
#                         Predict {'Lärarrum': 13}
#                       --> False:
#                         Is temp >= 14.5?
#                         --> True:
#                           Is temp >= 16.1?
#                           --> True:
#                             Predict {'Lärarrum': 1}
#                           --> False:
#                             Predict {'Klassrum': 1}
#                         --> False:
#                           Predict {'Lärarrum': 2}
#     --> False:
#       Is temp >= 13.5?
#       --> True:
#         Is temp >= 28.8?
#         --> True:
#           Predict {'Klassrum': 4}
#         --> False:
#           Is temp >= 22.1?
#           --> True:
#             Is temp >= 22.8?
#             --> True:
#               Is temp >= 23.1?
#               --> True:
#                 Is size >= 78.4?
#                 --> True:
#                   Is temp >= 23.4?
#                   --> True:
#                     Is size >= 79.4?
#                     --> True:
#                       Is temp >= 26.4?
#                       --> True:
#                         Is temp >= 27.7?
#                         --> True:
#                           Is temp >= 28.4?
#                           --> True:
#                             Predict {'Klassrum': 1}
#                           --> False:
#                             Predict {'Lärarrum': 1}
#                         --> False:
#                           Predict {'Klassrum': 6}
#                       --> False:
#                         Is temp >= 25.1?
#                         --> True:
#                           Predict {'Lärarrum': 5}
#                         --> False:
#                           Is temp >= 24.4?
#                           --> True:
#                             Predict {'Klassrum': 3}
#                           --> False:
#                             Is temp >= 23.7?
#                             --> True:
#                               Predict {'Lärarrum': 2}
#                             --> False:
#                               Predict {'Klassrum': 3}
#                     --> False:
#                       Predict {'Klassrum': 7}
#                   --> False:
#                     Predict {'Lärarrum': 6}
#                 --> False:
#                   Is temp >= 23.8?
#                   --> True:
#                     Is temp >= 24.1?
#                     --> True:
#                       Is temp >= 24.8?
#                       --> True:
#                         Is temp >= 25.1?
#                         --> True:
#                           Is temp >= 26.7?
#                           --> True:
#                             Predict {'Lärarrum': 13}
#                           --> False:
#                             Is temp >= 25.8?
#                             --> True:
#                               Predict {'Klassrum': 3}
#                             --> False:
#                               Predict {'Lärarrum': 9}
#                         --> False:
#                           Predict {'Klassrum': 6}
#                       --> False:
#                         Predict {'Lärarrum': 15}
#                     --> False:
#                       Predict {'Klassrum': 6}
#                   --> False:
#                     Predict {'Lärarrum': 14}
#               --> False:
#                 Predict {'Klassrum': 10}
#             --> False:
#               Is size >= 80.4?
#               --> True:
#                 Is temp >= 22.5?
#                 --> True:
#                   Is temp >= 22.7?
#                   --> True:
#                     Predict {'Lärarrum': 2}
#                   --> False:
#                     Predict {'Klassrum': 3}
#                 --> False:
#                   Predict {'Lärarrum': 4}
#               --> False:
#                 Predict {'Lärarrum': 25}
#           --> False:
#             Is temp >= 21.8?
#             --> True:
#               Predict {'Klassrum': 14}
#             --> False:
#               Is temp >= 21.7?
#               --> True:
#                 Predict {'Lärarrum': 18}
#               --> False:
#                 Is temp >= 20.8?
#                 --> True:
#                   Is temp >= 21.1?
#                   --> True:
#                     Is temp >= 21.4?
#                     --> True:
#                       Predict {'Klassrum': 4}
#                     --> False:
#                       Predict {'Lärarrum': 6}
#                   --> False:
#                     Predict {'Klassrum': 23}
#                 --> False:
#                   Is temp >= 20.1?
#                   --> True:
#                     Is size >= 79.4?
#                     --> True:
#                       Is temp >= 20.5?
#                       --> True:
#                         Is temp >= 20.7?
#                         --> True:
#                           Predict {'Lärarrum': 1}
#                         --> False:
#                           Predict {'Klassrum': 3}
#                       --> False:
#                         Predict {'Lärarrum': 7}
#                     --> False:
#                       Predict {'Lärarrum': 22}
#                   --> False:
#                     Is temp >= 19.8?
#                     --> True:
#                       Predict {'Klassrum': 23}
#                     --> False:
#                       Is temp >= 19.1?
#                       --> True:
#                         Is temp >= 19.7?
#                         --> True:
#                           Predict {'Lärarrum': 23}
#                         --> False:
#                           Is temp >= 19.4?
#                           --> True:
#                             Predict {'Klassrum': 3}
#                           --> False:
#                             Predict {'Lärarrum': 18}
#                       --> False:
#                         Is temp >= 18.8?
#                         --> True:
#                           Predict {'Klassrum': 24}
#                         --> False:
#                           Is temp >= 18.1?
#                           --> True:
#                             Is temp >= 18.7?
#                             --> True:
#                               Predict {'Lärarrum': 13}
#                             --> False:
#                               Is temp >= 18.5?
#                               --> True:
#                                 Predict {'Klassrum': 2}
#                               --> False:
#                                 Predict {'Lärarrum': 8}
#                           --> False:
#                             Is temp >= 17.8?
#                             --> True:
#                               Predict {'Klassrum': 22}
#                             --> False:
#                               Is temp >= 17.1?
#                               --> True:
#                                 Predict {'Lärarrum': 23}
#                               --> False:
#                                 Is temp >= 16.8?
#                                 --> True:
#                                   Predict {'Klassrum': 9}
#                                 --> False:
#                                   Is temp >= 16.1?
#                                   --> True:
#                                     Is size >= 62.5?
#                                     --> True:
#                                       Is size >= 77.4?
#                                       --> True:
#                                         Is temp >= 16.5?
#                                         --> True:
#                                           Is temp >= 16.7?
#                                           --> True:
#                                             Predict {'Lärarrum': 1}
#                                           --> False:
#                                             Predict {'Klassrum': 3}
#                                         --> False:
#                                           Predict {'Lärarrum': 6}
#                                       --> False:
#                                         Predict {'Lärarrum': 13}
#                                     --> False:
#                                       Predict {'Kylrum': 1}
#                                   --> False:
#                                     Is temp >= 15.8?
#                                     --> True:
#                                       Predict {'Klassrum': 13}
#                                     --> False:
#                                       Is temp >= 15.100000000000001?
#                                       --> True:
#                                         Is size >= 67.5?
#                                         --> True:
#                                           Is size >= 73.5?
#                                           --> True:
#                                             Predict {'Lärarrum': 13}
#                                           --> False:
#                                             Is temp >= 15.7?
#                                             --> True:
#                                               Predict {'Lärarrum': 5}
#                                             --> False:
#                                               Predict {'Klassrum': 1}
#                                         --> False:
#                                           Predict {'Kylrum': 1}
#                                       --> False:
#                                         Is temp >= 14.8?
#                                         --> True:
#                                           Predict {'Klassrum': 5}
#                                         --> False:
#                                           Is temp >= 14.100000000000001?
#                                           --> True:
#                                             Is size >= 66.5?
#                                             --> True:
#                                               Is temp >= 14.5?
#                                               --> True:
#                                                 Is temp >= 14.7?
#                                                 --> True:
#                                                   Predict {'Lärarrum': 3}
#                                                 --> False:
#                                                   Predict {'Klassrum': 2}
#                                               --> False:
#                                                 Predict {'Lärarrum': 4}
#                                             --> False:
#                                               Predict {'Kylrum': 1}
#                                           --> False:
#                                             Is temp >= 13.8?
#                                             --> True:
#                                               Predict {'Klassrum': 5}
#                                             --> False:
#                                               Is temp >= 13.7?
#                                               --> True:
#                                                 Predict {'Lärarrum': 2}
#                                               --> False:
#                                                 Predict {'Klassrum': 1}
#       --> False:
#         Is size >= 69.5?
#         --> True:
#           Predict {'Lärarrum': 17}
#         --> False:
#           Predict {'Kylrum': 6}
# --> False:
#   Is temp >= 18.1?
#   --> True:
#     Is size >= 51.4?
#     --> True:
#       Is temp >= 21.1?
#       --> True:
#         Predict {'Lärarrum': 10}
#       --> False:
#         Is temp >= 20.8?
#         --> True:
#           Predict {'Klassrum': 2}
#         --> False:
#           Is size >= 57.4?
#           --> True:
#             Predict {'Lärarrum': 7}
#           --> False:
#             Is temp >= 19.1?
#             --> True:
#               Is size >= 56.4?
#               --> True:
#                 Predict {'Kylrum': 1}
#               --> False:
#                 Predict {'Lärarrum': 4}
#             --> False:
#               Predict {'Kylrum': 1}
#     --> False:
#       Is temp >= 19.1?
#       --> True:
#         Is temp >= 20.4?
#         --> True:
#           Predict {'Kylrum': 1}
#         --> False:
#           Predict {'Lärarrum': 1}
#       --> False:
#         Predict {'Kylrum': 1}
#   --> False:
#     Is temp >= 16.1?
#     --> True:
#       Is temp >= 16.4?
#       --> True:
#         Is size >= 58.4?
#         --> True:
#           Predict {'Lärarrum': 1}
#         --> False:
#           Is size >= 51.4?
#           --> True:
#             Is size >= 52.4?
#             --> True:
#               Predict {'Kylrum': 8}
#             --> False:
#               Is temp >= 17.4?
#               --> True:
#                 Predict {'Kylrum': 1}
#               --> False:
#                 Predict {'Lärarrum': 1}
#           --> False:
#             Predict {'Kylrum': 22}
#       --> False:
#         Predict {'Lärarrum': 1}
#     --> False:
#       Predict {'Kylrum': 869}

# %%
def classify(row, node):
    """See the 'rules of recursion' above."""

    # Base case: we've reached a leaf
    if isinstance(node, Leaf):
        return node.predictions

    # Decide whether to follow the true-branch or the false-branch.
    # Compare the feature / value stored in the node,
    # to the example we're considering.
    if node.question.match(row):
        return classify(row, node.true_branch)
    else:
        return classify(row, node.false_branch)

# %%
#######
# Demo:
# The tree predicts the 1st row of our
# training data is an apple with confidence 1.
classify(training_data[0], my_tree)
#######
# Out:
# {'Kylrum': 869}

# %%
def print_leaf(counts):
    """A nicer way to print the predictions at a leaf."""
    total = sum(counts.values()) * 1.0
    probs = {}
    for lbl in counts.keys():
        probs[lbl] = str(int(counts[lbl] / total * 100)) + "%"
    return probs

# %%
#######
# Demo:
# Printing that a bit nicer
print_leaf(classify(training_data[0], my_tree))
#######
# Out:
# {'Kylrum': '100%'}

# %%
#######
# Demo:
# On the second example, the confidence is lower
print_leaf(classify(training_data[1], my_tree))
#######
# Out:
# {'Kylrum': '100%'}

# %%
# Evaluate
testing_data = [   
    [30, 15.6, 'Kylrum'],
    [50, 16, 'Klassrum'],
    [89, 21, 'Klassrum'],
    [81.7, 19,'Lärarrum'],
    [87, 19.8, 'Lärarrum'],
]

# %%
def generate_testingdata(times):
    while times != 0:
        randomRow = testing_data[random.randint(0, len(testing_data) - 1)]
        new_row = [randomRow[0]+ round(random.uniform(-5, 5)), randomRow[1] + round(random.uniform(-3, 3)), randomRow[2]]
        testing_data.append(new_row)
        times += -1

# %%
generate_testingdata(20)

# %%
for row in testing_data:
    print ("Actual: %s. Predicted: %s" %
           (row[-1], print_leaf(classify(row, my_tree))))
# Out:
# Actual: Kylrum. Predicted: {'Kylrum': '100%'}
# Actual: Klassrum. Predicted: {'Kylrum': '100%'}
# Actual: Klassrum. Predicted: {'Klassrum': '100%'}
# Actual: Lärarrum. Predicted: {'Klassrum': '100%'}
# Actual: Lärarrum. Predicted: {'Klassrum': '100%'}
# Actual: Kylrum. Predicted: {'Kylrum': '100%'}
# Actual: Lärarrum. Predicted: {'Klassrum': '100%'}
# Actual: Lärarrum. Predicted: {'Klassrum': '100%'}
# Actual: Kylrum. Predicted: {'Kylrum': '100%'}
# Actual: Kylrum. Predicted: {'Kylrum': '100%'}
# Actual: Lärarrum. Predicted: {'Klassrum': '100%'}
# Actual: Klassrum. Predicted: {'Lärarrum': '100%'}
# Actual: Lärarrum. Predicted: {'Klassrum': '100%'}
# Actual: Lärarrum. Predicted: {'Lärarrum': '100%'}
# Actual: Lärarrum. Predicted: {'Klassrum': '100%'}
# Actual: Lärarrum. Predicted: {'Klassrum': '100%'}
# Actual: Lärarrum. Predicted: {'Klassrum': '100%'}
# Actual: Kylrum. Predicted: {'Kylrum': '100%'}
# Actual: Kylrum. Predicted: {'Kylrum': '100%'}
# Actual: Klassrum. Predicted: {'Kylrum': '100%'}
# Actual: Kylrum. Predicted: {'Kylrum': '100%'}
# Actual: Lärarrum. Predicted: {'Klassrum': '100%'}
# Actual: Lärarrum. Predicted: {'Klassrum': '100%'}
# Actual: Klassrum. Predicted: {'Klassrum': '100%'}
# Actual: Klassrum. Predicted: {'Kylrum': '100%'}
